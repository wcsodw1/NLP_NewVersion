# %% [markdown]
# # how to generate document vector ?

# %%
import pickle
from gensim.models import Doc2Vec, doc2vec
from gensim.models import word2vec
import random
import numpy as np
import logging
import os

## turn back to main directory
os.chdir("../")
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Resume\\V2.5\\v2-5-nlp\\Part2'

# %%
print(Doc2Vec)
print(doc2vec)
# Out:
# <class 'gensim.models.doc2vec.Doc2Vec'>
# <module 'gensim.models.doc2vec' from 'C:\\Users\\user\\Anaconda3\\lib\\site-packages\\gensim\\models\\doc2vec.py'>

# %%
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
logging.root.setLevel(level=logging.INFO)

# %%
## load 'article_cutted'

os.chdir("data/")
os.getcwd()

with open('article_cutted', 'rb') as file:
    data = pickle.load(file)

# %%
#check data
data
# Out:
# [['韓瑜',
#   '協志',
#   '前妻',
#   '正',
#   '女演員',
#   '周子',
#   '瑜',
#   'TWICE',
#   '團裡裡面',
#   '台灣',
#   '人',
#   '正',
#   '兩個',
#   '要當',
#   '鄉民',
#   '老婆',
#   '選',
#   '五樓',
#   '真',
#   '勇氣'],
#  ['dear',
#   'all',
#   '逢甲',
#   '碟仙',
#   '發生',
#   '民國',
#   '七十五年',
#   '三月中',
#   '事情',
#   '一堆',
#   '大學生',
#   '玩',
#   '碟仙',
#   '後發',
#   'bbs',
#   '成功',
#   '預測',
#   '地震',
#   '小弟',
#   '預言',
#   '都還沒',
#   '出生',
#   '後面',
#   '說',
#   '預言',
#   '一百',
#   '一十六年',
#   '兩岸',
#   '統一',
#   '統一',
#   '對岸',
#   '對岸',
#   '統一',
#   '應該',
#   '不用',
#   '猜',
#   '真的',
#   '存在',
#   '預言',
#   '這種',
#   '事情',
#   '倒底',
#   '被統',
#   '知道',
#   '資料庫',
#   '發文',
#   '日期',
#   '輕鬆',
#   '改變',
#   '拍照',
#   '狀況',
#   '下',
#   '碟仙',
#   '真的假',
#   '有沒有',
#   '科學',
#   '經驗',
#   '法則',
#   '破解',
#   '謠言',
#   '真實',
#   '八卦'],
#  ['晚上',
#   '好',
#   '預備',
#   '唱',
#   '風雲',
#   '山河',
#   '動',
#   '國軍',
#   '早上',
#   '唱',
#   '有沒有',
#   '相關',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Xiaomi',
#   'Redmi',
#   'Note'],
#  ['明天',
#   '早起',
#   '睡覺',
#   '旁邊',
#   'Youtube',
#   '眼睛',
#   '壞掉',
#   '有沒有',
#   '方法',
#   '早點',
#   '睡',
#   '掛',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'D10i'],
#  ['一段時間',
#   '注意',
#   'LOL',
#   '發現',
#   '各大',
#   'LOL',
#   '討論區',
#   '人數',
#   '明顯',
#   '下降',
#   '趨勢',
#   '實在',
#   '令人',
#   '驚訝',
#   '曾經',
#   '一時',
#   '遊戲',
#   '霸主',
#   '漸漸',
#   '過氣',
#   'LOL',
#   '確實',
#   '撐',
#   '久',
#   '現在',
#   '算',
#   '厲害',
#   '遊戲',
#   '玩久',
#   '會膩'],
#  ['總覺',
#   '每天',
#   '睡',
#   '睡覺時間',
#   '睡',
#   '不著',
#   '長時間',
#   '有沒有',
#   '相關',
#   '八卦',
#   '世界',
#   '大學排名',
#   'No.12',
#   'U',
#   'niversity',
#   'of',
#   'C',
#   'alifornia',
#   'L',
#   'os',
#   'ngeles',
#   '國立',
#   '台灣',
#   '大學'],
#  ['現在',
#   'messenger',
#   '好像',
#   '一個',
#   '新',
#   '功能',
#   '類似',
#   '日期',
#   '文字',
#   '出現',
#   '底線',
#   '再',
#   '點選',
#   '建立',
#   '計畫',
#   '以下',
#   '小魯',
#   '朋友',
#   '對話',
#   '原來',
#   '國慶'],
#  ['題',
#   '一堆',
#   '山路',
#   '天黑',
#   '後',
#   '路燈',
#   '暗冥',
#   '矇',
#   '有人',
#   '一套',
#   '很長',
#   '鋼絲',
#   '綁',
#   '山壁',
#   '護欄',
#   '天亮',
#   '後'],
#  ['資料',
#   '上市公司',
#   '味全',
#   '公司',
#   '公司',
#   '提供',
#   '民國',
#   '年',
#   '月',
#   '單位',
#   '新台幣',
#   '仟',
#   '元',
#   '項目',
#   '營業',
#   '收入',
#   '淨額',
#   '本月',
#   '去年同期',
#   '增減',
#   '金額',
#   '增減',
#   '百分比',
#   '年',
#   '累計',
#   '去年',
#   '累計',
#   '增減',
#   '金額',
#   '增減',
#   '百分比',
#   'YTD',
#   '負的',
#   '單月',
#   '翻',
#   '正',
#   '滅頂',
#   '鄉民',
#   '臉',
#   '有沒有',
#   '腫腫',
#   '加油',
#   '月份',
#   '成長',
#   '表示',
#   '秒',
#   '買',
#   '秒',
#   '退',
#   '抵制',
#   '無效',
#   '業績',
#   '更好',
#   '不夠',
#   '腫',
#   '加油',
#   '拒買',
#   '好',
#   '大多數',
#   '人',
#   '行為',
#   '背道而馳',
#   '精確',
#   '地說',
#   '拒買',
#   '人',
#   '越來越少',
#   '囉',
#   '好好',
#   '堅持下去',
#   '呦',
#   '覺得',
#   '越來越',
#   '好',
#   '喔',
#   '加油',
#   '嘴',
#   '砲',
#   '鍵盤',
#   '滅頂',
#   'EINARD',
#   '賽賽',
#   '郎',
#   '他養',
#   '閒',
#   '義務',
#   '每個',
#   '月',
#   '更新',
#   '閒',
#   '更新',
#   '消息',
#   '味全'],
#  ['題',
#   '這篇文',
#   '月',
#   '號',
#   '唯一',
#   '一篇',
#   '金城武',
#   '文',
#   '今天',
#   '這篇',
#   '金城武',
#   '文就會',
#   '中斷',
#   '連續',
#   '一個多月',
#   '每天',
#   'PO',
#   '文',
#   '紀錄',
#   '金城武',
#   '知道',
#   '八卦',
#   '版有',
#   '紀錄',
#   'I',
#   'see',
#   'you'],
#  ['今年',
#   '指考',
#   '台大',
#   '機械',
#   '幹掉',
#   '清大電資',
#   '學士',
#   '清大資',
#   '工資',
#   '電組',
#   '台大',
#   '機械',
#   '收',
#   '人',
#   '比較',
#   '看板',
#   '資電',
#   '潮',
#   '機械',
#   '悲傷',
#   '好',
#   '有無',
#   '八卦'],
#  ['本來',
#   '水管',
#   '搭',
#   '沒一搭',
#   '有人',
#   '放',
#   '現在',
#   '操掉',
#   '惹',
#   '第三季',
#   '還沒',
#   '看到',
#   '一半',
#   '想',
#   '請問',
#   '有無',
#   '鍛刀',
#   '大賽',
#   '八卦',
#   '看到',
#   '一季',
#   '感覺',
#   '全美',
#   '刀匠',
#   '已經',
#   '上過',
#   '一直',
#   '洗',
#   '舊',
#   '面孔',
#   '知道',
#   '幹嘛'],
#  ['南部',
#   '高中',
#   '分數',
#   '好像',
#   '越來越低',
#   '相反',
#   '北部',
#   '高中',
#   '似乎',
#   '分數',
#   '越來越',
#   '高',
#   '請問',
#   '南一中',
#   '北北基',
#   '程度',
#   '高中',
#   '有板',
#   '中強'],
#  ['看到',
#   '頂尖',
#   '國立大學',
#   '圖書館',
#   '裡面',
#   '學生',
#   '一望無際',
#   '使',
#   '使用',
#   '蘋果',
#   '筆電',
#   '居多',
#   '蘋果',
#   '筆電',
#   '價格',
#   '六萬多',
#   '後',
#   '段',
#   '私校',
#   '學店',
#   '使用',
#   '東芝',
#   '筆電會',
#   '取笑',
#   '有沒有',
#   '頂尖',
#   '國立大學',
#   '使用',
#   '蘋果',
#   '筆電',
#   '八卦'],
#  ['機師',
#   '聽說',
#   '月薪',
#   '一二十萬',
#   '說',
#   '開',
#   '飛機',
#   '很酷',
#   '但版',
#   '只',
#   '推當',
#   '醫師',
#   '工程師',
#   '小弟',
#   '太',
#   '邊緣',
#   '身旁',
#   '走',
#   '這條',
#   '路',
#   '朋友',
#   '想',
#   '聽',
#   '相關',
#   '經驗',
#   '分享',
#   '一下',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'A9u'],
#  ['最近',
#   '出國',
#   '問到',
#   '人',
#   '從沒',
#   '保',
#   '說',
#   '刷卡',
#   '送',
#   '搭機',
#   '出事',
#   '航空公司',
#   '保',
#   '保',
#   '幹麻',
#   '故有',
#   '一問',
#   '旅行',
#   '會保',
#   '旅平險',
#   '國內',
#   '保',
#   '國外',
#   '不保',
#   '國內',
#   '不保',
#   '國外',
#   '保',
#   '刷卡',
#   '不用',
#   '保',
#   '國內外',
#   '保',
#   '宅',
#   '在家',
#   '保',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['嘻嘻',
#   '肥肥',
#   'ㄤ',
#   'ㄤ',
#   '我亞綸',
#   'ㄌ',
#   '小時候',
#   '聽說',
#   '手指',
#   '月亮',
#   '耳朵',
#   '割下來',
#   '那用',
#   '雞雞',
#   '指著',
#   '月亮',
#   '發生',
#   '事',
#   '嘻嘻',
#   '再',
#   '對準',
#   '月亮',
#   '手槍',
#   'JIZZ',
#   '超大',
#   '一炮',
#   '月亮',
#   'ㄅ',
#   '敬',
#   '發生',
#   '事',
#   '有木有',
#   '肥肥',
#   '知道'],
#  ['眾多',
#   '肥宅',
#   '單身',
#   '好',
#   '選擇',
#   '爭鮮',
#   '不開',
#   '小時',
#   '餵養',
#   '眾多',
#   '單身',
#   '肥宅',
#   '半夜',
#   '整家店',
#   '散發出',
#   '宅味',
#   '有沒有',
#   '八卦'],
#  ['之前',
#   '傳出',
#   '說',
#   '有人',
#   '使用',
#   '大學',
#   '宿網',
#   '下載',
#   'BT',
#   '抓',
#   '想',
#   '請問',
#   '現在',
#   '教育部',
#   '學術',
#   '網路',
#   '抓',
#   'BT',
#   '現在',
#   '人',
#   '使用',
#   '宿舍',
#   '網路',
#   '抓',
#   'BT',
#   '有沒有',
#   '使用',
#   '大學',
#   '宿舍',
#   '網路',
#   'BT',
#   '下載',
#   '抓',
#   '八卦'],
#  ['乳蹄',
#   '水之七島',
#   '美好',
#   '年代',
#   '六式',
#   '超越',
#   '人體',
#   '極限',
#   '超人',
#   '技能',
#   '鐵塊',
#   '武裝',
#   '色',
#   '壓制',
#   '紙繪',
#   '用學',
#   '見聞',
#   '色',
#   '直接',
#   '躲',
#   '現在',
#   '職場',
#   '過勞',
#   '普遍',
#   '肝臟',
#   '修練',
#   '鐵塊',
#   '用紙',
#   '繪',
#   '躲',
#   '工作',
#   '月步',
#   '直接',
#   '窗戶',
#   '下班',
#   '主管',
#   '看到',
#   '剃',
#   '用來',
#   '捷運',
#   '關門',
#   '前',
#   '衝進去',
#   '覺得',
#   '挺',
#   '實用',
#   '技能',
#   '學會',
#   '六式',
#   '起薪',
#   '肥肥',
#   '宅',
#   '好',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   '堅持',
#   '手打',
#   '簽名檔',
#   '設定',
#   '印章',
#   '檔'],
#  ['之前',
#   '看過',
#   '幾個',
#   '爸爸媽媽',
#   '小寶寶',
#   '玩',
#   '看到',
#   '嘴巴',
#   '玩',
#   '屁股',
#   '應該',
#   '吃',
#   '一個',
#   'ㄅ',
#   'ㄛ',
#   'ㄅ',
#   'ㄛ',
#   'ㄅ',
#   'ㄛ',
#   '聲音',
#   '小',
#   '嬰兒',
#   '笑',
#   '超',
#   '開心',
#   '看過',
#   '好幾個',
#   '父母',
#   '阿公',
#   '阿嬤會',
#   '有沒有',
#   '大人',
#   '喜歡',
#   '吃',
#   '小',
#   '嬰兒',
#   '屁股',
#   '八卦'],
#  ['字',
#   '美的',
#   '男生',
#   '國考',
#   '申論題',
#   '有點',
#   '優勢',
#   '實在',
#   '想不出',
#   '妹有',
#   '優勢',
#   '以前',
#   '把妹',
#   '寫',
#   '情書',
#   '賣弄',
#   '文采',
#   '現在',
#   '用賴',
#   '打字',
#   '傳情',
#   '告白',
#   '會管',
#   '字',
#   '美不美',
#   '字',
#   '美的',
#   '男生',
#   '是不是',
#   '把妹',
#   '方面',
#   '完全',
#   '優勢',
#   '可言'],
#  ['看到',
#   '有多人',
#   '推文',
#   '留言',
#   '會問',
#   '哪部',
#   '問是',
#   '嗆',
#   '聲',
#   '真的',
#   '想',
#   '知道',
#   '肥宅',
#   '發文',
#   '當成',
#   '作品',
#   '影射',
#   '幻想',
#   '沒人',
#   '相信',
#   '叔叔',
#   '度蜜月',
#   '經營',
#   '女僕',
#   '俱樂部',
#   '交給',
#   '打理',
#   '這種',
#   '故事'],
#  ['剛剛',
#   '本魯在',
#   '河濱',
#   '騎',
#   '腳踏車',
#   '聽到',
#   '消防車',
#   '聲音',
#   '好像',
#   '木柵',
#   '焚化爐',
#   '有沒有',
#   '發生',
#   '事',
#   '八卦'],
#  ['乳提',
#   '今天',
#   '可愛',
#   '女朋友',
#   '摸',
#   '完',
#   '雞雞',
#   '後',
#   '說',
#   '好',
#   '想',
#   '懶覺',
#   '博物館',
#   '參觀',
#   '雞雞',
#   '喔',
#   '知道',
#   '哪裡',
#   '懶覺',
#   '博物館',
#   '請問',
#   'Ecup',
#   '給窩',
#   '一點',
#   '意見',
#   'PTT',
#   'Perfume',
#   'desu',
#   'あ',
#   'ち',
#   'ゃ',
#   'ん',
#   'か',
#   'し',
#   'ゆ',
#   'か',
#   'の',
#   'っ',
#   'ち',
#   'ψ',
#   'hsnufp',
#   '___',
#   '____',
#   '兩個',
#   '齁',
#   '窩還',
#   '不想',
#   '睡',
#   '有點',
#   '奇怪',
#   '說',
#   '想',
#   '動物',
#   '覽',
#   '有點',
#   '擔心'],
#  ['北韓',
#   '已經',
#   '嗆',
#   '聲',
#   '八月',
#   '中會射',
#   '四顆',
#   '飛彈',
#   '彈著點',
#   '關島',
#   '附近',
#   '海域',
#   '飛彈',
#   '路徑',
#   '日本',
#   '本土',
#   '試想',
#   '飛彈',
#   '國土',
#   '飛過',
#   '根本',
#   '眼裡',
#   '日本',
#   '採取',
#   '措施',
#   '是否',
#   '啟動',
#   '飛彈',
#   '防禦',
#   '系統',
#   '北韓',
#   '飛彈',
#   '下來'],
#  ['台北',
#   '學生',
#   '懂',
#   '中南部',
#   '學生',
#   '來說',
#   '大學',
#   '台北',
#   '唸書',
#   '一個',
#   '字',
#   '邱',
#   '現在',
#   '回家',
#   '還會',
#   '聽到',
#   '爸爸',
#   '街坊鄰居',
#   '炫耀',
#   '兒子',
#   '台北',
#   '鄧來',
#   '欸',
#   '台北',
#   '唸書',
#   '真的',
#   '比較',
#   '厲害',
#   '聽',
#   '比較',
#   '厲害',
#   '有沒有',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'iPhone'],
#  ['乳題', '大學', '科系', '千百種', '好系', '天堂', '糞系', '進', '糞坑', '系才', '糞系', '中', '霸主'],
#  ['本魯',
#   '預計',
#   '開學',
#   '後',
#   '一週',
#   '日本',
#   '玩',
#   '開學',
#   '後',
#   '一週',
#   '不想',
#   '肥宅',
#   '擠',
#   '同班',
#   '飛機',
#   '臭味',
#   '臭死',
#   '有錢',
#   '爺',
#   '下',
#   '要來',
#   '決定',
#   '哪家',
#   '航空',
#   '華航',
#   '換',
#   '制服',
#   '後',
#   'low',
#   '掉',
#   '長榮',
#   '制服',
#   '不錯',
#   '曲線',
#   '背後',
#   '優',
#   '香草',
#   '太像',
#   '百事',
#   '達',
#   '配色',
#   '老虎',
#   '制服',
#   '包覆',
#   '性',
#   '不錯',
#   '全日',
#   '顏色',
#   '太喪',
#   '捷星',
#   '黑橘',
#   '配色',
#   '做',
#   '高鐵',
#   '日本',
#   '空姐',
#   '領巾',
#   '很大',
#   '一坨',
#   '樂桃',
#   '顏色',
#   '不錯',
#   '拆',
#   '禮物',
#   '感覺',
#   '國泰',
#   '太像',
#   '銀行',
#   '櫃檯',
#   '鄉民',
#   '會選',
#   '哪家',
#   '航空'],
#  ['八卦',
#   '版',
#   '六星',
#   '肥將',
#   '安安',
#   '小肥',
#   '新訓',
#   '用餐',
#   '時',
#   '一定',
#   '有人',
#   '掉',
#   '筷子',
#   '班長',
#   '聽到',
#   '掉',
#   '筷聲',
#   '好像',
#   '中邪',
#   '馬上開',
#   '噴',
#   '還要',
#   '全營',
#   '面',
#   '大喊',
#   '筷子',
#   '我愛你',
#   '十遍',
#   '感覺',
#   '好',
#   '小學生',
#   '不禁',
#   '想著',
#   '真的',
#   '捍衛',
#   '國家',
#   '軍人',
#   '有沒有',
#   '新訓',
#   '掉',
#   '筷子',
#   '八卦',
#   '知道',
#   '營長',
#   '掉',
#   '筷子',
#   '有沒有',
#   '人敢噴',
#   '撿',
#   '意思',
#   '嘻嘻'],
#  ['子瑜',
#   'twice',
#   '實勢',
#   'twice',
#   '支柱',
#   'twice',
#   '少女時代',
#   '並列',
#   '韓國',
#   '第一',
#   '女團',
#   '子瑜',
#   '很大',
#   '功勞',
#   '人',
#   '說子',
#   '瑜',
#   '本錢',
#   '單飛',
#   '說',
#   '事實',
#   '討厭',
#   '子瑜'],
#  ['有沒有',
#   '那種',
#   '嬰兒',
#   '肥',
#   '卻',
#   '娃娃臉',
#   '娃娃臉',
#   '嬰兒',
#   '肥',
#   '共存',
#   '鄧紫棋',
#   'Selina',
#   '徐佳瑩',
#   '分不太'],
#  ['反核',
#   '覺青',
#   '現在',
#   '最強',
#   '招式',
#   '燃料',
#   '棒放',
#   '你家',
#   '肥宅',
#   '覺得',
#   '燃料',
#   '棒',
#   '放到',
#   '國家',
#   '好',
#   '一定',
#   '缺錢',
#   '國家',
#   '台灣塞',
#   '錢給',
#   '買',
#   '國家',
#   '空間',
#   '放',
#   '燃料',
#   '棒',
#   '問題',
#   '解決',
#   '核電',
#   '重啟',
#   '台灣',
#   '缺點',
#   '問題',
#   '解決',
#   '冷氣',
#   '吹',
#   '台積電',
#   '出走',
#   '繼續',
#   '救台灣',
#   '二來',
#   '買賣',
#   '貪污',
#   '空間',
#   '政客',
#   '賺頭',
#   '現在',
#   '沒糖',
#   '吃',
#   '送',
#   '錢',
#   '邦交國',
#   '搞不好',
#   '幾個',
#   '雙贏',
#   '核電',
#   '燃料',
#   '棒',
#   '國家',
#   '買',
#   '空間',
#   '放',
#   '好',
#   '有沒有',
#   '相關',
#   '八卦'],
#  ['本宅',
#   '今日',
#   '久違',
#   '健身房',
#   '運動',
#   '剛剛',
#   '發生',
#   '一件',
#   '令本宅',
#   '驚訝',
#   '事情',
#   '本宅',
#   '喝水',
#   '休息',
#   '時',
#   '無意間',
#   '看到',
#   '旁邊',
#   '做',
#   '一個',
#   '器材',
#   '人',
#   '行為',
#   '奇怪',
#   '手機',
#   '一直',
#   '呈現',
#   '拍照',
#   '模式',
#   '本宅',
#   '不以',
#   '為意',
#   '之後',
#   '發現',
#   '根本',
#   '無意',
#   '運動',
#   '臉上',
#   '神情',
#   '奇怪',
#   '原來',
#   '一直',
#   '偷拍',
#   '斜對面',
#   '幾個',
#   '很壯',
#   '男生',
#   '發現',
#   '怪異',
#   '假裝',
#   '運動',
#   '音量',
#   '鍵',
#   '拍照',
#   '有沒有',
#   '健身房',
#   '旁邊',
#   '男生',
#   '卦'],
#  ['相信',
#   '人',
#   '已經',
#   '知道',
#   '英文版',
#   'PTT',
#   'Reddit',
#   '日文版',
#   '好像',
#   '有沒有',
#   '中國',
#   '版',
#   'PTT',
#   '貼',
#   '算是',
#   '之前',
#   '逛',
#   '感覺',
#   '比較',
#   'Dcard',
#   '那貼',
#   '吧裡',
#   '八卦',
#   '版',
#   '一個',
#   '咧',
#   '好奇',
#   '想',
#   '逛逛',
#   '天涯',
#   '水木',
#   '咧',
#   '只好',
#   '逛',
#   '囉'],
#  ['日本',
#   '早期',
#   'P2P',
#   '神器',
#   'Share',
#   '又稱',
#   '雪兒',
#   '笑臉',
#   '男',
#   '我國',
#   '高中',
#   '抓',
#   '日本',
#   '稀有',
#   '資源',
#   '現在',
#   '好像',
#   '已經',
#   '沒落',
#   '有沒有',
#   '日本',
#   'P2P',
#   '神器',
#   'Share',
#   '八卦'],
#  ['乳題',
#   '好像',
#   '體驗',
#   '過爆',
#   'XX',
#   '感覺',
#   '之前',
#   '玩楓',
#   '之谷',
#   '有人',
#   '收負',
#   '名聲',
#   '有沒有',
#   '感覺',
#   '卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'X00DDA',
#   '平常',
#   '懶得',
#   '貼',
#   '新聞',
#   '哭哭',
#   '稜',
#   '森好',
#   '難',
#   'XOXOXOXO',
#   '平衡',
#   '壞'],
#  ['最近',
#   '宋',
#   '淒厲',
#   '重出江湖',
#   '還出',
#   '本書',
#   '說',
#   '用書',
#   '身體',
#   '住',
#   '用書',
#   '隔空',
#   '推倒',
#   '推倒',
#   '妹妹',
#   '倒',
#   '說',
#   '佛性',
#   '不夠',
#   '看不見',
#   '分身',
#   '叫做',
#   '悟性',
#   '未開',
#   '有沒有',
#   '人',
#   '體驗',
#   '定身法',
#   '威力',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Samsung',
#   'SMG720AX'],
#  ['本魯邊',
#   '看著',
#   '女子',
#   '團體',
#   '音樂',
#   '影片',
#   '看到',
#   '那蜜',
#   '大腿',
#   '好奇',
#   '女生',
#   '大腿',
#   '摸起來',
#   '感覺',
#   '有沒有',
#   '八卦'],
#  ['品牌',
#   '電腦',
#   '主打',
#   '方便',
#   '機子',
#   '問題',
#   '保固',
#   '免費',
#   '幫',
#   '處理',
#   '好',
#   '不用',
#   '還要',
#   '除錯',
#   '浪費',
#   '一堆',
#   '時間',
#   '尤其',
#   '脫離',
#   '學生',
#   '身份',
#   '後',
#   '更是',
#   '心力',
#   '搞',
#   '人',
#   '喜歡',
#   '追求',
#   'CP',
#   '值',
#   '組裝',
#   '認為',
#   '買',
#   '品牌',
#   '電腦',
#   '盤子',
#   '有沒有',
#   '人愛酸',
#   '品牌',
#   '電腦',
#   '八卦',
#   '組',
#   '電腦',
#   '樂趣',
#   '但出',
#   '問題',
#   '幹',
#   '內文',
#   '重點',
#   '組',
#   '售後',
#   '維修',
#   '大哥'],
#  ['事情',
#   '低能',
#   '卡',
#   '最近',
#   '一個',
#   '甲甲',
#   '跑',
#   '捐血',
#   '捐',
#   '就森',
#   '低能',
#   '彩虹',
#   '版討',
#   '拍',
#   '噴到',
#   '不像話',
#   '不乏',
#   '一堆',
#   '低能',
#   '同溫層',
#   '護航',
#   '那種',
#   '揪',
#   '團拒',
#   '捐血',
#   '好像',
#   '血',
#   '貴',
#   '豆頁',
#   '痛',
#   '小弟',
#   '發',
#   '一篇',
#   '甲血甲用',
#   '避免',
#   '玻璃',
#   '公平',
#   '改成',
#   '肛血',
#   '肛用',
#   '幹有',
#   '一個',
#   '學店',
#   '仔',
#   '一直',
#   '跳針',
#   '中山',
#   '戰政大',
#   '真心',
#   '求解',
#   '甲血甲用',
#   '真的',
#   '實施',
#   '破綻',
#   '攻破'],
#  ['高中',
#   '畢旅去',
#   '義大',
#   '世界',
#   '後',
#   '再',
#   '去過',
#   '國內',
#   '遊樂園',
#   '小時候',
#   '劍湖山',
#   '國',
#   '中小',
#   '畢旅',
#   '九族',
#   '文化村',
#   '麗寶',
#   '樂園',
#   '六福村',
#   '小人國',
#   '好像',
#   '補習班',
#   '去過',
#   '沒什麼',
#   '特別',
#   '憧憬',
#   '會想',
#   '說',
#   '地方',
#   '乖乖',
#   '存錢',
#   '迪士尼',
#   '上海',
#   '環球',
#   '影城',
#   '樂天',
#   '遊樂園',
#   '知道',
#   '覺得',
#   '臺灣',
#   '遊樂園',
#   '無聊',
#   '懂',
#   '人',
#   '想',
#   '門票',
#   '錢',
#   '再加',
#   '一下',
#   'HK'],
#  ['最近', '聽到', '一首歌', '年', '翻唱', '知道', '有人', '聽過', '好聽'],
#  ['餓死',
#   '抬頭',
#   '小弟',
#   '看到',
#   '一些',
#   '帥哥美女',
#   '臥蠶',
#   '像是',
#   '版上',
#   '各地',
#   '金乘',
#   '小弟',
#   '偶像',
#   '趙',
#   '麗穎',
#   '說',
#   '是不是',
#   '臥',
#   '蠶會',
#   '比較',
#   '好看',
#   '沒臥',
#   '蠶',
#   '一堆',
#   '帥哥',
#   '美女',
#   '有沒有',
#   '八卦',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['現在',
#   '人',
#   '電話號碼',
#   '記在',
#   '手機',
#   '通訊',
#   '軟體',
#   '人會',
#   '背',
#   '一堆',
#   '聯絡',
#   '親朋好友',
#   '電話號碼',
#   '前',
#   '幾天',
#   '長輩',
#   '玩',
#   '一個',
#   '遊戲',
#   '背',
#   '出還',
#   '記得',
#   '親朋好友',
#   '電話號碼',
#   '發現',
#   '老一輩',
#   '真是',
#   '強',
#   '連前',
#   '幾任',
#   '里長',
#   '電話號碼',
#   '倒背如流',
#   '真是',
#   '強到',
#   '優點',
#   '手機',
#   '不在',
#   '身邊',
#   '時',
#   '緊急',
#   '聯絡',
#   '時',
#   '方便',
#   '防止',
#   '老人',
#   '痴呆',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z017DA'],
#  ['覺得',
#   '爆',
#   '公平',
#   '耶',
#   '人',
#   '推文數',
#   '爆',
#   '推文',
#   '正好',
#   '爆',
#   '一些',
#   '歷史',
#   '廢文',
#   '終結',
#   '時間',
#   '洪流',
#   '裡',
#   '一起',
#   '發起',
#   '推',
#   '文才',
#   '爆',
#   '運動',
#   '好',
#   '鋪',
#   '好',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['本魯',
#   '甲甲',
#   '母豬',
#   '一個',
#   '善良',
#   '肥宅',
#   '最近',
#   '發現',
#   '好',
#   '玻璃心',
#   '辦法',
#   '接受',
#   '負面',
#   '批評'],
#  ['超級',
#   '歪',
#   '超級',
#   '歪',
#   '一個',
#   '台灣',
#   'youtuber',
#   '一個月',
#   '只產',
#   '一部',
#   '一部',
#   '資訊',
#   '量',
#   '超多',
#   '後面',
#   '列出',
#   '書單',
#   '不知',
#   'youtuber',
#   '平常',
#   '維生',
#   '書單',
#   '面向',
#   '廣到',
#   '不知',
#   '讀',
#   '科系',
#   '有沒有',
#   '超級',
#   '歪',
#   'supery',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Sony',
#   'D6503'],
#  ['晚上',
#   '好',
#   '一個',
#   '朋友',
#   '朋友',
#   '跟前',
#   '幾天',
#   '熱炒',
#   '店',
#   '喝酒',
#   '醉到',
#   '不省人事',
#   '隔天',
#   '床上',
#   '一絲不掛',
#   '想',
#   '請問',
#   '知道',
#   '有沒有',
#   '肛過',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z00LD'],
#  ['新聞',
#   '改成',
#   '賣',
#   '電子版',
#   '似乎',
#   '貼心',
#   '方便',
#   '粉絲',
#   '空',
#   '右手',
#   '喔',
#   '方便',
#   '收藏',
#   '一本',
#   '半夜',
#   '開賣',
#   '半個',
#   '小時',
#   '賣完',
#   '半夜',
#   '賣',
#   '電子版',
#   '不知',
#   '賣',
#   '幾本',
#   '有無',
#   '八卦'],
#  ['剛剛',
#   'youtube',
#   '收斂',
#   '遊戲王',
#   '幹',
#   '無名',
#   '龍',
#   '效果',
#   '太',
#   '唬爛',
#   '融合',
#   '效果',
#   '愛波',
#   '說了算',
#   '根本',
#   '作弊',
#   '狗',
#   '明明',
#   '名字',
#   '亂叫',
#   '一通',
#   '有沒有',
#   '無名',
#   '龍',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'iPhone'],
#  ['囧',
#   '哞',
#   '辦',
#   'ㄍ',
#   '女森',
#   '網友',
#   '一直',
#   '要約',
#   '倫家',
#   '明明',
#   '矮矮胖胖',
#   'ㄉ',
#   '體重',
#   '破',
#   '兩百',
#   '身高',
#   'ㄧ',
#   '米',
#   '倫家',
#   '木訥',
#   '想',
#   '找',
#   'ㄘ',
#   '飯飯',
#   'ㄇ',
#   '倫家',
#   '認識',
#   '男女生',
#   '比例',
#   '迪卡',
#   '女生',
#   '卡友',
#   'ㄍ',
#   '不太敢',
#   '女森',
#   '說',
#   '辣',
#   '我會',
#   '害羞',
#   '羞內',
#   '宅宅',
#   '低頭',
#   '不敢',
#   '女森',
#   '狂',
#   '抬頭',
#   '仰望',
#   '陽光',
#   '素',
#   'ㄅ',
#   '女森吶',
#   '請',
#   '交交',
#   '偶好',
#   '想',
#   'ㄘ',
#   '辣辣',
#   'ㄉ',
#   '麵',
#   '麵',
#   '倫家',
#   'ㄘ',
#   '飯飯'],
#  ['拜倫',
#   '帥',
#   '正太',
#   '好像',
#   '長',
#   '歪',
#   '惹',
#   '照片',
#   '還會',
#   '聯想',
#   '王思聰',
#   '那種',
#   '目空一切',
#   '表情',
#   '有錢人',
#   '小孩',
#   '最終',
#   '氣質',
#   '髮型',
#   '關係',
#   '拜倫',
#   '長',
#   '歪'],
#  ['從小到大',
#   '人生',
#   '越來越',
#   '痛苦',
#   '越來越',
#   '難',
#   '活著',
#   '真的',
#   '好',
#   '痛苦',
#   '勇氣',
#   '死',
#   '感覺',
#   '好痛',
#   '好',
#   '想',
#   '逃避',
#   '直接',
#   '逃跑',
#   '逃跑',
#   '難堪',
#   '準備',
#   '開天窗',
#   '倒數',
#   '明天',
#   '就要',
#   '開天窗',
#   '好',
#   '想',
#   '死',
#   '一死',
#   '種',
#   '人生',
#   '越來越',
#   '難',
#   '轉',
#   '教教'],
#  ['看到',
#   '那群',
#   '固定',
#   'id',
#   '蓋樓',
#   'ptt',
#   '辦法',
#   '巴哈',
#   '蓋',
#   '幾千幾萬',
#   '樓',
#   '肥宅',
#   '推',
#   '謝謝'],
#  ['好',
#   '窩',
#   '喜歡',
#   '喝',
#   '香菇',
#   '雞湯',
#   '如題',
#   '剛剛',
#   '小學',
#   '照片',
#   '一張',
#   '玩',
#   '武力',
#   'CS',
#   '這款',
#   '遊戲',
#   '突然',
#   '想起',
#   '這款',
#   '遊戲',
#   '當時',
#   '超多人',
#   '玩',
#   '想',
#   '一直',
#   '刷',
#   '一直',
#   '刷刷',
#   '軍階',
#   '元帥',
#   '他媽的',
#   '每次',
#   '直升機',
#   '轟炸',
#   '剛剛',
#   'google',
#   '下載點',
#   '重溫',
#   '一下',
#   '小學',
#   '回憶',
#   '一點',
#   '沒變',
#   '刷',
#   '不到',
#   '元帥',
#   '想',
#   '問宅',
#   '宅們',
#   '刷',
#   '元帥',
#   '過嗎',
#   '乾五',
#   '八卦',
#   '散彈',
#   '覺得',
#   '不用',
#   '瞄準',
#   '比較',
#   '好',
#   '殺'],
#  ['肥宅',
#   '晚安',
#   '前',
#   '幾個',
#   '月',
#   '我家',
#   '附近',
#   '上達',
#   '倒',
#   '再',
#   '一陣子',
#   '連我',
#   '阿嬤家',
#   '附近',
#   '開',
#   '多年',
#   '展書堂',
#   '樣稱',
#   '不住',
#   '倒',
#   '惹',
#   '不爭氣',
#   '閱讀',
#   '習慣',
#   '改變',
#   '造成'],
#  ['幾天',
#   '全',
#   '台',
#   '各地',
#   '公務',
#   '機關',
#   '共體',
#   '時艱',
#   '關',
#   '冷氣',
#   '守護',
#   '限電',
#   '真是太',
#   '感人',
#   '小弟',
#   '公務員',
#   '卻',
#   '體認',
#   '大大的',
#   '辛勞',
#   '小弟',
#   '工作',
#   '進',
#   '倉庫',
#   '理貨',
#   '夏天',
#   '只',
#   '有出',
#   '太陽',
#   '白天',
#   '進',
#   '密不透風',
#   '倉庫',
#   '小時',
#   '上衣',
#   '全濕',
#   '想',
#   '窗戶',
#   '辦',
#   '公室',
#   '應該',
#   '同樣',
#   '概念',
#   '好',
#   '今天',
#   '禁令',
#   '解除',
#   '冷氣',
#   '吹',
#   '出現',
#   '一個',
#   '新',
#   '問題',
#   '困擾',
#   '原以',
#   '今天',
#   '用電量',
#   '暴增',
#   '減少',
#   '是不是',
#   '解禁',
#   '說法',
#   '原因',
#   '不敢',
#   '開',
#   '冷氣',
#   '台電',
#   '網站',
#   '突然',
#   '修正',
#   'bug',
#   '發現',
#   '以前',
#   '算錯'],
#  ['學校',
#   '附近',
#   '看到',
#   '一群',
#   '人',
#   '阿北',
#   '類似',
#   '板上',
#   '肥宅',
#   '走進',
#   '一看',
#   '抓',
#   '寶',
#   '已經',
#   '過氣',
#   '有卦'],
#  ['看到',
#   '前面',
#   '有人',
#   '討論',
#   'AI',
#   '星海',
#   '打贏',
#   '人類',
#   '曉得',
#   'AI',
#   '作弊',
#   '情況',
#   '下',
#   '世紀',
#   '最難',
#   '電腦',
#   '似乎',
#   '資源',
#   '一對一',
#   '打得贏',
#   '人類',
#   '世界冠軍'],
#  ['東離',
#   '劍',
#   '遊記',
#   '粉',
#   '專上',
#   '看到',
#   '新',
#   '漫畫',
#   '動漫展',
#   '打算',
#   '明天',
#   '買',
#   '這是',
#   '第一次',
#   '參加',
#   '動漫展',
#   '之前',
#   '去過',
#   '書展',
#   '動漫展',
#   '書展',
#   '會差',
#   '第一次',
#   '參加',
#   '有沒有',
#   '注意事項',
#   '說真的'],
#  ['題', '老伯', '家', '籃框', '變好', '高', '老伯', '魔力', '卦', '跨哩', '__', '小', '覺得'],
#  ['一定',
#   '納粹',
#   '相同',
#   '理念',
#   '國家',
#   '共產',
#   '法西斯',
#   '有沒有',
#   '年',
#   '之內',
#   '出現',
#   '一個',
#   '強國',
#   '爾且',
#   '侵略',
#   '侵占',
#   '土地',
#   '知道',
#   '美國',
#   '目前',
#   '應該',
#   '直接',
#   '派兵',
#   '侵略',
#   '地方',
#   '試圖',
#   '該地',
#   '變成',
#   '領土',
#   '不算',
#   '有沒有',
#   '出現',
#   '一個',
#   '國家',
#   '機會',
#   '軍力',
#   '強佔',
#   '土地',
#   '成功',
#   '鴨',
#   '鴨',
#   '卡卡',
#   '正常',
#   '推文',
#   'Gossiping'],
#  ['上台',
#   '政治',
#   '開心',
#   '難過',
#   '政治系',
#   '幹嘛',
#   '先',
#   '台大',
#   '找',
#   '男朋友',
#   '養',
#   'ps',
#   '幫別人',
#   '問',
#   '喔',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'D826y'],
#  ['原本',
#   'X',
#   '記',
#   '麻',
#   '糬',
#   '有名',
#   '伴',
#   '手禮',
#   '今天',
#   '新聞',
#   '報',
#   '特報',
#   '根本',
#   '免費',
#   '廣告',
#   '幾天',
#   '曉得',
#   '銷售量',
#   '大增',
#   'X',
#   '記',
#   '麻',
#   '糬',
#   '這次',
#   'F16',
#   '最大',
#   '贏家',
#   '有沒有',
#   '相關',
#   '八卦',
#   '推',
#   'Israfil',
#   '慘',
#   '推',
#   'wyvernlee',
#   '嗆',
#   '五樓',
#   '嗆夠',
#   '推',
#   'maple0425',
#   '幫五樓',
#   'QQ',
#   '推',
#   'meowchen',
#   '樓下',
#   '幫轉',
#   '邊緣',
#   '人板',
#   'Fanchiang',
#   '早點',
#   '死',
#   '一死'],
#  ['假設', '有個', '魯蛇', '找', '工作', '只能', '領', '最低', '時薪', '最低', '底薪', '比較', '好'],
#  ['乳題',
#   '本肥宅',
#   '最近',
#   '滑',
#   'FB',
#   '偷看',
#   '正妹',
#   '照片',
#   '發現',
#   '突然',
#   '通知',
#   '本肥',
#   'J',
#   'Der',
#   '奇怪',
#   '姨',
#   '朋友',
#   '妹油',
#   '什摸會',
#   '通知',
#   '本肥',
#   '聚精會神',
#   '一看',
#   '笑靨',
#   '如花',
#   '正妹',
#   '送',
#   '交友',
#   '邀請',
#   '想作',
#   '本肥',
#   '捧',
#   '油',
#   '本肥',
#   '毫不猶豫',
#   '加',
#   '本肥',
#   '太',
#   '害羞',
#   '不敢',
#   '訊息',
#   '給新',
#   '正妹',
#   '捧',
#   '油',
#   '只能',
#   '默默',
#   '心中',
#   '意淫',
#   '隔',
#   '一天',
#   '一個',
#   '正妹',
#   '想',
#   '當本肥',
#   '捧',
#   '油',
#   '本肥',
#   '猶豫',
#   '太',
#   '花心',
#   '正妹',
#   '笑容',
#   '融化',
#   '本肥',
#   '油膩',
#   '心',
#   '本肥',
#   '只好',
#   '再加',
#   '好友',
#   '現在',
#   '本肥',
#   '正妹',
#   '捧',
#   '油',
#   '兩天',
#   '本肥',
#   '再次',
#   '收到',
#   '交友',
#   '邀請',
#   '正妹',
#   '本肥',
#   '真的',
#   'J',
#   'DER',
#   '太夯',
#   '肚子',
#   '驕傲',
#   '挺起來',
#   '懷孕',
#   '驕傲',
#   '正妹',
#   '想',
#   '加本肥',
#   '好友',
#   '八卦',
#   'PS',
#   '正妹',
#   '外國',
#   '正妹',
#   '名字',
#   '好長',
#   '一堆',
#   '字母',
#   '念',
#   '相信',
#   '一定',
#   '靈魂',
#   '溝通',
#   '搜魯妹',
#   '特',
#   '問君',
#   '幾多',
#   '魯',
#   '一條',
#   '魯蛇',
#   '向東',
#   '蠕',
#   '問君',
#   '何能爾',
#   '臉醜',
#   '人',
#   '自魯'],
#  ['反核',
#   '人士',
#   '最愛',
#   '妖',
#   '核電廠',
#   '蓋',
#   '你家',
#   '好不好',
#   '說好',
#   '核廢料',
#   '放',
#   '我家',
#   '好不好',
#   'ok',
#   '放在',
#   '地下室',
#   '就行了',
#   '火力發電',
#   '燒完',
#   '渣',
#   '渣',
#   '放射性物質',
#   '放',
#   '你家',
#   '現在',
#   '搬',
#   '龍井',
#   '住',
#   '試',
#   '看看',
#   '拎',
#   '北',
#   '去核',
#   '三廠',
#   '養老',
#   '認識',
#   '一些',
#   '老頭',
#   '在裡',
#   '面過',
#   '爽爽',
#   '全部',
#   '電腦',
#   '監控',
#   '沒事',
#   '做',
#   '換',
#   '燃料',
#   '棒',
#   '人去換',
#   '火力發電',
#   '燒',
#   '重油',
#   '燒煤',
#   '看看',
#   '一個',
#   '人',
#   '一生',
#   '咪咪',
#   '燃料',
#   '棒',
#   '搞定',
#   '火力發電',
#   '要燒',
#   '幾公斤',
#   '反核',
#   '人士',
#   '冷氣',
#   '開',
#   '爽爽',
#   '交換',
#   '住',
#   '台',
#   '中要',
#   '來試',
#   '看看',
#   '我住',
#   '靠近',
#   '東海',
#   '住',
#   '沙鹿',
#   '龍井',
#   '你家',
#   '哪條',
#   '路上',
#   '拍張',
#   '身分證',
#   '一堆',
#   '嘴',
#   '砲',
#   '去過',
#   '台',
#   '中',
#   '龍井',
#   '核電廠',
#   '根本',
#   '養老',
#   '天堂',
#   '轉機',
#   '老頭',
#   '必選',
#   '鍵盤',
#   'IP',
#   '喔',
#   '拍',
#   '路牌',
#   'OK',
#   '查',
#   '別進',
#   '家族',
#   '我講',
#   '認真',
#   '火力發電',
#   '垃圾',
#   '擔心',
#   '地方',
#   '放',
#   '接收',
#   '樂意',
#   '接收',
#   '核廢料',
#   '等價交換',
#   '覺得',
#   '少廢話',
#   '找',
#   '電廠',
#   '談',
#   '家',
#   '火力發電',
#   '談起',
#   'OK',
#   '燃料',
#   '棒',
#   '來說',
#   '經濟',
#   '價值',
#   '願意',
#   '電廠',
#   '談請',
#   '給我',
#   '火力發電廠',
#   '談',
#   '請',
#   '送',
#   '灰燼'],
#  ['人',
#   '小花',
#   '黏上去',
#   '請問',
#   '一下',
#   '有人',
#   '黏過',
#   '真的',
#   '黏',
#   '一起',
#   '整個',
#   '視窗',
#   '黏得',
#   '滿滿的',
#   '照片',
#   '看不到',
#   '有人',
#   '經驗',
#   '謝謝'],
#  ['常上',
#   '新聞',
#   '龍捲風',
#   '感覺',
#   '斯文人',
#   '剃',
#   '鬍子',
#   '節目',
#   '個人感覺',
#   '真的',
#   'style',
#   '掛著',
#   '生物',
#   '老師',
#   '名稱',
#   '節目',
#   '好像',
#   '講過',
#   '生物',
#   '領域',
#   '東西',
#   '北一女',
#   '生物',
#   '老師',
#   '八卦'],
#  ['前',
#   '陣子',
#   '小魯',
#   '路過',
#   '台',
#   '中',
#   '火車站',
#   '附近',
#   '酒廠',
#   '逛',
#   '驚為',
#   '天人',
#   '潮度',
#   '似乎',
#   '突破',
#   '高雄駁',
#   '文青度',
#   '破',
#   '錶',
#   '出水',
#   '惹',
#   '好像',
#   '人潮',
#   '有沒有',
#   '這方面',
#   '八卦'],
#  ['豪',
#   '小弟',
#   '今天',
#   '超市',
#   '買',
#   '一盒',
#   '衛生棉',
#   '回家',
#   '研究',
#   '理解',
#   '沒錯',
#   '黏在',
#   '內褲',
#   '接',
#   '藍色',
#   '經血',
#   '小弟',
#   '轉念',
#   '一想',
#   '尿布',
#   '只',
#   '是從',
#   '接尿',
#   '改成',
#   '接血',
#   '實際上',
#   '有沒有',
#   '衛生棉',
#   '尿布',
#   '變形',
#   '八卦',
#   '阿是',
#   '買',
#   '逆',
#   '好奇心',
#   '強阿',
#   '知道',
#   '黏',
#   '內褲',
#   '黏到',
#   '毛',
#   '超痛'],
#  ['OL', '下班', '後', '穿', '一整天', '絲襪', '發酵', '一整天', '廚餘', '比較', '嘻嘻'],
#  ['蹦',
#   '啾',
#   '妹魯喜',
#   '波',
#   '那佩梯',
#   'KTV',
#   '唱歌',
#   '現代',
#   '平常',
#   '休閒活動',
#   '慎選',
#   '同伴',
#   '重要',
#   '選對',
#   '愉快',
#   '消磨',
#   '時間',
#   '選錯',
#   '時間',
#   '久',
#   '最',
#   '喜歡',
#   '一種',
#   '人去',
#   '唱歌',
#   '一直',
#   '搶麥',
#   '人',
#   '編園',
#   '分姆肥宅',
#   '喝',
#   '唱',
#   '結帳',
#   '前',
#   '先閃',
#   '唱歌',
#   '難聽'],
#  ['自由',
#   '時報',
#   '棄獨',
#   '擁蔡',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '自由',
#   '時報',
#   '擁蔡',
#   '壓扁',
#   '變',
#   '西瓜',
#   '派',
#   '人',
#   '統獨',
#   '人士',
#   '以為',
#   '自由',
#   '時報',
#   '主張',
#   '台獨',
#   '現在',
#   '實際',
#   '月',
#   '日',
#   '星期四',
#   '新台灣',
#   '國策',
#   '智庫',
#   '公布',
#   '年',
#   '總統',
#   '選舉',
#   '民調',
#   '支持',
#   '台南',
#   '市長',
#   '賴清德',
#   '參選',
#   '高於',
#   '蔡',
#   '英文',
#   '總統',
#   '總統府',
#   '資政',
#   '辜寬敏則',
#   '說',
#   '蔡',
#   '總統',
#   '做',
#   '年',
#   '好',
#   '下次',
#   '最好',
#   '賴清德',
#   '賴清德則',
#   '說',
#   '無意',
#   '選',
#   '總統',
#   '持續',
#   '議題',
#   '陷',
#   '不義',
#   '總統府',
#   '發言人',
#   '林鶴明則',
#   '表示',
#   '民調',
#   '完成',
#   '重大',
#   '改革',
#   '當務之急',
#   '年',
#   '總統大選',
#   '議題',
#   '月',
#   '日新',
#   '台灣',
#   '國策',
#   '智庫',
#   '公布',
#   '民調',
#   '後',
#   '各家',
#   '媒體',
#   '立即',
#   '大肆',
#   '報導',
#   '平面',
#   '報紙',
#   '媒體',
#   '則以',
#   '即時新聞',
#   '刊',
#   '電子版',
#   '自由',
#   '時報',
#   '例外',
#   '奇怪的是',
#   '第二天',
#   '月',
#   '日',
#   '報紙',
#   '版面',
#   '新聞',
#   '號稱',
#   '第一',
#   '大報',
#   '自由',
#   '時報',
#   '卻',
#   '不刊',
#   '消音',
#   '這才',
#   '新聞',
#   '賴清德',
#   '親中',
#   '愛台',
#   '言論',
#   '出現',
#   '後',
#   '投機',
#   '個性',
#   '暴露無遺',
#   '親中',
#   '愛台',
#   '愛',
#   '投機',
#   '判斷',
#   '自由',
#   '時報',
#   '消音',
#   '因賴',
#   '清德親',
#   '中愛台',
#   '愛',
#   '投機',
#   '自由',
#   '時報',
#   '擁護',
#   '蔡',
#   '英文',
#   '故對',
#   '蔡',
#   '英文',
#   '不利',
#   '新聞',
#   '報紙',
#   '版面',
#   '則不刊',
#   '只能',
#   '出現',
#   '極少',
#   '人',
#   '注意',
#   '前一天',
#   '電子版',
#   '即時新聞',
#   '自由',
#   '時報',
#   '棄台',
#   '擁護',
#   '蔡',
#   '英文',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '一件',
#   '事情',
#   '得到',
#   '相同',
#   '判斷',
#   '月',
#   '日',
#   '媒體',
#   '報導',
#   '阿扁',
#   '總統',
#   '質疑',
#   '高院',
#   '法官',
#   '曾德水',
#   '利用',
#   '媒體',
#   '放',
#   '話',
#   '心證',
#   '偏頗',
#   '公正',
#   '之虞',
#   '上週五',
#   '聲請',
#   '法官',
#   '曾德水',
#   '迴避',
#   '已由林',
#   '孟宜',
#   '法官',
#   '審理',
#   '近日',
#   '做出',
#   '裁定',
#   '民主',
#   '法治',
#   '國家',
#   '人',
#   '質疑',
#   '法官',
#   '偏頗',
#   '公正',
#   '一件',
#   '一個',
#   '前',
#   '總統',
#   '涉及',
#   '違反',
#   '司法程序',
#   '正義',
#   '特赦',
#   '議題',
#   '阿扁',
#   '案件',
#   '月',
#   '日',
#   '媒體',
#   '報導',
#   '或刊',
#   '電子版',
#   '即時新聞',
#   '第二天',
#   '月',
#   '日',
#   '報紙',
#   '版面',
#   '標題',
#   '號稱',
#   '第一',
#   '大報',
#   '自由',
#   '時報',
#   '不刊',
#   '消音',
#   '更好',
#   '判斷',
#   '自由',
#   '時報',
#   '站',
#   '擁護',
#   '蔡',
#   '英文',
#   '特赦',
#   '前',
#   '總統',
#   '陳水扁',
#   '立場',
#   '封殺',
#   '引起',
#   '特赦',
#   '議題',
#   '新聞',
#   '自由',
#   '時報',
#   '棄台',
#   '擁護',
#   '蔡',
#   '英文',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '擁護',
#   '蔡',
#   '英文',
#   '壓迫',
#   '陳水扁',
#   '變',
#   '西瓜',
#   '派',
#   '結合',
#   '頭腦清楚',
#   '文明',
#   '法治',
#   '有志一同',
#   '打倒',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '享受',
#   '權力',
#   '蔡',
#   '英文',
#   '民進黨',
#   '取得',
#   '政權',
#   '建立',
#   'Republic',
#   'of',
#   'Taiwan',
#   '台灣',
#   '民國',
#   '歡迎',
#   '轉載',
#   '傳送',
#   '謝謝',
#   '祝',
#   '萬事如意',
#   '平安',
#   '健康',
#   'Thanks',
#   'and',
#   'Best',
#   'Regards',
#   '陳',
#   '永昌',
#   'Yong',
#   'C',
#   'Chen',
#   'PhD',
#   '英國',
#   'QS',
#   '世界',
#   '大學排名',
#   'WUR',
#   '中心',
#   '評鑑',
#   '委員',
#   '美國',
#   '賓卅',
#   '大學',
#   '華頓',
#   'Wharton',
#   '商學院',
#   '企管',
#   '行銷',
#   '博士',
#   '美國',
#   '哈佛',
#   'Harvard',
#   '大學',
#   '商學院',
#   '企管',
#   '學者',
#   '研究',
#   '國際',
#   '名錄',
#   '美國',
#   'Marquis',
#   '世界',
#   '名人錄',
#   'Whos',
#   'Who',
#   'in',
#   'the',
#   'World',
#   '瑞士',
#   '洛桑',
#   '國際',
#   '管理',
#   '研究院',
#   'IMD',
#   '世界',
#   '競爭力',
#   '中心',
#   '評鑑',
#   '專家',
#   '沙烏地阿',
#   '拉伯',
#   '法',
#   '德國',
#   '王',
#   'King',
#   'Fahd',
#   '石油',
#   '礦產',
#   '大學',
#   '計畫',
#   '評審委員'],
#  ['下',
#   '對岸',
#   '中國',
#   '有嘻哈',
#   '每個',
#   '人',
#   '打扮',
#   '一副',
#   '潮到',
#   '水',
#   '刺青',
#   '重點',
#   '講話',
#   '方式',
#   '個個',
#   '氣勢凌人',
#   '自信',
#   '度',
#   '滿百',
#   '放到',
#   '校園',
#   '是號',
#   '領袖',
#   '級',
#   '人物',
#   '太',
#   '囂張',
#   '人',
#   '一天',
#   '三餐',
#   '開扁',
#   '人物',
#   '撇開',
#   '有無',
#   '饒舌',
#   '實力',
#   '裝逼',
#   '耍',
#   '屌',
#   '外',
#   '饒舌',
#   '必要',
#   '包裝'],
#  ['憤怒',
#   '鳥',
#   '相信',
#   '記得',
#   '手遊',
#   '智慧型',
#   '手機',
#   '稱霸',
#   '續作',
#   '還出',
#   '電影',
#   '漸漸',
#   '淡出',
#   '有沒有',
#   '憤怒',
#   '鳥去',
#   '八卦'],
#  ['XDDD',
#   'D',
#   '罩杯',
#   '正妹',
#   '女友',
#   '啪',
#   '感覺',
#   '職業',
#   '空姐',
#   '櫃姐',
#   '這種',
#   '正妹',
#   '女友',
#   '小魯',
#   '真心',
#   '想要',
#   '問',
#   '一下',
#   '喔',
#   '這種',
#   'D',
#   '罩杯',
#   '高挑',
#   '外送',
#   '茶',
#   '小時',
#   '一萬塊',
#   '錢',
#   '正確',
#   '行情',
#   '分享',
#   '一下',
#   '謝謝'],
#  ['小妹',
#   '之前',
#   '煮',
#   '麵',
#   '滑倒',
#   '燙',
#   '水泡',
#   '消',
#   '剩下',
#   '一塊',
#   '很大',
#   '疤',
#   '之前',
#   '手賤',
#   '皮',
#   '扯破',
#   '現在',
#   '傷口',
#   '超級',
#   '癢',
#   '抓',
#   '好',
#   '蘇服',
#   '好像',
#   '不太好',
#   '放',
#   '毛巾',
#   '加點',
#   '冰塊',
#   '敷會',
#   '舒服',
#   '一點',
#   '傷口',
#   '癢',
#   'R'],
#  ['魯哥',
#   '魯姐',
#   '好',
#   '魯弟',
#   '有個',
#   '疑問',
#   '一休',
#   '和尚',
#   '卡通版',
#   '看過',
#   '長大',
#   '後',
#   '版本',
#   '演',
#   '長大',
#   '版',
#   '成人版',
#   '想',
#   '知道',
#   '一休',
#   '家裡',
#   '有錢',
#   '引誘',
#   '一休',
#   '捉弄',
#   '一休',
#   '實際上',
#   '偷偷',
#   '暗戀',
#   '一休',
#   '千金',
#   '何麗心',
#   '姑娘',
#   '窮',
#   '農夫',
#   '孫女',
#   '一休',
#   '真',
#   '青梅竹馬',
#   '大方',
#   '承認',
#   '喜歡',
#   '一休',
#   '窮',
#   '身材',
#   '沒麗心',
#   '好',
#   '小妍妹',
#   '一個',
#   '安國',
#   '寺',
#   '變成',
#   '大廟',
#   '千金',
#   '一個',
#   '遇到',
#   '真',
#   '心愛',
#   '人',
#   '一休',
#   '最後',
#   '選',
#   '有沒有',
#   '八卦',
#   '答案',
#   '接受',
#   '公主',
#   '戲分',
#   '太少',
#   '結局',
#   '變成',
#   '路人',
#   '公主',
#   '粉絲',
#   '批成',
#   '糞作',
#   '耶',
#   '美化',
#   '意思',
#   '還俗',
#   '避禍',
#   '出家',
#   '日本',
#   '和尚',
#   '婚娶',
#   '變成',
#   '酒肉和尚',
#   '辜負',
#   '大師',
#   '栽培',
#   '已經',
#   '開葷',
#   '知道',
#   '有沒有',
#   '子嗣',
#   '存在',
#   '李總兵',
#   '處理',
#   '掉'],
#  ['浦島',
#   '太郎',
#   '日本',
#   '童話故事',
#   '浦島',
#   '太郎',
#   '陸地',
#   '上救',
#   '一隻',
#   '烏龜',
#   '受邀',
#   '龍宮',
#   '乙姬',
#   '結婚',
#   '幸福',
#   '厭倦',
#   '一成不變',
#   '生活',
#   '想家',
#   '提出',
#   '上岸',
#   '請求',
#   '乙姬',
#   '上岸',
#   '並給',
#   '盒子',
#   '告訴',
#   '他裡面',
#   '還說',
#   '不行',
#   '打開',
#   '喔',
#   '人',
#   '總是',
#   '好奇',
#   '浦島',
#   '太郎',
#   '回到',
#   '陸上',
#   '看到',
#   '人',
#   '事物',
#   '變',
#   '開',
#   '盒子',
#   '變',
#   '歲',
#   '老頭',
#   '乙姬給',
#   '盒子',
#   '舉動',
#   '是不是',
#   '得不到',
#   '就要',
#   '毀了',
#   '心態',
#   '還讓',
#   '變老',
#   '還吊人',
#   '胃口',
#   '給了',
#   '東西',
#   '不讓',
#   '人',
#   '打開',
#   '這是',
#   '鄉民',
#   '所說',
#   '母',
#   'X'],
#  ['欸',
#   '說',
#   '女友',
#   '幫',
#   '男森含',
#   '完',
#   '寶貝',
#   '男森',
#   '接吻',
#   '男森',
#   '間接',
#   '幫',
#   '口交',
#   '人覺',
#   '怪怪的'],
#  ['遊戲',
#   '公司',
#   '大小',
#   '眼太',
#   '嚴重',
#   '其他人',
#   '劇情',
#   '曖昧',
#   '尤其',
#   '花音',
#   '只差',
#   '主動',
#   '騎上',
#   '狼師',
#   '惹',
#   '給給',
#   '部分',
#   '幾個',
#   '臉紅',
#   '想',
#   '草草',
#   '帶過',
#   '太過分',
#   '怎看',
#   '幫給給',
#   'QQ',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意',
#   '奶',
#   '說',
#   '不夠',
#   'coser',
#   '墊太少',
#   'QQ'],
#  ['發現',
#   '公司',
#   '裡有',
#   '一個',
#   '記者',
#   '超人',
#   '長',
#   '超像',
#   '別以',
#   '戴',
#   '眼鏡',
#   '看不出來',
#   '請問',
#   '我要',
#   '注意'],
#  ['好',
#   '社會',
#   '正義',
#   '魔人',
#   '當道',
#   '手機',
#   '在手',
#   '記者',
#   '爆料',
#   '想問',
#   '今天',
#   '肥宅',
#   '真的',
#   '舒服',
#   '坐',
#   '一下',
#   '博愛',
#   '座'],
#  ['現在',
#   '網路',
#   '社群',
#   '發達',
#   '一堆',
#   '文組要',
#   '網路',
#   '生存',
#   '風向',
#   '做文章',
#   '想',
#   '美國',
#   '就讓',
#   '欲求',
#   '做起',
#   '生意',
#   '大肆',
#   '崛起',
#   '文字遊戲',
#   '好好',
#   '幹',
#   '一票',
#   '聰明',
#   '記者',
#   '訪問',
#   '時',
#   '應對',
#   '只會',
#   '敏感',
#   '問題',
#   '時',
#   '答',
#   '知道',
#   '知道',
#   '真的',
#   '越老越',
#   '掏心',
#   '掏肺',
#   '連話都',
#   '說不清楚',
#   'Jay',
#   'Chou',
#   'PTT',
#   '說',
#   '中文',
#   '問題',
#   '笑',
#   '已經',
#   '吃抗',
#   '精神藥物',
#   '年',
#   '還被',
#   '這版',
#   '水桶',
#   '超過',
#   '一年',
#   '移民',
#   '美國',
#   '拖',
#   '幾年',
#   '就當',
#   '這是',
#   '版',
#   '看不起',
#   '中'],
#  ['階級',
#   '流動',
#   '一件',
#   '勵志',
#   '事',
#   '窮',
#   '小孩',
#   '後天',
#   '努力',
#   '成為',
#   '一介',
#   '富人',
#   '這種',
#   '例子',
#   '現在',
#   '已經',
#   '越來越少',
#   '原因',
#   '原生',
#   '家庭',
#   '菁英',
#   '教育',
#   '事實上',
#   '造成',
#   '臺灣',
#   '進步',
#   '正是',
#   '菁英',
#   '教育',
#   '下',
#   '出生',
#   '家庭',
#   '那為',
#   '禮遇',
#   '想要',
#   '一些',
#   '像是',
#   '繁星',
#   '這類',
#   '骯髒',
#   '手段',
#   '原本',
#   '菁英',
#   '家庭',
#   '缺額',
#   '擠掉',
#   '知道',
#   '臺灣',
#   '進步',
#   '窮人',
#   '好處',
#   '菁英',
#   '發展',
#   '核電',
#   '臺灣人',
#   '享受',
#   '便宜',
#   '的電',
#   '吹',
#   '多免',
#   '錢',
#   '冷氣',
#   '刻意',
#   '造成',
#   '階級',
#   '流動',
#   '好'],
#  ['電影',
#   '電視劇',
#   '裡',
#   '黑道',
#   '出獄',
#   '找',
#   '法官',
#   '報仇',
#   '台灣',
#   '黑道',
#   '檢察官',
#   '起訴',
#   '法官',
#   '判刑',
#   '好像',
#   '聽到',
#   '黑道',
#   '出獄',
#   '後',
#   '找',
#   '檢察官',
#   '法官',
#   '報仇',
#   '判他',
#   '刑',
#   '法官',
#   '已經',
#   '退休',
#   '黑道',
#   '好像',
#   '想',
#   '找',
#   '報仇',
#   '有沒有',
#   '八卦'],
#  ['拉',
#   '一個',
#   '住',
#   '日本',
#   '朋友',
#   '一支',
#   '武士刀',
#   '送',
#   '當作',
#   '收藏',
#   '開鋒',
#   '查',
#   '一下',
#   '法令',
#   '東西',
#   '需要',
#   '警局',
#   '申請',
#   '持刀',
#   '證',
#   '還要',
#   '送',
#   '鑑定',
#   '幫刀',
#   '辦',
#   '一張',
#   '身分證',
#   '前科',
#   '好像',
#   '先決條件',
#   '知道',
#   '持刀',
#   '證容',
#   '容易',
#   '辦'],
#  ['每次',
#   '加油',
#   '加油站',
#   '員工',
#   '會問',
#   '加',
#   '一瓶',
#   '汽油',
#   '精',
#   '去除',
#   '積碳',
#   '比較',
#   '省油',
#   '有沒有',
#   '人加過',
#   'r',
#   '真的',
#   '比較',
#   '省油',
#   'ㄇ',
#   'u',
#   'mi',
#   'u',
#   'gua',
#   'r',
#   '廢文',
#   '產生器',
#   '小弟',
#   '多餘'],
#  ['好',
#   '自介',
#   '肥宅',
#   '女兒',
#   '老婆',
#   '肥宅',
#   '老家',
#   '附近',
#   '夜市',
#   '一攤',
#   '東山',
#   '鴨頭',
#   '還蠻',
#   '好吃',
#   '老闆娘',
#   '單親',
#   '媽媽',
#   '每天',
#   '中午',
#   '一過',
#   '擺攤',
#   '半夜',
#   '一次',
#   '肥宅',
#   '準備',
#   '買',
#   '宵夜',
#   '老闆娘',
#   '泣不成聲',
#   '說',
#   '女兒',
#   '交到',
#   '壞',
#   '朋友',
#   '跑',
#   '去當',
#   '太妹',
#   '八嘎',
#   '囧',
#   '拐走',
#   '辛辛苦苦',
#   '女兒',
#   '養',
#   '人',
#   '騙走',
#   '看到',
#   '努力',
#   '養大',
#   '孩子',
#   '變成',
#   '太妹',
#   '八卦'],
#  ['小',
#   '沒交過',
#   '女',
#   '碰友',
#   '常聽到',
#   '有人',
#   '說',
#   '交往',
#   '後',
#   '發現',
#   '不合',
#   '分手',
#   '一個',
#   '黑人',
#   '問號',
#   '一個',
#   '人',
#   '不合',
#   '交往',
#   '前',
#   '知道',
#   '相處',
#   '知道',
#   '合',
#   '不合',
#   '交往',
#   '後',
#   '現出原形',
#   '真',
#   '不知',
#   '演太好',
#   '太',
#   '無知'],
#  ['標題',
#   '今天',
#   '去逛',
#   '看到',
#   '下圖',
#   '所示',
#   '位置',
#   '西屯區',
#   '漢口路',
#   '二段',
#   '號',
#   '少',
#   '一個',
#   '看書',
#   '地方'],
#  ['台灣',
#   '當年',
#   '鄭成功',
#   '家族',
#   '統治',
#   '心想',
#   '反攻大陸',
#   '政績',
#   '當年',
#   '施琅',
#   '征戰',
#   '台灣',
#   '未果',
#   '延續',
#   '至今',
#   '東寧',
#   '國'],
#  ['鑒',
#   '社會',
#   '貧富',
#   '城鄉',
#   '差距',
#   '過大',
#   '階級',
#   '複製',
#   '狀況',
#   '嚴重',
#   '今天',
#   '立法',
#   '家庭',
#   '年收',
#   '萬',
#   '以上',
#   '小孩',
#   '念',
#   '台大',
#   '台大',
#   '只收',
#   '貧困人家',
#   '小孩',
#   '以下',
#   '貧困',
#   '小孩',
#   '翻身',
#   '成為',
#   '中流砥柱',
#   '促成',
#   '台灣',
#   '階級',
#   '流動',
#   '台大',
#   '出現',
#   '宮廟',
#   '社團',
#   '進',
#   '台大',
#   '發揚',
#   '傳統',
#   '文化',
#   '台大',
#   '變成',
#   '全國',
#   '最大',
#   '陣頭',
#   '有錢人',
#   '學校',
#   '念',
#   '只好',
#   '去念',
#   '亞洲',
#   '大學',
#   '私大',
#   '學校',
#   '倍',
#   '薪水',
#   '挖角',
#   '原',
#   '台大',
#   '教授',
#   '私立',
#   '大學',
#   '變台灣',
#   '常春藤',
#   '聯盟',
#   '一種',
#   '狀況',
#   '比較',
#   '發生'],
#  ['蹦',
#   '啾',
#   '妹魯喜',
#   '波納佩',
#   '梯',
#   '蹦蹦跳',
#   '姆',
#   '咪',
#   '剛剛',
#   '問我',
#   '喜不喜歡',
#   '吃姆',
#   '咪',
#   '零食',
#   '請問',
#   '單兵',
#   '回答',
#   '有沒有',
#   '卦',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆'],
#  ['有時',
#   '八卦',
#   '板',
#   '探探',
#   '風氣',
#   '發現',
#   '得到',
#   '回覆',
#   '功利',
#   '弱者',
#   '欺負',
#   '正常',
#   '社會',
#   '本來',
#   '公平',
#   '一些',
#   '公平',
#   '事情',
#   '合理化',
#   '法官',
#   '做出',
#   '不合理',
#   '判決',
#   '時',
#   '罵',
#   '弱者',
#   '判他',
#   '敗訴',
#   '壞人',
#   '被判',
#   '死刑',
#   '合理',
#   '八卦',
#   '板'],
#  ['港款',
#   '沒變',
#   '口',
#   '洨',
#   '美',
#   '妳',
#   '變',
#   '吼',
#   '妳',
#   '整形',
#   '喔',
#   '迷友',
#   '迷友',
#   '呵呵',
#   '快來',
#   '麻辣鍋',
#   '洨',
#   '美',
#   '友迷友',
#   '整形',
#   '早些',
#   '前',
#   '廣告',
#   '知道',
#   '最近',
#   '打粉',
#   '凶'],
#  ['酸宅',
#   '機會',
#   '動畫',
#   '犬屋',
#   '敷',
#   '徵選',
#   '酸酸',
#   '角色',
#   '聲優',
#   '這是',
#   '作品',
#   '名',
#   '場面',
#   '上酸',
#   '獅子',
#   '神',
#   '角色',
#   '日薪',
#   '高達',
#   '萬元',
#   '日幣',
#   '當天',
#   '配音',
#   '聲優',
#   '簽名',
#   '贈品',
#   '徵人',
#   '年齡',
#   '性別',
#   '學',
#   '經歷',
#   '徵人',
#   '時間',
#   '請',
#   '酸宅',
#   '踴躍',
#   '報名',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'LGE',
#   'LGH815',
#   '知道',
#   '動物',
#   '朋友',
#   '甲賽',
#   '動物',
#   '朋友',
#   '雙頭',
#   '龍',
#   '朋友'],
#  ['今天',
#   '北門',
#   '看到',
#   '一群',
#   '戴',
#   '鴨舌帽',
#   '北門',
#   '城門',
#   '玩',
#   '滑板',
#   '新蓋',
#   '階梯',
#   '表演',
#   '特技',
#   '無視',
#   '旁邊',
#   '路過',
#   '人',
#   '本魯',
#   '沒膽',
#   '嗆',
#   '只好',
#   '播',
#   '報警',
#   '五分鐘',
#   '警察',
#   '驅離',
#   '不甘',
#   '不願',
#   '離開',
#   '旁邊',
#   '玩',
#   '滑板',
#   '相信',
#   '多數',
#   '滑板',
#   '社群',
#   '高調',
#   '古蹟',
#   '牆邊',
#   '玩',
#   '滑板',
#   '推測',
#   '有人',
#   '幕後',
#   '指使',
#   '意圖',
#   '不用說',
#   '有沒有',
#   '有人',
#   '台北',
#   '街頭',
#   '作亂',
#   '八卦'],
#  ['以前',
#   '印象',
#   '隔板',
#   '男廁',
#   '舊欠',
#   '經費',
#   '改善',
#   '那種',
#   '最近',
#   '看到',
#   '紫',
#   '南宮',
#   '花',
#   '多萬',
#   '建',
#   '男廁',
#   '隔板',
#   '顯然',
#   '經費',
#   '問題',
#   '設計',
#   '這是',
#   '設計師',
#   '小',
#   '巧思',
#   '世界潮流'],
#  ['登革熱',
#   '轉移',
#   '台北',
#   '全國',
#   '登革熱',
#   '本土',
#   '病例',
#   '境外',
#   '移入',
#   '病例',
#   '地理分佈',
#   '年',
#   '週',
#   '年',
#   '週',
#   '衛福部',
#   '網站',
#   '連結',
#   '屏東縣',
#   '病',
#   '例數',
#   '人',
#   '高雄市',
#   '病',
#   '例數',
#   '人',
#   '台南市',
#   '病',
#   '例數',
#   '人',
#   '台中市',
#   '病',
#   '例數',
#   '人',
#   '桃園市',
#   '病',
#   '例數',
#   '人',
#   '新北市',
#   '病',
#   '例數',
#   '人',
#   '台北市',
#   '病',
#   '例數',
#   '人',
#   '數據',
#   '證明',
#   '今年以來',
#   '台北市',
#   '登革熱病',
#   '例數',
#   '全台',
#   '最多',
#   '雙北',
#   '市加',
#   '已經',
#   '遠超過',
#   '南部',
#   '總和',
#   '南部',
#   '早已',
#   '洗刷',
#   '登革熱',
#   '汙名',
#   '有沒有',
#   '八卦'],
#  ['西卡',
#   '目前',
#   '接受',
#   '韓媒',
#   '訪問',
#   '時',
#   '表示',
#   '出道',
#   '週年',
#   '最',
#   '辛苦',
#   '瞬間',
#   '少女時代',
#   '離別',
#   '回到',
#   '過去',
#   '西卡',
#   '還會',
#   '選擇',
#   '離團',
#   '卦',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['再',
#   '一個月',
#   '小大',
#   '一們',
#   '就要',
#   '當菜',
#   '逼',
#   '惹',
#   '迎新',
#   '前',
#   '拐',
#   '加系隊',
#   '繳費單',
#   '惹',
#   '邊緣',
#   '人',
#   '來說',
#   '費用',
#   '根本',
#   '有去無回',
#   '直接',
#   '噱',
#   '一票',
#   '開學',
#   '後',
#   '買',
#   '學長',
#   '二手書',
#   '再',
#   '噱',
#   '一票',
#   '有沒有',
#   '小大一',
#   '拿到',
#   '系',
#   '學會',
#   '費單',
#   '乖乖',
#   '去繳',
#   '八卦'],
#  ['新聞來源',
#   '非核',
#   '家園',
#   '燃煤',
#   '電廠',
#   '再生能源',
#   '綠能',
#   '天然氣',
#   '發電',
#   '能源',
#   '配比',
#   '張圖',
#   '年',
#   '各國',
#   '平均',
#   '電價',
#   '國際',
#   '能源',
#   '總署',
#   '台灣',
#   '電價',
#   '便宜',
#   '張圖',
#   '年',
#   '台電',
#   '電源',
#   '成本',
#   '燃煤',
#   '天然氣',
#   '綠能',
#   '至少',
#   '焚化',
#   '廠',
#   'or',
#   '搞',
#   '熱能',
#   '再',
#   '利用',
#   '等於',
#   '能源',
#   '用燒',
#   '冬天',
#   '夏天',
#   '就夠',
#   '熱了',
#   '外面',
#   '還在燒',
#   '電',
#   '不夠',
#   '拼命',
#   '燒',
#   '他媽的',
#   '更熱',
#   '減碳',
#   '全部',
#   '用燒',
#   '成本',
#   '高',
#   '說',
#   '電價',
#   '漲',
#   '來源',
#   '維基百科',
#   '張圖',
#   '世界',
#   '各國',
#   '電力',
#   '消耗',
#   '排名',
#   '前',
#   '幾名',
#   '產油國',
#   'or',
#   '寒帶',
#   '國家',
#   '產油國',
#   '跳過',
#   '提',
#   '富',
#   '流油',
#   '寒帶',
#   '國家',
#   '比較',
#   '容易',
#   '使用',
#   '高耗能',
#   '電器',
#   '用品',
#   '冰島',
#   '冰島',
#   '多座',
#   '火山',
#   '多個',
#   '溫泉',
#   '能源',
#   '水力',
#   '地熱',
#   '列支',
#   '敦',
#   '斯登',
#   '公國',
#   '人口',
#   '萬多',
#   '人均',
#   '挪威',
#   '北海',
#   '油田',
#   '世界',
#   '第三',
#   '石油',
#   '輸出國',
#   '加拿大',
#   '產',
#   '石油',
#   '天然氣',
#   '地方',
#   '大到',
#   '玩',
#   '太陽能',
#   '板',
#   '推',
#   '骨牌',
#   '芬蘭',
#   '後續',
#   '瑞典',
#   '木業',
#   '紙業',
#   '世界',
#   '前',
#   '核能',
#   '石油',
#   '綠能',
#   '綠能',
#   '燒',
#   '木屑',
#   '熱',
#   '廢水',
#   '美國',
#   '不用',
#   '講了',
#   '自已',
#   '國不',
#   '開採',
#   '買',
#   '外國',
#   '買不到',
#   '台灣',
#   '德國',
#   '梅克爾',
#   '非核',
#   '家園',
#   '蔡',
#   '英文',
#   '應該',
#   '學',
#   '德國',
#   '目前',
#   '電價',
#   '上漲',
#   '一度',
#   '電',
#   '元台幣',
#   '德國',
#   '產煤國',
#   '燃煤',
#   '發電',
#   '團體',
#   '最愛',
#   '扯',
#   '德國',
#   '直說',
#   '非核',
#   '好',
#   '從來不',
#   '提',
#   '電價',
#   '台灣',
#   '產煤',
#   '提',
#   '一下',
#   '芬蘭',
#   '好',
#   '芬蘭',
#   '台灣',
#   '部份',
#   '發電',
#   '情況',
#   '最像',
#   '芬蘭',
#   '目前',
#   '共有',
#   '座',
#   '核電機組',
#   '處於',
#   '運轉',
#   '狀態',
#   '座',
#   '年',
#   '蓋',
#   '預算',
#   '億',
#   '歐元',
#   '最終',
#   '預算',
#   '預估',
#   '達',
#   '億',
#   '歐元',
#   '本來',
#   '年',
#   '啟用',
#   '拖到',
#   '年',
#   '延到',
#   '最後',
#   '延到',
#   '年',
#   '都還不',
#   '確定',
#   '啟用',
#   '芬蘭',
#   '發電',
#   '來源',
#   '概況',
#   '石油',
#   '天然氣',
#   '煤炭',
#   '核能',
#   '再生能源',
#   '生質',
#   '廢棄物',
#   '水力',
#   '芬蘭',
#   '廣大',
#   '森林',
#   '發達',
#   '鋸木業',
#   '造紙業',
#   '產生',
#   '大量',
#   '木屑',
#   '生質',
#   '燒',
#   '木屑',
#   '水力',
#   '燒完',
#   '的熱',
#   '廢水',
#   '綠能',
#   '台灣',
#   '砍',
#   '一棵樹',
#   '幹',
#   '狗',
#   '燒',
#   '木屑',
#   'zzzz',
#   '廢核',
#   '之後',
#   '能源',
#   '替代',
#   '綠能',
#   '用燒',
#   '減碳',
#   '不用',
#   '火力',
#   '燃煤',
#   '核能',
#   '燃煤',
#   '台灣',
#   '能源',
#   '缺口',
#   '賭',
#   '天然氣',
#   '綠能',
#   '用燒',
#   '綠能',
#   '先',
#   '說',
#   '天然氣',
#   '發電',
#   '天然氣',
#   '應該',
#   '台灣',
#   '武器',
#   '目前',
#   '有效',
#   '乾淨',
#   '能源',
#   '還在',
#   '開發',
#   '中',
#   '天然氣',
#   '應該',
#   '能源危機',
#   '時才',
#   '拿來',
#   '發電',
#   '....',
#   '有人',
#   '說',
#   '買',
#   '台灣',
#   '海島',
#   '國家',
#   '運輸成本',
#   '加一加',
#   '說',
#   '電費',
#   '漲',
#   'ZZ',
#   '漲',
#   '電費',
#   '買',
#   '漲',
#   '自已',
#   '燒',
#   '自已',
#   '台灣',
#   '天然氣',
#   '燒完',
#   '台灣',
#   'GG',
#   '直接',
#   '統一',
#   '補',
#   '一個',
#   '小常識',
#   '天然氣',
#   '輸出國',
#   '最大',
#   '俄羅斯',
#   '年產量',
#   '超過',
#   '台灣',
#   '倍',
#   '以上',
#   '中',
#   '俄',
#   '簽訂',
#   '億美元',
#   '天然氣',
#   '協議',
#   '年',
#   '俄羅斯',
#   '將向',
#   '中國',
#   '連續',
#   '年',
#   '每年',
#   '輸出',
#   '億平方米',
#   '天然氣',
#   '中國',
#   '天然氣',
#   '石油',
#   '煤礦',
#   '還跟',
#   '俄羅斯',
#   '買',
#   '天然氣',
#   '瑞典',
#   '禁用',
#   '石油',
#   '德國',
#   '非核',
#   '家園',
#   '挪威',
#   '年',
#   '禁售',
#   '內燃機',
#   '汽車',
#   '挪威',
#   '世界',
#   '第三',
#   '石油',
#   '輸出國',
#   '芬蘭',
#   '擬',
#   '率先',
#   '立法',
#   '年',
#   '禁止',
#   '燃煤',
#   '發電',
#   '實現',
#   '巴黎',
#   '協議',
#   '減排',
#   '承諾',
#   '台灣',
#   '非核',
#   '家園',
#   '節能',
#   '減碳',
#   '電費',
#   '漲',
#   '信',
#   'ps',
#   '看到',
#   '回',
#   '文才',
#   '想',
#   '從頭到尾',
#   '提到',
#   '擁核',
#   'or',
#   '支持',
#   '核四',
#   '針對',
#   '電價',
#   '漲',
#   '部分',
#   '提出',
#   '質疑',
#   '一件',
#   '事情',
#   '愛',
#   '發電',
#   '可行',
#   '屁',
#   '甲烷',
#   '一種',
#   '考慮',
#   '用屁',
#   '發電',
#   '收集',
#   '問題',
#   '愛',
#   '發電',
#   '假',
#   '用屁',
#   '發電',
#   '比較',
#   '可行',
#   '自殺',
#   '應該',
#   '企業',
#   '出走',
#   '用電',
#   '辛苦',
#   '台灣',
#   '經濟',
#   '垮',
#   'M',
#   '六個',
#   '字',
#   '精闢',
#   '解釋',
#   '合理',
#   '反映',
#   '成本',
#   '說',
#   '實在',
#   '台灣',
#   '能源',
#   '全部',
#   '仰賴',
#   '進口',
#   '天然氣',
#   '完',
#   '發生',
#   '戰爭',
#   '提了',
#   '能源危機',
#   '台灣',
#   '就要',
#   '垮',
#   '陳',
#   '其邁',
#   '說',
#   '吸',
#   '二氧化碳',
#   '會腦',
#   '殘',
#   '發現',
#   '盲腸',
#   '說真的',
#   '北部',
#   '房價',
#   '降價',
#   '真的',
#   '一招',
#   '民生問題',
#   '沒錯',
#   '製造',
#   '電呢',
#   '請問',
#   '辦法',
#   '替代',
#   '天然氣',
#   '漲',
#   '喔',
#   '主軸',
#   '電價',
#   '漲',
#   '知道',
#   '一直',
#   '扯',
#   '核能',
#   '說真的',
#   '林淑芬',
#   '很棒'],
#  ['世界',
#   '三大',
#   '無人',
#   '知道',
#   '秘密',
#   '配方',
#   '可口可樂',
#   '美味',
#   '蟹堡',
#   '麥當勞',
#   '糖醋',
#   '醬',
#   '破解',
#   '麥當勞',
#   '糖醋',
#   '醬',
#   '大賺一票',
#   '自用',
#   '送人',
#   '兩相宜',
#   '神秘',
#   '配方',
#   '原稿',
#   '藏',
#   '哪裡',
#   '保險櫃'],
#  ['注意',
#   '注意',
#   '還動',
#   '噓文',
#   '特別',
#   '半夜',
#   '肥宅',
#   '弟兄',
#   '觀念',
#   '遇到',
#   '學長',
#   '推文',
#   '還噓文',
#   '第一次',
#   '良性',
#   '勸導',
#   '希望',
#   '再犯',
#   '推文',
#   '之後',
#   '敬禮',
#   '解散'],
#  ['三井',
#   '壽',
#   '體能',
#   '很差',
#   '球場',
#   '昏倒',
#   '沒力',
#   '退場',
#   '三井',
#   '壽',
#   '彈性',
#   '球星',
#   '裡也算',
#   '差',
#   '灌籃高手',
#   '以上',
#   '球員',
#   '灌籃',
#   '三井',
#   '身高',
#   '卻',
#   '無法',
#   '灌籃',
#   '三井',
#   '卻',
#   '守住',
#   '流川楓',
#   '阿福',
#   '飛人',
#   '球星',
#   '八卦'],
#  ['朋友',
#   '說',
#   '淡水',
#   '騎去',
#   '永和',
#   '走環',
#   '河北',
#   '今天',
#   '騎環',
#   '河北',
#   '警察',
#   '攔',
#   '下來',
#   '冥冥之中',
#   '想起',
#   '說',
#   '穿過',
#   '一個',
#   '門',
#   '走',
#   '請問',
#   '門',
#   '耍',
#   '機車',
#   '走環',
#   '河北',
#   '幹',
#   '有沒有',
#   '認真',
#   '鄉民',
#   '門',
#   '嘻嘻',
#   '真',
#   '好',
#   '謝謝'],
#  ['一天',
#   '壘上',
#   '有人',
#   '雙方',
#   '平手',
#   '狀況',
#   '一個',
#   '投手',
#   '投',
#   '一個',
#   '姚明',
#   '接',
#   '不到',
#   '爆',
#   '投',
#   '可想而知',
#   '失',
#   '一分',
#   '沒想到',
#   '捕手',
#   '撿',
#   '完球',
#   '球',
#   '傳給',
#   '補位',
#   '投手',
#   '發現',
#   '投手',
#   '散步',
#   '補',
#   '本壘',
#   '失',
#   '一分',
#   '請問',
#   '投手',
#   '散步',
#   '不補位',
#   '想',
#   '捕手',
#   '想',
#   '總教練',
#   '想',
#   '這是',
#   '假球',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Samsung',
#   'SMN9208'],
#  ['最',
#   '早期',
#   '恐怖片',
#   '服裝',
#   '造型',
#   '化妝',
#   '技術',
#   '都還',
#   '普普通通',
#   '現在',
#   '鬼',
#   '殺人',
#   '魔',
#   '造型',
#   '越來越',
#   '噁',
#   '爛',
#   '音效',
#   '特效',
#   '配合',
#   '恐怖片',
#   '場景',
#   '變得',
#   '真實',
#   '有時候',
#   '總會',
#   '覺得',
#   '嚇人',
#   '時間',
#   '點',
#   '越來越',
#   '好',
#   '掌握',
#   '感覺',
#   '這時候',
#   '嚇人',
#   '恐怖片',
#   '天花板'],
#  ['昨天',
#   '第一次',
#   '小天使',
#   '說話',
#   '已經',
#   '半夜',
#   '三點',
#   '回耶',
#   '真是',
#   '謝謝',
#   '喔',
#   '有沒有',
#   '人當過',
#   '小天使',
#   '分享',
#   '一下',
#   '心得',
#   '好玩',
#   '累',
#   '推薦',
#   '當嗎',
#   '有人',
#   '分享',
#   '小天使',
#   '互動',
#   '經驗',
#   '歡迎',
#   '喔',
#   '問',
#   '一些',
#   'PTT',
#   '使用',
#   '問題'],
#  ['號稱',
#   '當代',
#   '古典',
#   '小提琴',
#   '第一把',
#   '交椅',
#   '雙腳',
#   '不良',
#   '行',
#   '小提琴',
#   '技法',
#   '高超',
#   '一次',
#   '演奏',
#   '時弦斷',
#   '一根',
#   '三條',
#   '弦',
#   '演奏',
#   '完',
#   '剩下',
#   '部分',
#   '有沒有',
#   '帕爾曼',
#   '八卦',
#   '辛德勒',
#   '名單',
#   '拉',
#   '好好',
#   '聽',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Sony',
#   'D6503',
#   'You',
#   'want',
#   'to',
#   'know',
#   'how',
#   'I',
#   'did',
#   'it',
#   'This',
#   'is',
#   'how',
#   'I',
#   'did',
#   'it',
#   'I',
#   'never',
#   'saved',
#   'anything',
#   'for',
#   'the',
#   'swim',
#   'back'],
#  ['上次',
#   '吃飯',
#   '爸',
#   '討論',
#   '接球',
#   '說',
#   '接球',
#   '位置',
#   '痛',
#   '公里',
#   '痛',
#   '接',
#   '手套',
#   '點',
#   '說',
#   '時速',
#   '會痛',
#   '反應',
#   '很快',
#   '有沒有',
#   '接過',
#   '時速',
#   '以上',
#   '說明',
#   '一下',
#   '痛',
#   '有沒有',
#   'o',
#   'o'],
#  ['買',
#   '宵夜',
#   '設定',
#   '預算',
#   '元',
#   '實際',
#   '現場',
#   '預算',
#   '爆表',
#   '失去',
#   '理智',
#   '本來',
#   '預計',
#   '購買',
#   '名單',
#   '裡的',
#   '食物',
#   '加點',
#   '買',
#   '回家',
#   '慾望',
#   '戰勝',
#   '熱量',
#   '爆表',
#   '惹',
#   '預算',
#   '慾望',
#   '慾望',
#   '預算',
#   '惹',
#   '多買',
#   '一杯',
#   '無糖',
#   '手搖',
#   '茶',
#   '不知',
#   '減低',
#   '罪惡感',
#   '....'],
#  ['安安',
#   '肥宅',
#   '今天',
#   '出差',
#   '台南',
#   '客戶',
#   '洗臉',
#   '後',
#   '點多',
#   '聽說',
#   '台南',
#   '美食',
#   '找',
#   '路邊攤',
#   '坐',
#   '下來',
#   '吃',
#   '蝦',
#   '捲',
#   '撇到',
#   '旁邊',
#   '一個',
#   '阿伯',
#   '年輕人',
#   '弄',
#   '醬油膏',
#   '薑末',
#   '蝦',
#   '捲',
#   '胡椒',
#   '夠味',
#   '沒想到',
#   '台南人',
#   '口味',
#   '那摸重',
#   '桌',
#   '一盤',
#   '牛',
#   '番茄',
#   '幹',
#   '醬油膏',
#   '薑末',
#   '沾',
#   '番茄',
#   '吃',
#   '好',
#   '噁心',
#   '看不下去',
#   '害',
#   '老闆娘',
#   '說',
#   '包',
#   '拿到',
#   '車上',
#   '吃',
#   '這種',
#   '沾法',
#   '想',
#   '八卦'],
#  ['聽說',
#   '首歌',
#   '歡喜',
#   '好',
#   '算是',
#   '陳',
#   '雷較',
#   '出名',
#   '代表',
#   '歌曲',
#   '歌詞',
#   '聽',
#   '感覺',
#   '綠綠的',
#   '有沒有',
#   '首歌',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z012DA'],
#  ['題',
#   '三者',
#   '屬於',
#   '年代',
#   '美國',
#   '經典',
#   '樂團',
#   '當時',
#   '排名',
#   '聽說',
#   '超脫',
#   '邦',
#   '喬飛',
#   '槍花',
#   '小弟',
#   '最愛',
#   '槍',
#   '玫瑰',
#   '請問',
#   '哪團',
#   '鄉民',
#   '心中',
#   '經典'],
#  ['獵人',
#   '世界',
#   '相傳',
#   '東巴',
#   '西索',
#   '剩下',
#   '南北',
#   '中',
#   '有沒有',
#   '獵人',
#   '五絕',
#   '剩下',
#   '三絕',
#   '八卦'],
#  ['同事',
#   '只來',
#   '天',
#   '提出',
#   '離職',
#   '老闆',
#   '不想',
#   '慰留',
#   '但過',
#   '幾天',
#   '卻',
#   '打電話',
#   '回來',
#   '問',
#   '天',
#   '工資',
#   '現在',
#   '試用期',
#   '還要',
#   '錢',
#   '東西',
#   '還學',
#   '還要',
#   '領錢',
#   '十天',
#   '連茶',
#   '搖',
#   '東西',
#   '還沒',
#   '背熟',
#   '制服',
#   '還被',
#   '穿',
#   '髒'],
#  ['胎嘎',
#   '後',
#   '想問',
#   '一下',
#   '吃',
#   '壽司',
#   '看到',
#   '很俗',
#   '南部',
#   '人',
#   '芥末',
#   '醬油',
#   '攪和',
#   '一起',
#   '沾',
#   '驚呆',
#   '吃',
#   '根本',
#   '吃不出',
#   '芥末',
#   '清香',
#   '醬油',
#   '提',
#   '鮮味',
#   '有沒有',
#   '南部',
#   '台北市',
#   '中正',
#   '中山',
#   '大安',
#   '天母',
#   '朋友',
#   '幫',
#   '回答',
#   '一下',
#   '感恩',
#   '這位',
#   '朋友',
#   '想法',
#   'ㄋ',
#   '南部',
#   '土豪',
#   '比較',
#   '吃',
#   '汗味',
#   '唷',
#   '三味',
#   '食堂',
#   '粗飽',
#   'ㄋ',
#   '挖',
#   '鄭公',
#   '吃',
#   '生切',
#   '牛肉',
#   '厚片',
#   '炙燒',
#   '後',
#   '加一點',
#   '玫瑰',
#   '鹽',
#   '吃',
#   '牛排'],
#  ['先',
#   '定義',
#   '分界線',
#   '好',
#   '公司',
#   '負責人',
#   '佔',
#   '公司',
#   '資本額',
#   '以上',
#   '淨收入',
#   '一年',
#   '超過',
#   '萬',
#   '創業資金',
#   '親友',
#   '資助',
#   '萬',
#   '以內',
#   '存',
#   '銀行貸款',
#   '政府',
#   '補助',
#   '合夥',
#   '天使',
#   '投資人',
#   '法律',
#   '合法',
#   '社會',
#   '反感',
#   '產業',
#   '歲',
#   '以內',
#   '身邊',
#   '例子',
#   '有沒有',
#   '八卦'],
#  ['小嚕',
#   '朋友',
#   '睡覺',
#   '聞',
#   '腳',
#   '真的',
#   '奇怪',
#   '抓',
#   '聞',
#   '一聞',
#   '特別',
#   '好聞',
#   '有沒有',
#   '腳味',
#   '八卦',
#   'hi',
#   '謝謝',
#   '感受',
#   '心意',
#   '懶覺',
#   '五歲',
#   '好險',
#   '女',
#   '妹妹',
#   '綠水',
#   '靈洞',
#   '喜歡',
#   '浴室',
#   '超',
#   '可愛'],
#  ['間',
#   '環東',
#   '幹嘛',
#   '塞在環',
#   '東上',
#   '分鐘',
#   '真的',
#   '好',
#   '想',
#   '尿',
#   '尿',
#   '啊啊啊',
#   '啊啊啊',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['發現自己',
#   '常在',
#   'ptt',
#   '上拉',
#   '仇恨',
#   '三不五時',
#   '嘴',
#   '一下',
#   '甲甲',
#   '南部',
#   '人',
#   '母豬',
#   '這有',
#   '辦法',
#   '停止',
#   '我怕',
#   '一天',
#   '現實',
#   '中',
#   '小心',
#   '脫口而出'],
#  ['屏東', '潮州', '冷熱', '冰', '有名', '圓環', '兩家', '自稱', '老店', '請問', '吃', '哪家', '正統'],
#  ['乳題',
#   '最近',
#   'FB',
#   '出現',
#   '好像',
#   '馬來西亞',
#   '圖文',
#   '作家',
#   '叫做',
#   '金魚缸',
#   '幹',
#   '幹貓',
#   '底下',
#   '瘋狂',
#   '戰',
#   '父權',
#   '定義',
#   '一堆',
#   '人戰得',
#   '有沒有',
#   '八卦'],
#  ['鹽',
#   '酥',
#   '雞塗',
#   '奶油',
#   '新',
#   '吃法',
#   '有人',
#   '試過',
#   '利亞',
#   '先塗',
#   '奶油',
#   '執拗',
#   '好吃',
#   '人想過',
#   '台灣',
#   '鹽',
#   '酥',
#   '雞',
#   '太',
#   '故步自封',
#   '開發',
#   '一些',
#   '新',
#   '吃法'],
#  ['安安',
#   '最近',
#   '禮拜',
#   '一直',
#   '看到',
#   '電視',
#   '在講',
#   '用電量',
#   '新聞',
#   '一所',
#   '大學',
#   '裡面',
#   '起碼',
#   '幾千',
#   '台',
#   '電腦',
#   '電腦',
#   '沒在關',
#   '電燈',
#   '冷氣',
#   '飲水機',
#   '電梯',
#   '一些',
#   '沒得',
#   '用電',
#   '加',
#   '電費',
#   '應該',
#   '可怕',
#   '有沒有',
#   '一所',
#   '大學',
#   '夏天',
#   '一個月',
#   '電費',
#   '八卦',
#   '作者',
#   'Ifau',
#   'Not',
#   'my',
#   'fault',
#   '板',
#   'Gossiping',
#   '標題',
#   'Re',
#   '問卦',
#   '妹妹',
#   '懷孕',
#   '肚子',
#   '撐得',
#   '好大',
#   '整天',
#   '說',
#   '低能',
#   '卡',
#   '一堆',
#   '幻想',
#   '文',
#   '八卦',
#   '充斥',
#   '妹妹',
#   '戰女',
#   '姐姐',
#   '學姊',
#   '意淫',
#   '文',
#   '真是',
#   '可悲'],
#  ['玫瑰油',
#   '雞',
#   '出現',
#   '街頭巷尾',
#   '燒臘',
#   '店中',
#   '本體',
#   '滷雞',
#   '腿',
#   '看不到',
#   '玫瑰',
#   '紅色',
#   '烤雞',
#   '腿',
#   '命名',
#   '分隔',
#   '說',
#   '烤雞',
#   '腿',
#   '紅紅的',
#   '有加',
#   '玫瑰',
#   '我還',
#   '相信',
#   '有沒有',
#   '玫瑰油',
#   '雞',
#   '八卦',
#   '太陽',
#   '餅',
#   '太陽',
#   '概念',
#   '蜂蜜',
#   '醃',
#   '香蕉'],
#  ['牽',
#   '一台',
#   '新',
#   '摩托車',
#   '車行',
#   '老闆',
#   '說',
#   '記得',
#   '汽油',
#   '要加',
#   '附帶',
#   '開車',
#   '行',
#   '幾十年',
#   '聽',
#   '我的準',
#   '沒錯',
#   '一旁',
#   '學徒',
#   '猛',
#   '點頭',
#   '騎去',
#   '加油',
#   '騎',
#   '一半',
#   '想到',
#   '油箱蓋',
#   '明明',
#   '寫',
#   '建議',
#   '使用',
#   '無鉛',
#   '汽油',
#   '一個',
#   '一個',
#   '車行',
#   '老闆',
#   '老老',
#   '經驗豐富',
#   '沒錯',
#   '引擎',
#   '廠商',
#   '設計',
#   '耶',
#   '該加',
#   '一種',
#   '加',
#   '一半',
#   '一半'],
#  ['全台灣',
#   '成功',
#   '園區',
#   '竹科',
#   '南科',
#   '中科',
#   '普普通通',
#   '有點',
#   '雞肋',
#   '產業',
#   '聚落',
#   '沒什麼',
#   '特別',
#   '幫助',
#   '聽說',
#   '高雄要',
#   '弄',
#   '個體',
#   '感',
#   '園區',
#   '整個',
#   '問號',
#   '軟體',
#   '為主',
#   '公司',
#   '聚落',
#   '有個',
#   '冷氣',
#   '網路',
#   '地方',
#   '一堆',
#   '阿宅',
#   '裡面',
#   '電腦',
#   '就行了',
#   '最多',
#   '硬體',
#   '需求',
#   '電腦',
#   '感測器',
#   '路竹',
#   '園區',
#   '木柵',
#   '園區',
#   '園區',
#   '木柵',
#   '園區',
#   '說',
#   '產值',
#   '不錯',
#   '園區',
#   '幹嘛',
#   '總',
#   '想',
#   '炒地皮',
#   '民調',
#   '第一名',
#   '市長',
#   '幹',
#   '這種',
#   '事',
#   '不用',
#   '園區',
#   '成長',
#   '直轄市',
#   '亂搞',
#   '本來',
#   '成長',
#   '直轄市',
#   '資源',
#   '亂蓋',
#   '東西',
#   '亂',
#   '放煙火',
#   '用來',
#   '做',
#   '基礎',
#   '建設',
#   '工作',
#   '機會',
#   '臺中',
#   '精密',
#   '工業',
#   '園區',
#   '聚集',
#   '捷安特',
#   '美利達',
#   '一堆',
#   '精密',
#   '金工',
#   '自然',
#   '群聚',
#   '根本',
#   '園區',
#   '沒關係',
#   '園區',
#   '廠商',
#   'c',
#   'p',
#   '值',
#   '園區'],
#  ['本魯宅',
#   '吃',
#   '麥當勞',
#   '推出',
#   '點點',
#   '卡',
#   '後',
#   '更是',
#   '消費',
#   '再',
#   '送',
#   '一個',
#   '套餐',
#   '計算',
#   '之後',
#   '吃',
#   '銅板',
#   '餐點',
#   '兩份',
#   '一張',
#   '鈔票',
#   '打發',
#   'app',
#   '抽到',
#   '買',
#   '一送',
#   '一時',
#   '買',
#   '有沒有',
#   '麥當勞',
#   '吃',
#   '最',
#   '划算',
#   '八卦',
#   '人稱',
#   '交大',
#   '薛之謙',
#   '附上',
#   '自拍照',
#   '一張'],
#  ['安安',
#   '小弟',
#   '發現',
#   '台北',
#   '車站',
#   '一堆',
#   '消防車',
#   '消防員',
#   '進出',
#   '車站',
#   '有人',
#   '知道',
#   '小',
#   '失火',
#   '好',
#   '幹',
#   '嚇死',
#   '陰毛'],
#  ['現在',
#   '天氣',
#   '很熱',
#   '沒人要',
#   '做拔',
#   '菜',
#   '工作',
#   '請問',
# ...
#   '家屬',
#   '賺',
#   '一筆',
#   '好',
#   '廢死',
#   '理由',
#   '腰',
#   '正義',
#   '大旗',
#   '廢死',
#   '腰',
#   '有沒有',
#   '卦',
#   '廢死',
#   '幹',
#   '娘',
#   '卒',
#   '帥',
#   '馬',
#   '此時',
#   '車',
#   '帥有',
#   '何用',
#   '有車',
#   '馬',
#   '馬子',
#   '狡兔',
#   '三窟',
#   '馬子',
#   '一個',
#   '加害者',
#   '裝瘋',
#   '逃離',
#   '司法',
#   '制裁',
#   '家屬',
#   '選擇',
#   '原諒',
#   '不好',
#   '心裡',
#   '學上',
#   '家屬',
#   '產生',
#   '失調',
#   '真正',
#   '原諒',
#   '兇手',
#   '不好',
#   '消除',
#   '仇恨',
#   '不好',
#   '選',
#   '立委',
#   '有人',
#   '投',
#   '參政',
#   '管道',
#   '樂意',
#   '嘻嘻',
#   '反智',
#   '摳連',
#   '反智',
#   '嘻嘻',
#   '拜託',
#   '拉低',
#   '我方',
#   '水準',
#   '好',
#   '認真',
#   '說',
#   '開玩笑',
#   '謝謝',
#   '喔',
#   '喔',
#   '喔',
#   '湊',
#   '人',
#   '選啦',
#   '誤',
#   '喔',
#   '好',
#   '說',
#   '說',
#   '哪裡',
#   '反智',
#   '說',
#   '連個',
#   '屁',
#   '說不出來',
#   '反智',
#   '摳連',
#   '哭哭',
#   '是不是',
#   '小學',
#   '還沒',
#   '畢業',
#   '刑罰',
#   '存在',
#   '知道',
#   '刑罰',
#   '存在',
#   '意義',
#   '知道',
#   '還敢',
#   '犯人',
#   '改過',
#   '向善',
#   '該是',
#   '出家',
#   '關在',
#   '牢裡',
#   '刑罰',
#   '主要',
#   '安定',
#   '社會',
#   '功能',
#   '知不知道',
#   '喔',
#   '忘記',
#   '現在',
#   '正在',
#   '放暑假',
#   '喔',
#   '喔',
#   '逃過',
#   '重',
#   '制裁',
#   '逃',
#   '喔',
#   '胃',
#   '硬衝',
#   '輕判',
#   '逃過',
#   '喔',
#   '好',
#   '棒棒',
#   '滑坡',
#   '摳連',
#   '說',
#   '只會',
#   '說',
#   '反智',
#   '卻',
#   '思考',
#   '人',
#   '反智',
#   '幫',
#   '改錯',
#   '字',
#   '嘻嘻',
#   '終於',
#   '釣到',
#   '這種',
#   '人',
#   '先',
#   '檢討',
#   '說話',
#   '人',
#   '先',
#   '討論',
#   '事情',
#   '標準',
#   '人',
#   '事',
#   '叫做',
#   '思考',
#   '人',
#   '這不',
#   '一個',
#   '例子',
#   '哭哭',
#   '喔',
#   '釣到',
#   'www',
#   '可惜',
#   '根本',
#   '認識',
#   '政治',
#   '人物',
#   'www'],
#  ['本魯',
#   '早上',
#   '睡',
#   '一半',
#   '發現',
#   '電風扇',
#   '沒動靜',
#   '發現',
#   '家裡',
#   '整棟',
#   '沒電',
#   '總開關',
#   '開關',
#   '過了',
#   '沒用',
#   '本魯要',
#   '熱死',
#   '電源',
#   '恢復正常',
#   '愛',
#   '發電'],
#  ['最近',
#   '讀',
#   '希臘神話',
#   '讀',
#   '金蘋果',
#   '章',
#   '節時',
#   '總覺',
#   '帕里斯',
#   '評判',
#   '實在',
#   '有意思',
#   '赫拉',
#   '說',
#   '要給',
#   '帕里斯',
#   '成為',
#   '統領',
#   '全',
#   '亞洲',
#   '國王',
#   '給予',
#   '至高無上',
#   '權力',
#   '雅典娜',
#   '說',
#   '要給',
#   '帕里斯',
#   '智慧',
#   '戰場',
#   '時',
#   '戰無不勝',
#   '阿芙',
#   '蘿黛蒂說',
#   '要給',
#   '帕里斯',
#   '全世界',
#   '最美',
#   '女人',
#   '愛情',
#   '覺得',
#   '命題',
#   '邏輯',
#   '有點',
#   '問題',
#   '真的',
#   '至高無上',
#   '權力',
#   '打仗',
#   '時',
#   '真的',
#   '戰無不勝',
#   '還怕',
#   '得不到',
#   '世界',
#   '最美',
#   '女子',
#   '鑽牛角尖',
#   '肥宅會',
#   '選擇',
#   '八卦'],
#  ['鄉民',
#   '神人',
#   '早安',
#   '事情',
#   '子',
#   '小弟',
#   '受託',
#   '幫',
#   '買',
#   '營養品',
#   '一瓶',
#   '銀杏',
#   '魚油',
#   '瓶裝',
#   '膠囊',
#   'Costco',
#   '賣',
#   '小弟',
#   '翻遍',
#   'Costco',
#   '找',
#   '不到',
#   '線索',
#   '一張',
#   '圖片',
#   '上網',
#   '找遍',
#   '各大',
#   '購物網',
#   '找',
#   '不到',
#   '相同',
#   '圖片',
#   '營養品',
#   '想',
#   '請',
#   '神',
#   '人們',
#   '看看',
#   '有沒有',
#   '人',
#   '知道',
#   '一瓶',
#   '品牌',
#   '看過',
#   '賣',
#   '小弟',
#   '不勝感激',
#   '.....',
#   '以下',
#   '瓶裝',
#   '圖片'],
#  ['小弟',
#   '今天',
#   '搭',
#   '捷運',
#   '等車',
#   '一個',
#   '開',
#   '電動',
#   '代步車',
#   '阿伯',
#   '連路',
#   '直接',
#   '背後',
#   '衝',
#   '害',
#   '直接',
#   '撞倒',
#   '還好',
#   '背包',
#   '包',
#   '送',
#   '醫院',
#   '阿伯',
#   '一聲',
#   '對不起',
#   '說',
#   '直接',
#   '肇事',
#   '逃逸',
#   '有沒有',
#   '捷運',
#   '開',
#   '電動',
#   '代步車',
#   '還不看',
#   '路',
#   '人',
#   '想',
#   '八卦',
#   '車站',
#   '等車',
#   '撞',
#   '行動不便',
#   '看路',
#   '車來',
#   '我要',
#   '趕上',
#   '車',
#   '搭',
#   '電梯',
#   '門',
#   '直接',
#   '關上',
#   '真的',
#   '討厭',
#   '忠孝',
#   '新生',
#   '電梯',
#   '設計',
#   '真的',
#   '騎車',
#   '開車',
#   '遇過',
#   '開',
#   '大客車',
#   '砂石車',
#   '還兇',
#   '看路',
#   '現在',
#   '背',
#   '還會痛',
#   '棚頂',
#   '還蠻',
#   '大台',
#   '道路交通',
#   '法有',
#   '管到',
#   '代步車',
#   '代步車',
#   '確定'],
#  ['問卦',
#   '中國',
#   '人',
#   '驕傲',
#   '年代',
#   '是不是',
#   '已經',
#   '來到',
#   '先說',
#   '前面',
#   '獨派',
#   '昨天',
#   '朋友',
#   '吃飯',
#   '朋友',
#   '一個',
#   '香港',
#   '人住',
#   '上海',
#   '一個',
#   '浙江人',
#   '聊著',
#   '聊著',
#   '國內',
#   '大陸',
#   '進步',
#   '壯大',
#   '身為',
#   '炎黃子孫',
#   '心情',
#   '真',
#   '好',
#   '深感',
#   '驕傲',
#   '問卦',
#   '中國',
#   '人',
#   '驕傲',
#   '年代',
#   '是不是',
#   '已經',
#   '來到',
#   '萬惡',
#   '無能',
#   '蔡',
#   '英文',
#   '給我',
#   '下台',
#   '國民黨',
#   '相關',
#   '經濟犯罪',
#   '起訴',
#   '判刑',
#   '潛逃',
#   '列表',
#   '全員',
#   '逃走',
#   '中',
#   '牠',
#   '萬惡',
#   '國民黨',
#   '共識',
#   '共識',
#   '一中',
#   '框架',
#   '一中',
#   '同表',
#   '賣國',
#   '賣台',
#   '台',
#   '中',
#   '吃飯',
#   '聊天'],
#  ['廢', '文章', '發錢', '爆文', '是不是', '真的', '想', '測試', '一下', '看看', '推爆', '樓給'],
#  ['安安',
#   '最近',
#   '核能',
#   '議題',
#   '浮現',
#   '拉',
#   '核能',
#   '反對',
#   '原因',
#   '兩個',
#   '一個',
#   '安全性',
#   '最',
#   '先進',
#   '核四是',
#   '多家',
#   '廠商',
#   '合作',
#   '蓋起來',
#   '政治',
#   '因素',
#   '工期',
#   '太長',
#   '導致',
#   '安全',
#   '疑慮',
#   '越來越',
#   '高',
#   '民眾',
#   '感性',
#   '層面',
#   '福島',
#   '核災',
#   '嚇到',
#   '核災',
#   '管控',
#   '高',
#   '不信任感',
#   '一個',
#   '環保',
#   '性',
#   '科技進步',
#   '核廢料',
#   '再',
#   '處理',
#   '科技',
#   '發展',
#   '高階',
#   '核廢料',
#   '能夠',
#   '處理',
#   '再次',
#   '發電',
#   '處理',
#   '後',
#   '高',
#   '高階',
#   '核廢料',
#   '需要',
#   '處理',
#   '台灣',
#   '最新',
#   '核四',
#   '辦法',
#   '做到',
#   '高階',
#   '再',
#   '處理',
#   '政治',
#   '因素',
#   '辦法',
#   '發展',
#   '內部',
#   '因素',
#   '立法',
#   '蓋',
#   '新',
#   '核電廠',
#   '外',
#   '再',
#   '處理',
#   '技術',
#   '製做',
#   '核彈',
#   '原料',
#   '相關',
#   '核電廠',
#   '安全性',
#   '問題',
#   '淪',
#   '理組',
#   '文組',
#   '口水戰',
#   '認真',
#   '討論一下',
#   '環保',
#   '性',
#   '問題',
#   '結論',
#   '繼續',
#   '使用',
#   '核電',
#   '技術',
#   '減少',
#   '高階',
#   '核廢料',
#   '情況',
#   '下',
#   '勢必',
#   '找到',
#   '貯存',
#   '高階',
#   '核廢料',
#   '方法',
#   '海運',
#   '不太可能',
#   '發生',
#   '目前',
#   '高階',
#   '核廢料',
#   '暫時',
#   '放在',
#   '核電廠',
#   '裡',
#   '好像',
#   '已經',
#   '快滿',
#   '最好',
#   '方式',
#   '乾式',
#   '貯存',
#   '存在',
#   '地震帶',
#   '沙漠',
#   '裡',
#   '需要',
#   '解決',
#   '問題',
#   '找到',
#   '一塊',
#   '好',
#   '福地',
#   '好好',
#   '收藏',
#   '台灣',
#   '最',
#   '適合',
#   '乾式',
#   '貯存',
#   '地點',
#   '哪裡',
#   '考慮',
#   '容量',
#   '太小',
#   '核廢料',
#   '只會',
#   '增加',
#   '減少',
#   '安全',
#   '至少',
#   '耐震',
#   '土石',
#   '鬆動',
#   '政治',
#   '附近',
#   '有太多',
#   '居民',
#   '沒完沒了',
#   '環保',
#   '衝擊',
#   '小',
#   '影響',
#   '棲地',
#   '水源',
#   '知道',
#   '考量',
#   '別嘴',
#   '砲',
#   '說',
#   '放',
#   '你家',
#   '放',
#   '我家',
#   '拉',
#   '你家',
#   '牽到網',
#   '路線',
#   '能夠',
#   '發廢文',
#   '適合',
#   '放',
#   '台灣',
#   '地點',
#   '能夠',
#   '放個',
#   '幾千年',
#   '幾噸',
#   '核廢料',
#   '咧',
#   '放',
#   '核電廠',
#   '裡面',
#   '欸',
#   '高階',
#   '好像',
#   '上船',
#   '過海',
#   '誤會',
#   '拉',
#   '這是',
#   '一個',
#   '全台灣',
#   '一起',
#   '面對',
#   '議題',
#   '放',
#   '她家',
#   '放',
#   '你家',
#   '放',
#   '我家',
#   '搞不好',
#   '鄰居',
#   '痾',
#   '將你',
#   '意見',
#   '歸納',
#   '發展',
#   '高階',
#   '核廢料',
#   '新',
#   '用途',
#   '科技',
#   '研發',
#   '做成',
#   '武器',
#   '好像',
#   '人類',
#   '福祉',
#   '太好',
#   '幫助',
#   '連噓',
#   '兩次',
#   '辛苦',
#   '笑',
#   '恩',
#   '公布',
#   '一下',
#   '你家',
#   '住址',
#   '地方',
#   '看看',
#   '喔',
#   '喔',
#   '喔',
#   '第一次',
#   '聽到',
#   '多一點',
#   '資訊',
#   '政治',
#   '因素',
#   '太強',
#   '不太可能',
#   '高階',
#   '核廢料',
#   '上船',
#   '痾',
#   '目前',
#   '實質',
#   '比較',
#   '可行',
#   '高階',
#   '核廢料',
#   '火力',
#   '爐渣',
#   '好像',
#   '不太',
#   '埋',
#   '爐渣',
#   '放',
#   '高階',
#   '核廢料',
#   '場地',
#   '考量',
#   '應該',
#   '先',
#   '跳',
#   '無法',
#   '聚焦',
#   '討論',
#   '離島',
#   '運送',
#   '東部',
#   '花崗岩',
#   '地質',
#   '獲得',
#   '認可',
#   '第三點',
#   '值得',
#   '仔細',
#   '討論',
#   '內容',
#   '有點',
#   '濫情',
#   'OK',
#   '....',
#   '議題',
#   '重要',
#   '台灣',
#   '太空',
#   '科技',
#   '已經',
#   '製造',
#   '衛星',
#   '囉',
#   '射上去',
#   '火箭',
#   '運送',
#   '核',
#   '廢',
#   '限制',
#   '好像',
#   '找到',
#   '合適',
#   '地點',
#   '困難'],
#  ['如題',
#   '公家',
#   '單位',
#   '下午',
#   '開',
#   '冷氣',
#   '耗電量',
#   '佔',
#   '台電',
#   '用電量',
#   '影響',
#   '根本',
#   '本來',
#   '還說',
#   '兩個',
#   '禮拜',
#   '冷氣',
#   '一個',
#   '禮拜',
#   '達成',
#   '今天',
#   '開',
#   '冷氣',
#   '自打',
#   '臉',
#   '行政院長',
#   '檢討',
#   '這條',
#   '命令',
#   '這條',
#   '命令',
#   '負責',
#   '辦',
#   '家家酒',
#   '荒謬',
#   '腦殘',
#   '真是',
#   '極限',
#   '說明',
#   '開',
#   '冷氣',
#   '幫助',
#   '姑婆',
#   '芋',
#   '發言人',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'OPPO',
#   'X9079'],
#  ['蛤', '黑心', '內幕', '一種', '肉類', '火腿', '勒', '吃個', '早餐'],
#  ['標題',
#   '寫',
#   '台獨',
#   '有人',
#   '堅持',
#   '說',
#   '建國',
#   '正確',
#   '想',
#   '表達',
#   '台灣',
#   '變成',
#   '主權',
#   '獨立國家',
#   '改念',
#   '記得',
#   '以前',
#   '終止',
#   '代管',
#   '自決',
#   '建國',
#   '文章',
#   '一直',
#   '推爆',
#   '好像',
#   '覺得',
#   '台灣',
#   '唯有',
#   '建國',
#   '未來',
#   '可言',
#   '最近',
#   '建國',
#   '派',
#   '好像',
#   '式微',
#   '人理',
#   '台灣',
#   '人',
#   '真的',
#   '想要',
#   '獨立',
#   '中共',
#   '統一',
#   '好',
#   '感覺',
#   '多數',
#   '台灣',
#   '人',
#   '好像',
#   '後者',
#   '好',
#   '耶',
#   '好像',
#   '昨天',
#   '葉望輝',
#   '打槍',
#   '確定',
#   '台灣成',
#   '美國',
#   '州',
#   '葉望輝',
#   '政治',
#   '自由',
#   '時報',
#   '電子報',
#   '感覺',
#   '台灣',
#   '位置',
#   '太',
#   '重要',
#   '非',
#   '拿到',
#   '手',
#   '不可',
#   '中華民國',
#   '非',
#   '聯合國',
#   '會員國',
#   '觀察員',
#   '主權',
#   '獨立國家',
#   '政治',
#   '實體',
#   '聶',
#   '斯特',
#   '河',
#   '沿岸',
#   '納哥諾',
#   '卡拉',
#   '巴克',
#   '南奧塞',
#   '提亞',
#   '阿布哈茲',
#   '北賽',
#   '普',
#   '勒斯',
#   '索',
#   '馬利蘭',
#   '阿拉伯',
#   '撒哈拉',
#   '民主',
#   '共和國',
#   '馬爾他',
#   '騎士團',
#   '庫克',
#   '群島',
#   '紐埃',
#   '盧干斯克',
#   '人民共和國',
#   '頓內次',
#   '克',
#   '人民共和國',
#   '中華民國',
#   '馬爾他',
#   '騎士團',
#   '真的',
#   '聽過',
#   '找',
#   '俄羅斯',
#   '正妹',
#   '耶'],
#  ['立委',
#   '說',
#   '核一核',
#   '形同',
#   '提前',
#   '除役',
#   '再',
#   '啟動',
#   '囉',
#   '行政院',
#   '發言人',
#   '說',
#   '葉克膜',
#   '囉',
#   '同志',
#   '說',
#   '提前',
#   '除役',
#   '囉',
#   '台積電',
#   '全省',
#   '廠用電',
#   '約',
#   '萬千瓦',
#   '占',
#   '台電',
#   '供電',
#   '相當',
#   '核電廠',
#   '一部',
#   '機組',
#   '現在',
#   '已經',
#   '橘燈',
#   '前',
#   '陣子',
#   '紅燈',
#   '台積',
#   '電三奈',
#   '米廠',
#   '沒電',
#   '可用',
#   '連葉克膜',
#   '掰掰',
#   '囉',
#   'ω',
#   '阿災',
#   '林全',
#   '離岸',
#   '風機',
#   '先',
#   '要說',
#   '有沒有',
#   '插',
#   '還要',
#   '年'],
#  ['ㄤ',
#   'ㄤ',
#   '肥宅',
#   '窩',
#   '大阪',
#   '環球',
#   '影城',
#   '排',
#   '蜘蛛人',
#   '噗',
#   'ㄓ',
#   '噗',
#   'ㄓ',
#   '要排',
#   '分鐘',
#   '欸',
#   '這段',
#   '時間',
#   '窩要',
#   '幹嘛',
#   '肝',
#   '卦',
#   '真的',
#   'QQ',
#   '窩',
#   '剛剛',
#   '小小',
#   '兵店',
#   '買',
#   '花'],
#  ['小時候',
#   '夢想',
#   '職業',
#   '太空人',
#   '醫生',
#   '長大',
#   '比較',
#   '實際',
#   '有個',
#   '喜歡',
#   '公司',
#   '喜歡',
#   '牌子',
#   '高',
#   '中時',
#   '進',
#   '航空公司',
#   '嚮往',
#   'ㄉ',
#   '像是',
#   '長榮',
#   '阿聯酋',
#   'ANA',
#   '這種',
#   '只',
#   '是不是',
#   '空服員',
#   '機師',
#   '這類',
#   '工作',
#   '惹',
#   '夢想',
#   '進入',
#   '公司',
#   '我想',
#   '過當',
#   '導遊',
#   '覺得',
#   '最後',
#   '旅行',
#   '熱忱',
#   '覺得',
#   '出差',
#   '工作',
#   '好'],
#  ['剛看',
#   '一個',
#   'Youtuber',
#   '台主',
#   '大學',
#   '連成',
#   '北科',
#   '台科',
#   '沒考上',
#   '鄉民',
#   '眼裡',
#   '廢物',
#   '鄉民',
#   '邏輯',
#   '夾著',
#   '懶蛋',
#   '跑',
#   '日本',
#   '念立',
#   '命館',
#   '大學',
#   '畢業',
#   '後',
#   '日本',
#   '工作',
#   '現在',
#   '辭掉',
#   '工作',
#   '專心',
#   '當台主',
#   '命館',
#   '大學畢業',
#   '後',
#   '挾著',
#   '雙語',
#   '優勢',
#   '日本',
#   '企業',
#   '超',
#   '愛用',
#   '留在',
#   '日本',
#   '賺',
#   '日幣',
#   '念台',
#   '科大',
#   '優勢',
#   '哪裡',
#   '抬',
#   '蚵',
#   '連北科',
#   '台科',
#   '沒考上',
#   '廢物',
#   '鄉民',
#   '邏輯',
#   '通通',
#   '出國',
#   '念書',
#   '賺',
#   '外幣',
#   '留在',
#   '台灣戰',
#   '學校',
#   '領',
#   '作',
#   '甚'],
#  ['資深',
#   '蠕動',
#   '有點',
#   '頻繁',
#   '是不是',
#   '以為',
#   '民進黨',
#   '黑',
#   '國民黨',
#   '有救',
#   '林',
#   '北票',
#   '真的',
#   '投',
#   '知道',
#   '有腦',
#   '人',
#   '幹',
#   '譙',
#   '民進黨',
#   '歸幹',
#   '譙',
#   '下次',
#   '投票',
#   '最',
#   '投',
#   '投給',
#   '心裡',
#   '奉',
#   '圭臬',
#   '那塊',
#   '垃圾',
#   '醒',
#   '回',
#   '祖國',
#   '是不是',
#   '慘啊',
#   '黑',
#   '民進黨',
#   '永遠',
#   '投某',
#   '垃圾',
#   '黨',
#   '抱歉',
#   '第一句',
#   '第三句',
#   '邏輯',
#   '完全',
#   '相反',
#   '典型',
#   '症狀',
#   '可憐',
#   '示範',
#   '內文',
#   '扯',
#   '喔',
#   '邏輯',
#   '真棒'],
#  ['好',
#   '小弟',
#   '買',
#   '東西',
#   '被叫',
#   '成',
#   '弟弟',
#   '已經',
#   'ㄍ',
#   '大學',
#   '森惹',
#   '知道',
#   '這種',
#   '外表',
#   '年輕',
#   '肥宅',
#   '有加',
#   '分',
#   'ㄇ'],
#  ['幾年',
#   'R',
#   '時不時',
#   '各大',
#   '社群',
#   '媒體',
#   '看到',
#   '辛苦',
#   '工地',
#   '人',
#   '辛苦',
#   '水電',
#   '師傅',
#   '努力',
#   '學徒',
#   '這類',
#   '標題',
#   '底下',
#   '嘴',
#   '坐',
#   '辦公室',
#   '年輕人',
#   '好逸惡勞',
#   '看不起',
#   '藍領',
#   '階級',
#   '再',
#   '嘴',
#   '一下',
#   '薪水',
#   '藍領',
#   '高',
#   '人',
#   '行政',
#   '職',
#   '領來',
#   '批鬥',
#   '拿來',
#   '師傅',
#   '級',
#   '圍個',
#   '小圈圈',
#   '自慰',
#   '好爽',
#   '想過',
#   '藍領',
#   '看不起',
#   'R',
#   '有沒有',
#   '同情',
#   '藍領',
#   '趨勢',
#   'DER',
#   '八卦',
#   '兄弟',
#   '藍領',
#   '瞧不起',
#   '低薪',
#   '白領',
#   '藍領',
#   '社會',
#   '唾棄',
#   '調調',
#   '在家',
#   '裡',
#   '上班',
#   '低階',
#   '白領'],
#  ['昨日',
#   '大林',
#   '電廠',
#   '加入',
#   '救援',
#   '行列',
#   '燈號',
#   '瞬間',
#   '從紅轉',
#   '橘',
#   '度',
#   '信徒',
#   '好像',
#   '甩',
#   '一個',
#   '耳光',
#   '好響',
#   '今日',
#   '下起',
#   '豪',
#   '大雨',
#   '更是',
#   '機會',
#   '度',
#   '信徒',
#   '限電',
#   '夢',
#   '是不是',
#   '醒'],
#  ['ㄤ',
#   '風箏',
#   '陰天',
#   '擱淺',
#   '想念',
#   '還在',
#   '等待',
#   '救援',
#   '文山',
#   '不太會',
#   '放風箏',
#   '風箏',
#   '飛',
#   '躺',
#   '地上',
#   '還要',
#   '笑',
#   '擱淺',
#   '放風箏',
#   '技巧',
#   '太爛',
#   'ㄅ',
#   '有掛'],
#  ['咖啡',
#   '套',
#   '蜂蜜',
#   '布',
#   '人試過',
#   '感覺',
#   '怪怪的',
#   '試試',
#   '覺得',
#   '人間',
#   '美味',
#   '是不是',
#   '超想',
#   '試',
#   '咖啡',
#   '套',
#   '蜂蜜',
#   'best',
#   'coffee'],
#  ['崩崩',
#   '爽歪歪',
#   '這盤',
#   '沒救',
#   '惹',
#   '年',
#   '新高',
#   '點位',
#   '能崩到',
#   '嘻嘻',
#   '有沒有',
#   '八卦',
#   '草本',
#   '綱目',
#   '聽過',
#   '本草綱目',
#   '萬點',
#   '時',
#   '咻',
#   '真',
#   'der',
#   '還好',
#   '草本',
#   '綱目',
#   '聽過',
#   '本草綱目'],
#  ['台灣',
#   '國際',
#   '視為',
#   '正常',
#   '國家',
#   '做起',
#   '事情',
#   '綁',
#   '手',
#   '綁腳',
#   '國家',
#   '定位',
#   '不明',
#   '容易',
#   '產出',
#   '吃裡',
#   '扒',
#   '外',
#   '商人',
#   '台灣',
#   '很棒',
#   '一點',
#   '不輸',
#   '日韓',
#   '平起平坐',
#   '本錢',
#   '重點',
#   '定位',
#   '明確',
#   '力量',
#   '獨立',
#   '不用',
#   '天天',
#   '中國',
#   '套',
#   '小鞋',
#   '一個',
#   '天天',
#   '被套',
#   '小鞋',
#   '人',
#   '能力',
#   '無法',
#   '得到',
#   '充份',
#   '釋放',
#   '美國',
#   '支',
#   '支持',
#   '辦法',
#   '說服',
#   '世界',
#   '國家',
#   '全部',
#   '支持',
#   '美國',
#   '吞下去',
#   '人因',
#   '夢想',
#   '偉大',
#   '東西',
#   '慢慢來',
#   '羅馬不是',
#   '一天',
#   '造成',
#   '天然',
#   '世代',
#   '掌權',
#   '勢頭',
#   '老人',
#   '總會',
#   '死',
#   '台灣',
#   '猛',
#   '地方',
#   '缺',
#   '世界',
#   '佔有',
#   '一席之地',
#   '你換',
#   '一個',
#   '角度',
#   '日韓',
#   '石油',
#   '運補',
#   '台灣',
#   '旁邊',
#   '哪裡爛',
#   '先',
#   '美不美',
#   '好',
#   '國家',
#   '決定',
#   '整天',
#   '威脅',
#   '套',
#   '小鞋',
#   '就要',
#   '這種',
#   '脫離',
#   '霸凌',
#   '過程',
#   '值得',
#   '獨立',
#   '後',
#   '一個',
#   '階段',
#   '長大',
#   '離開',
#   '爸',
#   '媽',
#   '比較',
#   '長大',
#   '後',
#   '小時候',
#   '景況',
#   '嘻嘻',
#   '日',
#   '韓客',
#   '臉色',
#   '決定',
#   '世界',
#   '小',
#   '中國',
#   '選擇',
#   '方向',
#   '沒聽',
#   '過贏',
#   '起跑點',
#   '至少',
#   '已經',
#   '贏在',
#   '起跑點',
#   '繼續',
#   '維持',
#   '不讓',
#   '中國',
#   '趕上',
#   '好',
#   '中國',
#   '不用',
#   '產業',
#   '幾項',
#   '贏',
#   '就夠',
#   '說得好',
#   '想',
#   '辦法',
#   '起飛',
#   '嘻嘻',
#   '選擇',
#   '獨立',
#   '不用',
#   '付出',
#   '代價',
#   '想要',
#   '選擇',
#   '獨立',
#   '雄',
#   '整天',
#   '胖虎',
#   '打壓',
#   '大雄',
#   '胖虎大雄',
#   '打壓',
#   '打壓',
#   '獨立',
#   '獨立',
#   '打壓',
#   '不想',
#   '獨立',
#   '軟弱',
#   '呈現',
#   '期待',
#   '中國',
#   '垮台',
#   '變成',
#   '民主制度',
#   '印度',
#   '亂',
#   '不用',
#   '嘻嘻',
#   'XD',
#   '好笑'],
#  ['下雨', '惹', '溫度', '降', '蔡', '政府', '解套', '台', '電解', '套', '安心', '開', '度'],
#  ['嘻哈是',
#   '嘻哈是',
#   '一種',
#   '態度',
#   '搖滾',
#   '搖滾',
#   '一種',
#   '態度',
#   '金屬',
#   '金屬',
#   '一種',
#   '態度',
#   '龐克',
#   '龐克',
#   '一種',
#   '態度',
#   '饒舌',
#   '饒舌',
#   '一種',
#   '態度',
#   '態度',
#   '帶有',
#   '批判',
#   '社會',
#   '態度',
#   '他媽',
#   '每次',
#   '問',
#   '這種',
#   '問題',
#   '得到',
#   '答案',
#   '好像',
#   '屌',
#   '膩嗎',
#   '好好',
#   '回答',
#   '名詞',
#   '定義',
#   '說',
#   '搖滾',
#   '態度',
#   '樂器',
#   '玩',
#   '搖滾',
#   '好',
#   '有沒有',
#   '八卦'],
#  ['政府',
#   '正',
#   '積極',
#   '推動',
#   '離岸',
#   '風電',
#   '建設',
#   '看看',
#   '離岸',
#   '風電',
#   '機組',
#   '一支',
#   '支',
#   '風機',
#   '矗立',
#   '海上',
#   '多麼',
#   '壯觀',
#   '大支',
#   '風電',
#   '機組',
#   '安裝',
#   '海上',
#   '何不',
#   '安裝',
#   '太陽能',
#   '板',
#   '相信',
#   '安裝',
#   '太陽能',
#   '板',
#   '建設',
#   '成本',
#   '應該',
#   '單價',
#   '風電',
#   '機組',
#   '便宜',
#   '台灣',
#   '島內',
#   '裝設',
#   '太陽能',
#   '電廠',
#   '土地',
#   '應該',
#   '接近',
#   '飽和',
#   '太陽能',
#   '板',
#   '風電',
#   '機組',
#   '不易',
#   '颱風',
#   '吹壞',
#   '發展',
#   '離岸',
#   '太陽能'],
#  ['幾個',
#   '星期',
#   '前',
#   '小盛',
#   '開台',
#   '開台',
#   '小時',
#   '抖內',
#   '好幾',
#   '鎂',
#   '算',
#   '打工',
#   '還賺',
#   '還要',
#   '打工',
#   '天天',
#   '開',
#   'lol',
#   '賺抖',
#   '賺',
#   '有沒有',
#   '卦'],
#  ['乳蹄',
#   '現在',
#   '治安',
#   '噗',
#   '好',
#   '防身術',
#   '重要',
#   '技能',
#   '節錄自',
#   '冉',
#   '時報',
#   '新聞',
#   '人力',
#   '銀行',
#   '刊登',
#   '美編',
#   '徵才',
#   '廣告',
#   '月薪',
#   '月',
#   '休',
#   '天',
#   '工作',
#   '內容',
#   '包含',
#   '巡邏',
#   '建築物',
#   '周遭',
#   '環境',
#   '保護',
#   '保全',
#   '之人',
#   '或物',
#   '安全',
#   '監視器',
#   '畫面',
#   '監看',
#   '出入',
#   '份子',
#   '給予',
#   '意圖',
#   '不良',
#   '人士',
#   '入侵者',
#   '警告',
#   '必要',
#   '時',
#   '使用',
#   '武力',
#   '看出',
#   '現在',
#   '職場',
#   '漸漸',
#   '第二',
#   '專長',
#   '轉為',
#   '需要',
#   '防禦',
#   '技能',
#   '人才',
#   '學會',
#   'RKO',
#   '雙手',
#   '扣住',
#   '對方',
#   '頸部',
#   '利用',
#   '全身',
#   '重量',
#   '對方',
#   '地面',
#   '順勢',
#   '摔倒',
#   '脖子',
#   '勢必會',
#   '斷掉',
#   '扣住',
#   '瞬間',
#   '掙脫',
#   '一定',
#   '吃',
#   '下',
#   '這招',
#   '危險',
#   '招式',
#   '人',
#   '模仿',
#   '學會',
#   'RKO',
#   '美編',
#   '人才',
#   '起薪',
#   '有沒有',
#   '八卦',
#   '肥肥',
#   '宅',
#   '好',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   '堅持',
#   '手打',
#   '簽名檔',
#   '設定',
#   '印章',
#   '檔',
#   '新聞',
#   '說',
#   '美編',
#   '職務',
#   '內容',
#   '包含',
#   '使用',
#   '武力',
#   '保護',
#   '公司',
#   '財產'],
#  ['早',
#   '夏天',
#   '台灣',
#   '政府',
#   '顯得',
#   '有點',
#   '焦頭爛額',
#   '一下',
#   '墾丁',
#   '觀光',
#   '雪崩',
#   '式',
#   '下跌',
#   '一下',
#   '限電',
#   '危機',
#   '先講',
#   '墾丁',
#   '觀光',
#   '部分',
#   '說',
#   '墾丁',
#   '特色',
#   '貴',
#   '墾丁',
#   '沖繩',
#   '限電',
#   '方面',
#   '政府',
#   '現在',
#   '重啟',
#   '核四',
#   '限電',
#   '問題',
#   '卻',
#   '焦頭爛額',
#   '能夠',
#   '一個',
#   '新',
#   '核災',
#   '話題',
#   '炒',
#   '勢必',
#   '是場',
#   '及時雨',
#   '肥宅',
#   '想',
#   '政府',
#   '現在',
#   '派',
#   '密使',
#   '中國',
#   '懇求',
#   '中共',
#   '找',
#   '一天',
#   '砲',
#   '墾丁',
#   '避開',
#   '核三廠',
#   '好',
#   '為習',
#   '包子',
#   '立威',
#   '核災',
#   '問題',
#   '勢必',
#   '再度',
#   '引起',
#   '討論',
#   '風向',
#   '勢必',
#   '反核',
#   '一面倒',
#   '之後',
#   '全民',
#   '關',
#   '冷氣',
#   '沒人敢',
#   '說',
#   '最後',
#   '墾丁',
#   '再',
#   '一陣子',
#   '砲',
#   '戰打',
#   '完',
#   '之後',
#   '戰地',
#   '風情',
#   '主題',
#   '號召',
#   '重振',
#   '觀光',
#   '阿共',
#   '砲',
#   '彈做',
#   '菜刀',
#   '墾丁',
#   '之後',
#   '特色',
#   '戰地',
#   '風情',
#   '本島',
#   '金門',
#   '之稱',
#   '沖繩',
#   '做出',
#   '市場',
#   '區隔',
#   '重振',
#   '觀光',
#   '產業',
#   '暗黑',
#   '兵法',
#   '請',
#   '墾丁',
#   '獻頭',
#   '之計',
#   '台灣',
#   '政府',
#   '解套',
#   'posted',
#   'from',
#   'bbs',
#   'reader',
#   'hybrid',
#   'on',
#   'my',
#   'HTC',
#   'M9u'],
#  ...]

# %% [markdown]
# - ## average word vec 平均

# %%
## load word2vec model
os.chdir("../")
os.getcwd()

### 把之前train好的word2vec的model load 進來
model = word2vec.Word2Vec.load('word2vec_model.CBOW')
# Out:
# 2020-02-19 11:22:43,713: INFO: loading Word2Vec object from word2vec_model.CBOW
# 2020-02-19 11:22:44,324: INFO: loading wv recursively from word2vec_model.CBOW.wv.* with mmap=None
# 2020-02-19 11:22:44,325: INFO: loading vectors from word2vec_model.CBOW.wv.vectors.npy with mmap=None
# 2020-02-19 11:22:44,393: INFO: setting ignored attribute vectors_norm to None
# 2020-02-19 11:22:44,395: INFO: loading vocabulary recursively from word2vec_model.CBOW.vocabulary.* with mmap=None
# 2020-02-19 11:22:44,396: INFO: loading trainables recursively from word2vec_model.CBOW.trainables.* with mmap=None
# 2020-02-19 11:22:44,396: INFO: loading syn1neg from word2vec_model.CBOW.trainables.syn1neg.npy with mmap=None
# 2020-02-19 11:22:44,472: INFO: loaded word2vec_model.CBOW

# %%
## filter words that not in word2vec's vocab
data_filtered = [[w for w in l if w in model.wv] for l in data]
data_filtered
# Out:
# [['韓瑜',
#   '協志',
#   '前妻',
#   '正',
#   '女演員',
#   '周子',
#   '瑜',
#   'TWICE',
#   '台灣',
#   '人',
#   '正',
#   '兩個',
#   '要當',
#   '鄉民',
#   '老婆',
#   '選',
#   '五樓',
#   '真',
#   '勇氣'],
#  ['dear',
#   'all',
#   '逢甲',
#   '碟仙',
#   '發生',
#   '民國',
#   '事情',
#   '一堆',
#   '大學生',
#   '玩',
#   '碟仙',
#   '後發',
#   'bbs',
#   '成功',
#   '預測',
#   '地震',
#   '小弟',
#   '預言',
#   '都還沒',
#   '出生',
#   '後面',
#   '說',
#   '預言',
#   '一百',
#   '兩岸',
#   '統一',
#   '統一',
#   '對岸',
#   '對岸',
#   '統一',
#   '應該',
#   '不用',
#   '猜',
#   '真的',
#   '存在',
#   '預言',
#   '這種',
#   '事情',
#   '倒底',
#   '被統',
#   '知道',
#   '資料庫',
#   '發文',
#   '日期',
#   '輕鬆',
#   '改變',
#   '拍照',
#   '狀況',
#   '下',
#   '碟仙',
#   '真的假',
#   '有沒有',
#   '科學',
#   '經驗',
#   '法則',
#   '破解',
#   '謠言',
#   '真實',
#   '八卦'],
#  ['晚上',
#   '好',
#   '預備',
#   '唱',
#   '風雲',
#   '山河',
#   '動',
#   '國軍',
#   '早上',
#   '唱',
#   '有沒有',
#   '相關',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Xiaomi',
#   'Redmi',
#   'Note'],
#  ['明天',
#   '早起',
#   '睡覺',
#   '旁邊',
#   'Youtube',
#   '眼睛',
#   '壞掉',
#   '有沒有',
#   '方法',
#   '早點',
#   '睡',
#   '掛',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'D10i'],
#  ['一段時間',
#   '注意',
#   'LOL',
#   '發現',
#   '各大',
#   'LOL',
#   '討論區',
#   '人數',
#   '明顯',
#   '下降',
#   '趨勢',
#   '實在',
#   '令人',
#   '驚訝',
#   '曾經',
#   '一時',
#   '遊戲',
#   '霸主',
#   '漸漸',
#   '過氣',
#   'LOL',
#   '確實',
#   '撐',
#   '久',
#   '現在',
#   '算',
#   '厲害',
#   '遊戲',
#   '玩久',
#   '會膩'],
#  ['總覺',
#   '每天',
#   '睡',
#   '睡覺時間',
#   '睡',
#   '不著',
#   '長時間',
#   '有沒有',
#   '相關',
#   '八卦',
#   '世界',
#   '大學排名',
#   'No.12',
#   'U',
#   'niversity',
#   'of',
#   'C',
#   'alifornia',
#   'L',
#   'os',
#   'ngeles',
#   '國立',
#   '台灣',
#   '大學'],
#  ['現在',
#   'messenger',
#   '好像',
#   '一個',
#   '新',
#   '功能',
#   '類似',
#   '日期',
#   '文字',
#   '出現',
#   '底線',
#   '再',
#   '點選',
#   '建立',
#   '計畫',
#   '以下',
#   '小魯',
#   '朋友',
#   '對話',
#   '原來',
#   '國慶'],
#  ['題',
#   '一堆',
#   '山路',
#   '天黑',
#   '後',
#   '路燈',
#   '矇',
#   '有人',
#   '一套',
#   '很長',
#   '鋼絲',
#   '綁',
#   '山壁',
#   '護欄',
#   '天亮',
#   '後'],
#  ['資料',
#   '上市公司',
#   '味全',
#   '公司',
#   '公司',
#   '提供',
#   '民國',
#   '年',
#   '月',
#   '單位',
#   '新台幣',
#   '仟',
#   '元',
#   '項目',
#   '營業',
#   '收入',
#   '淨額',
#   '本月',
#   '去年同期',
#   '增減',
#   '金額',
#   '增減',
#   '百分比',
#   '年',
#   '累計',
#   '去年',
#   '累計',
#   '增減',
#   '金額',
#   '增減',
#   '百分比',
#   '負的',
#   '單月',
#   '翻',
#   '正',
#   '滅頂',
#   '鄉民',
#   '臉',
#   '有沒有',
#   '腫腫',
#   '加油',
#   '月份',
#   '成長',
#   '表示',
#   '秒',
#   '買',
#   '秒',
#   '退',
#   '抵制',
#   '無效',
#   '業績',
#   '更好',
#   '不夠',
#   '腫',
#   '加油',
#   '拒買',
#   '好',
#   '大多數',
#   '人',
#   '行為',
#   '背道而馳',
#   '精確',
#   '地說',
#   '拒買',
#   '人',
#   '越來越少',
#   '囉',
#   '好好',
#   '堅持下去',
#   '呦',
#   '覺得',
#   '越來越',
#   '好',
#   '喔',
#   '加油',
#   '嘴',
#   '砲',
#   '鍵盤',
#   '滅頂',
#   '郎',
#   '他養',
#   '閒',
#   '義務',
#   '每個',
#   '月',
#   '更新',
#   '閒',
#   '更新',
#   '消息',
#   '味全'],
#  ['題',
#   '這篇文',
#   '月',
#   '號',
#   '唯一',
#   '一篇',
#   '金城武',
#   '文',
#   '今天',
#   '這篇',
#   '金城武',
#   '文就會',
#   '中斷',
#   '連續',
#   '一個多月',
#   '每天',
#   'PO',
#   '文',
#   '紀錄',
#   '金城武',
#   '知道',
#   '八卦',
#   '版有',
#   '紀錄',
#   'I',
#   'see',
#   'you'],
#  ['今年',
#   '指考',
#   '台大',
#   '機械',
#   '幹掉',
#   '學士',
#   '清大資',
#   '工資',
#   '台大',
#   '機械',
#   '收',
#   '人',
#   '比較',
#   '看板',
#   '潮',
#   '機械',
#   '悲傷',
#   '好',
#   '有無',
#   '八卦'],
#  ['本來',
#   '水管',
#   '搭',
#   '沒一搭',
#   '有人',
#   '放',
#   '現在',
#   '惹',
#   '第三季',
#   '還沒',
#   '看到',
#   '一半',
#   '想',
#   '請問',
#   '有無',
#   '鍛刀',
#   '大賽',
#   '八卦',
#   '看到',
#   '一季',
#   '感覺',
#   '全美',
#   '已經',
#   '上過',
#   '一直',
#   '洗',
#   '舊',
#   '面孔',
#   '知道',
#   '幹嘛'],
#  ['南部',
#   '高中',
#   '分數',
#   '好像',
#   '越來越低',
#   '相反',
#   '北部',
#   '高中',
#   '似乎',
#   '分數',
#   '越來越',
#   '高',
#   '請問',
#   '南一中',
#   '北北基',
#   '程度',
#   '高中',
#   '有板',
#   '中強'],
#  ['看到',
#   '頂尖',
#   '國立大學',
#   '圖書館',
#   '裡面',
#   '學生',
#   '一望無際',
#   '使',
#   '使用',
#   '蘋果',
#   '筆電',
#   '居多',
#   '蘋果',
#   '筆電',
#   '價格',
#   '六萬多',
#   '後',
#   '段',
#   '私校',
#   '學店',
#   '使用',
#   '東芝',
#   '取笑',
#   '有沒有',
#   '頂尖',
#   '國立大學',
#   '使用',
#   '蘋果',
#   '筆電',
#   '八卦'],
#  ['機師',
#   '聽說',
#   '月薪',
#   '一二十萬',
#   '說',
#   '開',
#   '飛機',
#   '很酷',
#   '但版',
#   '只',
#   '醫師',
#   '工程師',
#   '小弟',
#   '太',
#   '邊緣',
#   '身旁',
#   '走',
#   '這條',
#   '路',
#   '朋友',
#   '想',
#   '聽',
#   '相關',
#   '經驗',
#   '分享',
#   '一下',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'A9u'],
#  ['最近',
#   '出國',
#   '問到',
#   '人',
#   '從沒',
#   '保',
#   '說',
#   '刷卡',
#   '送',
#   '搭機',
#   '出事',
#   '航空公司',
#   '保',
#   '保',
#   '幹麻',
#   '故有',
#   '一問',
#   '旅行',
#   '國內',
#   '保',
#   '國外',
#   '不保',
#   '國內',
#   '不保',
#   '國外',
#   '保',
#   '刷卡',
#   '不用',
#   '保',
#   '國內外',
#   '保',
#   '宅',
#   '在家',
#   '保',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['嘻嘻',
#   '肥肥',
#   'ㄤ',
#   'ㄤ',
#   '我亞綸',
#   'ㄌ',
#   '小時候',
#   '聽說',
#   '手指',
#   '月亮',
#   '耳朵',
#   '割下來',
#   '那用',
#   '雞雞',
#   '指著',
#   '月亮',
#   '發生',
#   '事',
#   '嘻嘻',
#   '再',
#   '對準',
#   '月亮',
#   '手槍',
#   'JIZZ',
#   '超大',
#   '一炮',
#   '月亮',
#   'ㄅ',
#   '敬',
#   '發生',
#   '事',
#   '有木有',
#   '肥肥',
#   '知道'],
#  ['眾多',
#   '肥宅',
#   '單身',
#   '好',
#   '選擇',
#   '爭鮮',
#   '不開',
#   '小時',
#   '餵養',
#   '眾多',
#   '單身',
#   '肥宅',
#   '半夜',
#   '整家店',
#   '散發出',
#   '宅味',
#   '有沒有',
#   '八卦'],
#  ['之前',
#   '傳出',
#   '說',
#   '有人',
#   '使用',
#   '大學',
#   '宿網',
#   '下載',
#   'BT',
#   '抓',
#   '想',
#   '請問',
#   '現在',
#   '教育部',
#   '學術',
#   '網路',
#   '抓',
#   'BT',
#   '現在',
#   '人',
#   '使用',
#   '宿舍',
#   '網路',
#   '抓',
#   'BT',
#   '有沒有',
#   '使用',
#   '大學',
#   '宿舍',
#   '網路',
#   'BT',
#   '下載',
#   '抓',
#   '八卦'],
#  ['乳蹄',
#   '水之七島',
#   '美好',
#   '年代',
#   '六式',
#   '超越',
#   '人體',
#   '極限',
#   '超人',
#   '技能',
#   '鐵塊',
#   '武裝',
#   '色',
#   '壓制',
#   '用學',
#   '見聞',
#   '色',
#   '直接',
#   '躲',
#   '現在',
#   '職場',
#   '過勞',
#   '普遍',
#   '肝臟',
#   '修練',
#   '鐵塊',
#   '用紙',
#   '繪',
#   '躲',
#   '工作',
#   '月步',
#   '直接',
#   '窗戶',
#   '下班',
#   '主管',
#   '看到',
#   '剃',
#   '用來',
#   '捷運',
#   '關門',
#   '前',
#   '衝進去',
#   '覺得',
#   '挺',
#   '實用',
#   '技能',
#   '學會',
#   '六式',
#   '起薪',
#   '肥肥',
#   '宅',
#   '好',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   '堅持',
#   '手打',
#   '簽名檔',
#   '設定',
#   '印章',
#   '檔'],
#  ['之前',
#   '看過',
#   '幾個',
#   '爸爸媽媽',
#   '小寶寶',
#   '玩',
#   '看到',
#   '嘴巴',
#   '玩',
#   '屁股',
#   '應該',
#   '吃',
#   '一個',
#   'ㄅ',
#   'ㄛ',
#   'ㄅ',
#   'ㄛ',
#   'ㄅ',
#   'ㄛ',
#   '聲音',
#   '小',
#   '嬰兒',
#   '笑',
#   '超',
#   '開心',
#   '看過',
#   '好幾個',
#   '父母',
#   '阿公',
#   '阿嬤會',
#   '有沒有',
#   '大人',
#   '喜歡',
#   '吃',
#   '小',
#   '嬰兒',
#   '屁股',
#   '八卦'],
#  ['字',
#   '美的',
#   '男生',
#   '國考',
#   '申論題',
#   '有點',
#   '優勢',
#   '實在',
#   '想不出',
#   '妹有',
#   '優勢',
#   '以前',
#   '把妹',
#   '寫',
#   '情書',
#   '賣弄',
#   '文采',
#   '現在',
#   '用賴',
#   '打字',
#   '傳情',
#   '告白',
#   '字',
#   '美不美',
#   '字',
#   '美的',
#   '男生',
#   '是不是',
#   '把妹',
#   '方面',
#   '完全',
#   '優勢',
#   '可言'],
#  ['看到',
#   '推文',
#   '留言',
#   '會問',
#   '哪部',
#   '問是',
#   '嗆',
#   '聲',
#   '真的',
#   '想',
#   '知道',
#   '肥宅',
#   '發文',
#   '當成',
#   '作品',
#   '影射',
#   '幻想',
#   '沒人',
#   '相信',
#   '叔叔',
#   '度蜜月',
#   '經營',
#   '女僕',
#   '俱樂部',
#   '交給',
#   '打理',
#   '這種',
#   '故事'],
#  ['剛剛',
#   '本魯在',
#   '河濱',
#   '騎',
#   '腳踏車',
#   '聽到',
#   '消防車',
#   '聲音',
#   '好像',
#   '木柵',
#   '焚化爐',
#   '有沒有',
#   '發生',
#   '事',
#   '八卦'],
#  ['乳提',
#   '今天',
#   '可愛',
#   '女朋友',
#   '摸',
#   '完',
#   '雞雞',
#   '後',
#   '說',
#   '好',
#   '想',
#   '懶覺',
#   '博物館',
#   '參觀',
#   '雞雞',
#   '喔',
#   '知道',
#   '哪裡',
#   '懶覺',
#   '博物館',
#   '請問',
#   'Ecup',
#   '給窩',
#   '一點',
#   '意見',
#   'PTT',
#   'Perfume',
#   'desu',
#   'あ',
#   'ち',
#   'ゃ',
#   'ん',
#   'か',
#   'し',
#   'ゆ',
#   'か',
#   'の',
#   'っ',
#   'ち',
#   'ψ',
#   '___',
#   '____',
#   '兩個',
#   '齁',
#   '窩還',
#   '不想',
#   '睡',
#   '有點',
#   '奇怪',
#   '說',
#   '想',
#   '動物',
#   '覽',
#   '有點',
#   '擔心'],
#  ['北韓',
#   '已經',
#   '嗆',
#   '聲',
#   '八月',
#   '四顆',
#   '飛彈',
#   '關島',
#   '附近',
#   '海域',
#   '飛彈',
#   '路徑',
#   '日本',
#   '本土',
#   '試想',
#   '飛彈',
#   '國土',
#   '飛過',
#   '根本',
#   '眼裡',
#   '日本',
#   '採取',
#   '措施',
#   '是否',
#   '啟動',
#   '飛彈',
#   '防禦',
#   '系統',
#   '北韓',
#   '飛彈',
#   '下來'],
#  ['台北',
#   '學生',
#   '懂',
#   '中南部',
#   '學生',
#   '來說',
#   '大學',
#   '台北',
#   '唸書',
#   '一個',
#   '字',
#   '邱',
#   '現在',
#   '回家',
#   '還會',
#   '聽到',
#   '爸爸',
#   '街坊鄰居',
#   '炫耀',
#   '兒子',
#   '台北',
#   '欸',
#   '台北',
#   '唸書',
#   '真的',
#   '比較',
#   '厲害',
#   '聽',
#   '比較',
#   '厲害',
#   '有沒有',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'iPhone'],
#  ['乳題', '大學', '科系', '千百種', '天堂', '糞系', '進', '糞坑', '系才', '糞系', '中', '霸主'],
#  ['本魯',
#   '預計',
#   '開學',
#   '後',
#   '一週',
#   '日本',
#   '玩',
#   '開學',
#   '後',
#   '一週',
#   '不想',
#   '肥宅',
#   '擠',
#   '同班',
#   '飛機',
#   '臭味',
#   '臭死',
#   '有錢',
#   '爺',
#   '下',
#   '要來',
#   '決定',
#   '哪家',
#   '航空',
#   '華航',
#   '換',
#   '制服',
#   '後',
#   'low',
#   '掉',
#   '長榮',
#   '制服',
#   '不錯',
#   '曲線',
#   '背後',
#   '優',
#   '香草',
#   '太像',
#   '百事',
#   '達',
#   '配色',
#   '老虎',
#   '制服',
#   '包覆',
#   '性',
#   '不錯',
#   '全日',
#   '顏色',
#   '黑橘',
#   '配色',
#   '做',
#   '高鐵',
#   '日本',
#   '空姐',
#   '很大',
#   '一坨',
#   '樂桃',
#   '顏色',
#   '不錯',
#   '拆',
#   '禮物',
#   '感覺',
#   '國泰',
#   '太像',
#   '銀行',
#   '櫃檯',
#   '鄉民',
#   '會選',
#   '哪家',
#   '航空'],
#  ['八卦',
#   '版',
#   '六星',
#   '安安',
#   '小肥',
#   '新訓',
#   '用餐',
#   '時',
#   '一定',
#   '有人',
#   '掉',
#   '筷子',
#   '班長',
#   '聽到',
#   '掉',
#   '好像',
#   '中邪',
#   '馬上開',
#   '噴',
#   '還要',
#   '面',
#   '大喊',
#   '筷子',
#   '我愛你',
#   '十遍',
#   '感覺',
#   '好',
#   '小學生',
#   '不禁',
#   '想著',
#   '真的',
#   '捍衛',
#   '國家',
#   '軍人',
#   '有沒有',
#   '新訓',
#   '掉',
#   '筷子',
#   '八卦',
#   '知道',
#   '營長',
#   '掉',
#   '筷子',
#   '有沒有',
#   '撿',
#   '意思',
#   '嘻嘻'],
#  ['子瑜',
#   'twice',
#   '實勢',
#   'twice',
#   '支柱',
#   'twice',
#   '少女時代',
#   '並列',
#   '韓國',
#   '第一',
#   '女團',
#   '子瑜',
#   '很大',
#   '功勞',
#   '人',
#   '說子',
#   '瑜',
#   '本錢',
#   '單飛',
#   '說',
#   '事實',
#   '討厭',
#   '子瑜'],
#  ['有沒有',
#   '那種',
#   '嬰兒',
#   '肥',
#   '卻',
#   '娃娃臉',
#   '娃娃臉',
#   '嬰兒',
#   '肥',
#   '共存',
#   '鄧紫棋',
#   'Selina',
#   '徐佳瑩',
#   '分不太'],
#  ['反核',
#   '覺青',
#   '現在',
#   '最強',
#   '招式',
#   '燃料',
#   '你家',
#   '肥宅',
#   '覺得',
#   '燃料',
#   '棒',
#   '放到',
#   '國家',
#   '好',
#   '一定',
#   '缺錢',
#   '國家',
#   '錢給',
#   '買',
#   '國家',
#   '空間',
#   '放',
#   '燃料',
#   '棒',
#   '問題',
#   '解決',
#   '核電',
#   '重啟',
#   '台灣',
#   '缺點',
#   '問題',
#   '解決',
#   '冷氣',
#   '吹',
#   '台積電',
#   '出走',
#   '繼續',
#   '救台灣',
#   '二來',
#   '買賣',
#   '貪污',
#   '空間',
#   '政客',
#   '賺頭',
#   '現在',
#   '吃',
#   '送',
#   '錢',
#   '邦交國',
#   '搞不好',
#   '幾個',
#   '雙贏',
#   '核電',
#   '燃料',
#   '棒',
#   '國家',
#   '買',
#   '空間',
#   '放',
#   '好',
#   '有沒有',
#   '相關',
#   '八卦'],
#  ['本宅',
#   '今日',
#   '久違',
#   '健身房',
#   '運動',
#   '剛剛',
#   '發生',
#   '一件',
#   '驚訝',
#   '事情',
#   '本宅',
#   '喝水',
#   '休息',
#   '時',
#   '無意間',
#   '看到',
#   '旁邊',
#   '做',
#   '一個',
#   '器材',
#   '人',
#   '行為',
#   '奇怪',
#   '手機',
#   '一直',
#   '呈現',
#   '拍照',
#   '模式',
#   '本宅',
#   '不以',
#   '為意',
#   '之後',
#   '發現',
#   '根本',
#   '無意',
#   '運動',
#   '臉上',
#   '神情',
#   '奇怪',
#   '原來',
#   '一直',
#   '偷拍',
#   '斜對面',
#   '幾個',
#   '很壯',
#   '男生',
#   '發現',
#   '怪異',
#   '假裝',
#   '運動',
#   '音量',
#   '鍵',
#   '拍照',
#   '有沒有',
#   '健身房',
#   '旁邊',
#   '男生',
#   '卦'],
#  ['相信',
#   '人',
#   '已經',
#   '知道',
#   '英文版',
#   'PTT',
#   'Reddit',
#   '日文版',
#   '好像',
#   '有沒有',
#   '中國',
#   '版',
#   'PTT',
#   '貼',
#   '算是',
#   '之前',
#   '逛',
#   '感覺',
#   '比較',
#   'Dcard',
#   '八卦',
#   '版',
#   '一個',
#   '咧',
#   '好奇',
#   '想',
#   '逛逛',
#   '天涯',
#   '水木',
#   '咧',
#   '只好',
#   '逛',
#   '囉'],
#  ['日本',
#   '早期',
#   'P2P',
#   '神器',
#   '又稱',
#   '雪兒',
#   '笑臉',
#   '男',
#   '我國',
#   '高中',
#   '抓',
#   '日本',
#   '稀有',
#   '資源',
#   '現在',
#   '好像',
#   '已經',
#   '沒落',
#   '有沒有',
#   '日本',
#   'P2P',
#   '神器',
#   '八卦'],
#  ['乳題',
#   '好像',
#   '體驗',
#   'XX',
#   '感覺',
#   '之前',
#   '玩楓',
#   '之谷',
#   '有人',
#   '名聲',
#   '有沒有',
#   '感覺',
#   '卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'X00DDA',
#   '平常',
#   '懶得',
#   '貼',
#   '新聞',
#   '哭哭',
#   '稜',
#   '森好',
#   '難',
#   '平衡',
#   '壞'],
#  ['最近',
#   '宋',
#   '淒厲',
#   '重出江湖',
#   '還出',
#   '本書',
#   '說',
#   '用書',
#   '身體',
#   '住',
#   '用書',
#   '隔空',
#   '推倒',
#   '推倒',
#   '妹妹',
#   '倒',
#   '說',
#   '佛性',
#   '不夠',
#   '看不見',
#   '分身',
#   '叫做',
#   '悟性',
#   '未開',
#   '有沒有',
#   '人',
#   '體驗',
#   '威力',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Samsung',
#   'SMG720AX'],
#  ['本魯邊',
#   '看著',
#   '女子',
#   '團體',
#   '音樂',
#   '影片',
#   '看到',
#   '大腿',
#   '好奇',
#   '女生',
#   '大腿',
#   '摸起來',
#   '感覺',
#   '有沒有',
#   '八卦'],
#  ['品牌',
#   '電腦',
#   '主打',
#   '方便',
#   '機子',
#   '問題',
#   '保固',
#   '免費',
#   '幫',
#   '處理',
#   '好',
#   '不用',
#   '還要',
#   '除錯',
#   '浪費',
#   '一堆',
#   '時間',
#   '尤其',
#   '脫離',
#   '學生',
#   '身份',
#   '後',
#   '更是',
#   '心力',
#   '搞',
#   '人',
#   '喜歡',
#   '追求',
#   'CP',
#   '值',
#   '組裝',
#   '認為',
#   '買',
#   '品牌',
#   '電腦',
#   '盤子',
#   '有沒有',
#   '品牌',
#   '電腦',
#   '八卦',
#   '組',
#   '電腦',
#   '樂趣',
#   '但出',
#   '問題',
#   '幹',
#   '內文',
#   '重點',
#   '組',
#   '售後',
#   '維修',
#   '大哥'],
#  ['事情',
#   '低能',
#   '卡',
#   '最近',
#   '一個',
#   '甲甲',
#   '跑',
#   '捐血',
#   '捐',
#   '就森',
#   '低能',
#   '彩虹',
#   '版討',
#   '拍',
#   '噴到',
#   '不像話',
#   '不乏',
#   '一堆',
#   '低能',
#   '同溫層',
#   '護航',
#   '那種',
#   '揪',
#   '捐血',
#   '好像',
#   '血',
#   '貴',
#   '豆頁',
#   '痛',
#   '小弟',
#   '發',
#   '一篇',
#   '甲血甲用',
#   '避免',
#   '玻璃',
#   '公平',
#   '改成',
#   '幹有',
#   '一個',
#   '學店',
#   '仔',
#   '一直',
#   '跳針',
#   '中山',
#   '真心',
#   '求解',
#   '甲血甲用',
#   '真的',
#   '實施',
#   '破綻',
#   '攻破'],
#  ['高中',
#   '畢旅去',
#   '義大',
#   '世界',
#   '後',
#   '再',
#   '去過',
#   '國內',
#   '遊樂園',
#   '小時候',
#   '劍湖山',
#   '國',
#   '中小',
#   '畢旅',
#   '九族',
#   '文化村',
#   '麗寶',
#   '樂園',
#   '六福村',
#   '小人國',
#   '好像',
#   '補習班',
#   '去過',
#   '沒什麼',
#   '特別',
#   '憧憬',
#   '會想',
#   '說',
#   '地方',
#   '乖乖',
#   '存錢',
#   '迪士尼',
#   '上海',
#   '環球',
#   '影城',
#   '樂天',
#   '遊樂園',
#   '知道',
#   '覺得',
#   '臺灣',
#   '遊樂園',
#   '無聊',
#   '懂',
#   '人',
#   '想',
#   '門票',
#   '錢',
#   '再加',
#   '一下',
#   'HK'],
#  ['最近', '聽到', '一首歌', '年', '翻唱', '知道', '有人', '聽過', '好聽'],
#  ['餓死',
#   '抬頭',
#   '小弟',
#   '看到',
#   '一些',
#   '帥哥美女',
#   '臥蠶',
#   '像是',
#   '版上',
#   '各地',
#   '小弟',
#   '偶像',
#   '趙',
#   '麗穎',
#   '說',
#   '是不是',
#   '臥',
#   '比較',
#   '好看',
#   '蠶',
#   '一堆',
#   '帥哥',
#   '美女',
#   '有沒有',
#   '八卦',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['現在',
#   '人',
#   '電話號碼',
#   '記在',
#   '手機',
#   '通訊',
#   '軟體',
#   '人會',
#   '背',
#   '一堆',
#   '聯絡',
#   '親朋好友',
#   '電話號碼',
#   '前',
#   '幾天',
#   '長輩',
#   '玩',
#   '一個',
#   '遊戲',
#   '背',
#   '記得',
#   '親朋好友',
#   '電話號碼',
#   '發現',
#   '老一輩',
#   '真是',
#   '強',
#   '連前',
#   '幾任',
#   '里長',
#   '電話號碼',
#   '倒背如流',
#   '真是',
#   '強到',
#   '優點',
#   '手機',
#   '不在',
#   '身邊',
#   '時',
#   '緊急',
#   '聯絡',
#   '時',
#   '方便',
#   '防止',
#   '老人',
#   '痴呆',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z017DA'],
#  ['覺得',
#   '爆',
#   '公平',
#   '耶',
#   '人',
#   '推文數',
#   '爆',
#   '推文',
#   '正好',
#   '爆',
#   '一些',
#   '歷史',
#   '廢文',
#   '終結',
#   '時間',
#   '洪流',
#   '裡',
#   '一起',
#   '發起',
#   '推',
#   '文才',
#   '爆',
#   '運動',
#   '好',
#   '鋪',
#   '好',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['本魯',
#   '甲甲',
#   '母豬',
#   '一個',
#   '善良',
#   '肥宅',
#   '最近',
#   '發現',
#   '好',
#   '玻璃心',
#   '辦法',
#   '接受',
#   '負面',
#   '批評'],
#  ['超級',
#   '歪',
#   '超級',
#   '歪',
#   '一個',
#   '台灣',
#   'youtuber',
#   '一個月',
#   '一部',
#   '一部',
#   '資訊',
#   '量',
#   '超多',
#   '後面',
#   '列出',
#   '書單',
#   '不知',
#   'youtuber',
#   '平常',
#   '維生',
#   '書單',
#   '面向',
#   '不知',
#   '讀',
#   '科系',
#   '有沒有',
#   '超級',
#   '歪',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Sony',
#   'D6503'],
#  ['晚上',
#   '好',
#   '一個',
#   '朋友',
#   '朋友',
#   '跟前',
#   '幾天',
#   '熱炒',
#   '店',
#   '喝酒',
#   '醉到',
#   '不省人事',
#   '隔天',
#   '床上',
#   '一絲不掛',
#   '想',
#   '請問',
#   '知道',
#   '有沒有',
#   '肛過',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z00LD'],
#  ['新聞',
#   '改成',
#   '賣',
#   '電子版',
#   '似乎',
#   '貼心',
#   '方便',
#   '粉絲',
#   '空',
#   '右手',
#   '喔',
#   '方便',
#   '收藏',
#   '一本',
#   '半夜',
#   '開賣',
#   '半個',
#   '小時',
#   '賣完',
#   '半夜',
#   '賣',
#   '電子版',
#   '不知',
#   '賣',
#   '幾本',
#   '有無',
#   '八卦'],
#  ['剛剛',
#   'youtube',
#   '收斂',
#   '遊戲王',
#   '幹',
#   '無名',
#   '龍',
#   '效果',
#   '太',
#   '唬爛',
#   '融合',
#   '效果',
#   '說了算',
#   '根本',
#   '作弊',
#   '狗',
#   '明明',
#   '名字',
#   '亂叫',
#   '一通',
#   '有沒有',
#   '無名',
#   '龍',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'iPhone'],
#  ['囧',
#   '哞',
#   '辦',
#   'ㄍ',
#   '女森',
#   '網友',
#   '一直',
#   '要約',
#   '倫家',
#   '明明',
#   'ㄉ',
#   '體重',
#   '破',
#   '兩百',
#   '身高',
#   'ㄧ',
#   '米',
#   '倫家',
#   '木訥',
#   '想',
#   '找',
#   'ㄘ',
#   '飯飯',
#   'ㄇ',
#   '倫家',
#   '認識',
#   '男女生',
#   '比例',
#   '迪卡',
#   '女生',
#   '卡友',
#   'ㄍ',
#   '不太敢',
#   '女森',
#   '說',
#   '辣',
#   '我會',
#   '害羞',
#   '宅宅',
#   '低頭',
#   '不敢',
#   '女森',
#   '狂',
#   '抬頭',
#   '仰望',
#   '陽光',
#   '素',
#   'ㄅ',
#   '請',
#   '交交',
#   '偶好',
#   '想',
#   'ㄘ',
#   '辣辣',
#   'ㄉ',
#   '麵',
#   '麵',
#   '倫家',
#   'ㄘ',
#   '飯飯'],
#  ['帥',
#   '正太',
#   '好像',
#   '長',
#   '歪',
#   '惹',
#   '照片',
#   '還會',
#   '聯想',
#   '王思聰',
#   '那種',
#   '表情',
#   '有錢人',
#   '小孩',
#   '最終',
#   '氣質',
#   '髮型',
#   '關係',
#   '長',
#   '歪'],
#  ['從小到大',
#   '人生',
#   '越來越',
#   '痛苦',
#   '越來越',
#   '難',
#   '活著',
#   '真的',
#   '好',
#   '痛苦',
#   '勇氣',
#   '死',
#   '感覺',
#   '好痛',
#   '好',
#   '想',
#   '逃避',
#   '直接',
#   '逃跑',
#   '逃跑',
#   '難堪',
#   '準備',
#   '開天窗',
#   '倒數',
#   '明天',
#   '就要',
#   '開天窗',
#   '好',
#   '想',
#   '死',
#   '一死',
#   '種',
#   '人生',
#   '越來越',
#   '難',
#   '轉',
#   '教教'],
#  ['看到',
#   '那群',
#   '固定',
#   'id',
#   '蓋樓',
#   'ptt',
#   '辦法',
#   '巴哈',
#   '蓋',
#   '幾千幾萬',
#   '樓',
#   '肥宅',
#   '推',
#   '謝謝'],
#  ['好',
#   '窩',
#   '喜歡',
#   '喝',
#   '香菇',
#   '雞湯',
#   '如題',
#   '剛剛',
#   '小學',
#   '照片',
#   '一張',
#   '玩',
#   '武力',
#   'CS',
#   '這款',
#   '遊戲',
#   '突然',
#   '想起',
#   '這款',
#   '遊戲',
#   '當時',
#   '超多人',
#   '玩',
#   '想',
#   '一直',
#   '刷',
#   '一直',
#   '刷刷',
#   '軍階',
#   '元帥',
#   '他媽的',
#   '每次',
#   '直升機',
#   '轟炸',
#   '剛剛',
#   'google',
#   '重溫',
#   '一下',
#   '小學',
#   '回憶',
#   '一點',
#   '沒變',
#   '刷',
#   '不到',
#   '元帥',
#   '想',
#   '宅們',
#   '刷',
#   '元帥',
#   '過嗎',
#   '乾五',
#   '八卦',
#   '覺得',
#   '不用',
#   '瞄準',
#   '比較',
#   '好',
#   '殺'],
#  ['肥宅',
#   '晚安',
#   '前',
#   '幾個',
#   '月',
#   '我家',
#   '附近',
#   '上達',
#   '倒',
#   '再',
#   '一陣子',
#   '連我',
#   '阿嬤家',
#   '附近',
#   '開',
#   '多年',
#   '不住',
#   '倒',
#   '惹',
#   '不爭氣',
#   '閱讀',
#   '習慣',
#   '改變',
#   '造成'],
#  ['幾天',
#   '全',
#   '台',
#   '各地',
#   '公務',
#   '機關',
#   '共體',
#   '時艱',
#   '關',
#   '冷氣',
#   '守護',
#   '限電',
#   '真是太',
#   '感人',
#   '小弟',
#   '公務員',
#   '卻',
#   '體認',
#   '大大的',
#   '辛勞',
#   '小弟',
#   '工作',
#   '進',
#   '倉庫',
#   '理貨',
#   '夏天',
#   '只',
#   '有出',
#   '太陽',
#   '白天',
#   '進',
#   '密不透風',
#   '倉庫',
#   '小時',
#   '上衣',
#   '全濕',
#   '想',
#   '窗戶',
#   '辦',
#   '應該',
#   '同樣',
#   '概念',
#   '好',
#   '今天',
#   '禁令',
#   '解除',
#   '冷氣',
#   '吹',
#   '出現',
#   '一個',
#   '新',
#   '問題',
#   '困擾',
#   '原以',
#   '今天',
#   '用電量',
#   '暴增',
#   '減少',
#   '是不是',
#   '解禁',
#   '說法',
#   '原因',
#   '不敢',
#   '開',
#   '冷氣',
#   '台電',
#   '網站',
#   '突然',
#   '修正',
#   'bug',
#   '發現',
#   '以前',
#   '算錯'],
#  ['學校',
#   '附近',
#   '看到',
#   '一群',
#   '人',
#   '阿北',
#   '類似',
#   '板上',
#   '肥宅',
#   '走進',
#   '一看',
#   '抓',
#   '寶',
#   '已經',
#   '過氣',
#   '有卦'],
#  ['看到',
#   '前面',
#   '有人',
#   '討論',
#   'AI',
#   '星海',
#   '打贏',
#   '人類',
#   '曉得',
#   'AI',
#   '作弊',
#   '情況',
#   '下',
#   '世紀',
#   '最難',
#   '電腦',
#   '似乎',
#   '資源',
#   '一對一',
#   '打得贏',
#   '人類',
#   '世界冠軍'],
#  ['東離',
#   '劍',
#   '遊記',
#   '粉',
#   '看到',
#   '新',
#   '漫畫',
#   '動漫展',
#   '打算',
#   '明天',
#   '買',
#   '這是',
#   '第一次',
#   '參加',
#   '動漫展',
#   '之前',
#   '去過',
#   '動漫展',
#   '會差',
#   '第一次',
#   '參加',
#   '有沒有',
#   '注意事項',
#   '說真的'],
#  ['題', '老伯', '家', '籃框', '變好', '高', '老伯', '魔力', '卦', '__', '小', '覺得'],
#  ['一定',
#   '納粹',
#   '相同',
#   '理念',
#   '國家',
#   '共產',
#   '法西斯',
#   '有沒有',
#   '年',
#   '之內',
#   '出現',
#   '一個',
#   '強國',
#   '侵略',
#   '侵占',
#   '土地',
#   '知道',
#   '美國',
#   '目前',
#   '應該',
#   '直接',
#   '派兵',
#   '侵略',
#   '地方',
#   '試圖',
#   '該地',
#   '變成',
#   '領土',
#   '不算',
#   '有沒有',
#   '出現',
#   '一個',
#   '國家',
#   '機會',
#   '軍力',
#   '強佔',
#   '土地',
#   '成功',
#   '鴨',
#   '鴨',
#   '卡卡',
#   '正常',
#   '推文',
#   'Gossiping'],
#  ['上台',
#   '政治',
#   '開心',
#   '難過',
#   '政治系',
#   '幹嘛',
#   '先',
#   '台大',
#   '找',
#   '男朋友',
#   '養',
#   'ps',
#   '幫別人',
#   '問',
#   '喔',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'D826y'],
#  ['原本',
#   'X',
#   '記',
#   '麻',
#   '糬',
#   '有名',
#   '伴',
#   '手禮',
#   '今天',
#   '新聞',
#   '報',
#   '特報',
#   '根本',
#   '免費',
#   '廣告',
#   '幾天',
#   '曉得',
#   '銷售量',
#   '大增',
#   'X',
#   '記',
#   '麻',
#   '糬',
#   '這次',
#   'F16',
#   '最大',
#   '贏家',
#   '有沒有',
#   '相關',
#   '八卦',
#   '推',
#   'Israfil',
#   '慘',
#   '推',
#   'wyvernlee',
#   '嗆',
#   '五樓',
#   '嗆夠',
#   '推',
#   'maple0425',
#   '幫五樓',
#   'QQ',
#   '推',
#   'meowchen',
#   '樓下',
#   '幫轉',
#   '邊緣',
#   '人板',
#   'Fanchiang',
#   '早點',
#   '死',
#   '一死'],
#  ['假設', '有個', '魯蛇', '找', '工作', '只能', '領', '最低', '時薪', '最低', '底薪', '比較', '好'],
#  ['乳題',
#   '本肥宅',
#   '最近',
#   '滑',
#   'FB',
#   '偷看',
#   '正妹',
#   '照片',
#   '發現',
#   '突然',
#   '通知',
#   '本肥',
#   'J',
#   'Der',
#   '奇怪',
#   '姨',
#   '朋友',
#   '妹油',
#   '什摸會',
#   '通知',
#   '本肥',
#   '一看',
#   '笑靨',
#   '如花',
#   '正妹',
#   '送',
#   '交友',
#   '邀請',
#   '想作',
#   '本肥',
#   '捧',
#   '油',
#   '本肥',
#   '毫不猶豫',
#   '加',
#   '本肥',
#   '太',
#   '害羞',
#   '不敢',
#   '訊息',
#   '給新',
#   '正妹',
#   '捧',
#   '油',
#   '只能',
#   '默默',
#   '心中',
#   '意淫',
#   '隔',
#   '一天',
#   '一個',
#   '正妹',
#   '想',
#   '當本肥',
#   '捧',
#   '油',
#   '本肥',
#   '猶豫',
#   '太',
#   '花心',
#   '正妹',
#   '笑容',
#   '融化',
#   '本肥',
#   '油膩',
#   '心',
#   '本肥',
#   '只好',
#   '再加',
#   '好友',
#   '現在',
#   '本肥',
#   '正妹',
#   '捧',
#   '油',
#   '兩天',
#   '本肥',
#   '再次',
#   '收到',
#   '交友',
#   '邀請',
#   '正妹',
#   '本肥',
#   '真的',
#   'J',
#   'DER',
#   '太夯',
#   '肚子',
#   '驕傲',
#   '挺起來',
#   '懷孕',
#   '驕傲',
#   '正妹',
#   '想',
#   '好友',
#   '八卦',
#   'PS',
#   '正妹',
#   '外國',
#   '正妹',
#   '名字',
#   '好長',
#   '一堆',
#   '字母',
#   '念',
#   '相信',
#   '一定',
#   '靈魂',
#   '溝通',
#   '特',
#   '問君',
#   '幾多',
#   '魯',
#   '一條',
#   '魯蛇',
#   '向東',
#   '蠕',
#   '問君',
#   '何能爾',
#   '臉醜',
#   '人',
#   '自魯'],
#  ['反核',
#   '人士',
#   '最愛',
#   '妖',
#   '核電廠',
#   '蓋',
#   '你家',
#   '好不好',
#   '說好',
#   '核廢料',
#   '放',
#   '我家',
#   '好不好',
#   'ok',
#   '放在',
#   '地下室',
#   '就行了',
#   '火力發電',
#   '燒完',
#   '渣',
#   '渣',
#   '放射性物質',
#   '放',
#   '你家',
#   '現在',
#   '搬',
#   '龍井',
#   '住',
#   '試',
#   '看看',
#   '拎',
#   '北',
#   '去核',
#   '三廠',
#   '養老',
#   '認識',
#   '一些',
#   '老頭',
#   '在裡',
#   '面過',
#   '爽爽',
#   '全部',
#   '電腦',
#   '監控',
#   '沒事',
#   '做',
#   '換',
#   '燃料',
#   '棒',
#   '火力發電',
#   '燒',
#   '重油',
#   '燒煤',
#   '看看',
#   '一個',
#   '人',
#   '一生',
#   '咪咪',
#   '燃料',
#   '棒',
#   '搞定',
#   '火力發電',
#   '要燒',
#   '幾公斤',
#   '反核',
#   '人士',
#   '冷氣',
#   '開',
#   '爽爽',
#   '交換',
#   '住',
#   '台',
#   '中要',
#   '來試',
#   '看看',
#   '我住',
#   '靠近',
#   '東海',
#   '住',
#   '沙鹿',
#   '龍井',
#   '你家',
#   '哪條',
#   '路上',
#   '拍張',
#   '身分證',
#   '一堆',
#   '嘴',
#   '砲',
#   '去過',
#   '台',
#   '中',
#   '龍井',
#   '核電廠',
#   '根本',
#   '養老',
#   '天堂',
#   '轉機',
#   '老頭',
#   '鍵盤',
#   'IP',
#   '喔',
#   '拍',
#   '路牌',
#   'OK',
#   '查',
#   '家族',
#   '我講',
#   '認真',
#   '火力發電',
#   '垃圾',
#   '擔心',
#   '地方',
#   '放',
#   '接收',
#   '樂意',
#   '接收',
#   '核廢料',
#   '等價交換',
#   '覺得',
#   '少廢話',
#   '找',
#   '電廠',
#   '談',
#   '家',
#   '火力發電',
#   '談起',
#   'OK',
#   '燃料',
#   '棒',
#   '來說',
#   '經濟',
#   '價值',
#   '願意',
#   '電廠',
#   '給我',
#   '火力發電廠',
#   '談',
#   '請',
#   '送',
#   '灰燼'],
#  ['人',
#   '小花',
#   '黏上去',
#   '請問',
#   '一下',
#   '有人',
#   '真的',
#   '黏',
#   '一起',
#   '整個',
#   '視窗',
#   '黏得',
#   '滿滿的',
#   '照片',
#   '看不到',
#   '有人',
#   '經驗',
#   '謝謝'],
#  ['常上',
#   '新聞',
#   '龍捲風',
#   '感覺',
#   '剃',
#   '鬍子',
#   '節目',
#   '個人感覺',
#   '真的',
#   'style',
#   '掛著',
#   '生物',
#   '老師',
#   '名稱',
#   '節目',
#   '好像',
#   '講過',
#   '生物',
#   '領域',
#   '東西',
#   '北一女',
#   '生物',
#   '老師',
#   '八卦'],
#  ['前',
#   '陣子',
#   '小魯',
#   '路過',
#   '台',
#   '中',
#   '火車站',
#   '附近',
#   '酒廠',
#   '逛',
#   '驚為',
#   '天人',
#   '潮度',
#   '似乎',
#   '突破',
#   '高雄駁',
#   '破',
#   '錶',
#   '出水',
#   '惹',
#   '好像',
#   '人潮',
#   '有沒有',
#   '這方面',
#   '八卦'],
#  ['豪',
#   '小弟',
#   '今天',
#   '超市',
#   '買',
#   '一盒',
#   '衛生棉',
#   '回家',
#   '研究',
#   '理解',
#   '沒錯',
#   '黏在',
#   '內褲',
#   '接',
#   '藍色',
#   '經血',
#   '小弟',
#   '轉念',
#   '一想',
#   '尿布',
#   '只',
#   '是從',
#   '改成',
#   '實際上',
#   '有沒有',
#   '衛生棉',
#   '尿布',
#   '變形',
#   '八卦',
#   '阿是',
#   '買',
#   '逆',
#   '好奇心',
#   '強阿',
#   '知道',
#   '黏',
#   '內褲',
#   '黏到',
#   '毛',
#   '超痛'],
#  ['OL', '下班', '後', '穿', '一整天', '絲襪', '發酵', '一整天', '廚餘', '比較', '嘻嘻'],
#  ['蹦',
#   '啾',
#   '妹魯喜',
#   '波',
#   '那佩梯',
#   'KTV',
#   '唱歌',
#   '現代',
#   '平常',
#   '休閒活動',
#   '慎選',
#   '同伴',
#   '重要',
#   '愉快',
#   '消磨',
#   '時間',
#   '選錯',
#   '時間',
#   '久',
#   '最',
#   '喜歡',
#   '一種',
#   '人去',
#   '唱歌',
#   '一直',
#   '人',
#   '喝',
#   '唱',
#   '結帳',
#   '前',
#   '先閃',
#   '唱歌',
#   '難聽'],
#  ['自由',
#   '時報',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '自由',
#   '時報',
#   '壓扁',
#   '變',
#   '西瓜',
#   '派',
#   '人',
#   '統獨',
#   '人士',
#   '以為',
#   '自由',
#   '時報',
#   '主張',
#   '台獨',
#   '現在',
#   '實際',
#   '月',
#   '日',
#   '星期四',
#   '新台灣',
#   '國策',
#   '智庫',
#   '公布',
#   '年',
#   '總統',
#   '選舉',
#   '民調',
#   '支持',
#   '台南',
#   '市長',
#   '賴清德',
#   '參選',
#   '高於',
#   '蔡',
#   '英文',
#   '總統',
#   '總統府',
#   '資政',
#   '說',
#   '蔡',
#   '總統',
#   '做',
#   '年',
#   '好',
#   '下次',
#   '最好',
#   '賴清德',
#   '說',
#   '無意',
#   '選',
#   '總統',
#   '持續',
#   '議題',
#   '陷',
#   '不義',
#   '總統府',
#   '發言人',
#   '表示',
#   '民調',
#   '完成',
#   '重大',
#   '改革',
#   '當務之急',
#   '年',
#   '總統大選',
#   '議題',
#   '月',
#   '日新',
#   '台灣',
#   '國策',
#   '智庫',
#   '公布',
#   '民調',
#   '後',
#   '各家',
#   '媒體',
#   '立即',
#   '大肆',
#   '報導',
#   '平面',
#   '報紙',
#   '媒體',
#   '則以',
#   '即時新聞',
#   '刊',
#   '電子版',
#   '自由',
#   '時報',
#   '例外',
#   '奇怪的是',
#   '第二天',
#   '月',
#   '日',
#   '報紙',
#   '版面',
#   '新聞',
#   '號稱',
#   '第一',
#   '大報',
#   '自由',
#   '時報',
#   '卻',
#   '消音',
#   '這才',
#   '新聞',
#   '賴清德',
#   '親中',
#   '愛台',
#   '言論',
#   '出現',
#   '後',
#   '投機',
#   '個性',
#   '親中',
#   '愛台',
#   '愛',
#   '投機',
#   '判斷',
#   '自由',
#   '時報',
#   '消音',
#   '中愛台',
#   '愛',
#   '投機',
#   '自由',
#   '時報',
#   '擁護',
#   '蔡',
#   '英文',
#   '蔡',
#   '英文',
#   '不利',
#   '新聞',
#   '報紙',
#   '版面',
#   '只能',
#   '出現',
#   '極少',
#   '人',
#   '注意',
#   '前一天',
#   '電子版',
#   '即時新聞',
#   '自由',
#   '時報',
#   '棄台',
#   '擁護',
#   '蔡',
#   '英文',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '一件',
#   '事情',
#   '得到',
#   '相同',
#   '判斷',
#   '月',
#   '日',
#   '媒體',
#   '報導',
#   '阿扁',
#   '總統',
#   '質疑',
#   '高院',
#   '法官',
#   '利用',
#   '媒體',
#   '放',
#   '話',
#   '心證',
#   '偏頗',
#   '公正',
#   '之虞',
#   '上週五',
#   '聲請',
#   '法官',
#   '迴避',
#   '法官',
#   '審理',
#   '近日',
#   '做出',
#   '裁定',
#   '民主',
#   '法治',
#   '國家',
#   '人',
#   '質疑',
#   '法官',
#   '偏頗',
#   '公正',
#   '一件',
#   '一個',
#   '前',
#   '總統',
#   '涉及',
#   '違反',
#   '司法程序',
#   '正義',
#   '特赦',
#   '議題',
#   '阿扁',
#   '案件',
#   '月',
#   '日',
#   '媒體',
#   '報導',
#   '電子版',
#   '即時新聞',
#   '第二天',
#   '月',
#   '日',
#   '報紙',
#   '版面',
#   '標題',
#   '號稱',
#   '第一',
#   '大報',
#   '自由',
#   '時報',
#   '消音',
#   '更好',
#   '判斷',
#   '自由',
#   '時報',
#   '站',
#   '擁護',
#   '蔡',
#   '英文',
#   '特赦',
#   '前',
#   '總統',
#   '陳水扁',
#   '立場',
#   '封殺',
#   '引起',
#   '特赦',
#   '議題',
#   '新聞',
#   '自由',
#   '時報',
#   '棄台',
#   '擁護',
#   '蔡',
#   '英文',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '擁護',
#   '蔡',
#   '英文',
#   '壓迫',
#   '陳水扁',
#   '變',
#   '西瓜',
#   '派',
#   '結合',
#   '頭腦清楚',
#   '文明',
#   '法治',
#   '有志一同',
#   '打倒',
#   '維持',
#   '偽',
#   '中華民國',
#   '現狀',
#   '享受',
#   '權力',
#   '蔡',
#   '英文',
#   '民進黨',
#   '取得',
#   '政權',
#   '建立',
#   'Republic',
#   'of',
#   'Taiwan',
#   '台灣',
#   '民國',
#   '歡迎',
#   '轉載',
#   '傳送',
#   '謝謝',
#   '祝',
#   '萬事如意',
#   '平安',
#   '健康',
#   'Thanks',
#   'and',
#   'Best',
#   'Regards',
#   '陳',
#   '永昌',
#   'C',
#   'Chen',
#   'PhD',
#   '英國',
#   'QS',
#   '世界',
#   '大學排名',
#   '中心',
#   '評鑑',
#   '委員',
#   '美國',
#   '大學',
#   '商學院',
#   '企管',
#   '行銷',
#   '博士',
#   '美國',
#   '哈佛',
#   'Harvard',
#   '大學',
#   '商學院',
#   '企管',
#   '學者',
#   '研究',
#   '國際',
#   '名錄',
#   '美國',
#   '世界',
#   'Whos',
#   'Who',
#   'in',
#   'the',
#   'World',
#   '瑞士',
#   '洛桑',
#   '國際',
#   '管理',
#   '研究院',
#   '世界',
#   '競爭力',
#   '中心',
#   '評鑑',
#   '專家',
#   '沙烏地阿',
#   '拉伯',
#   '法',
#   '德國',
#   '王',
#   'King',
#   '石油',
#   '礦產',
#   '大學',
#   '計畫',
#   '評審委員'],
#  ['下',
#   '對岸',
#   '中國',
#   '有嘻哈',
#   '每個',
#   '人',
#   '打扮',
#   '一副',
#   '潮到',
#   '水',
#   '刺青',
#   '重點',
#   '講話',
#   '方式',
#   '個個',
#   '自信',
#   '度',
#   '放到',
#   '校園',
#   '領袖',
#   '級',
#   '人物',
#   '太',
#   '囂張',
#   '人',
#   '一天',
#   '三餐',
#   '開扁',
#   '人物',
#   '撇開',
#   '有無',
#   '饒舌',
#   '實力',
#   '裝逼',
#   '耍',
#   '屌',
#   '外',
#   '饒舌',
#   '必要',
#   '包裝'],
#  ['憤怒',
#   '鳥',
#   '相信',
#   '記得',
#   '手遊',
#   '智慧型',
#   '手機',
#   '稱霸',
#   '續作',
#   '還出',
#   '電影',
#   '漸漸',
#   '淡出',
#   '有沒有',
#   '憤怒',
#   '八卦'],
#  ['XDDD',
#   'D',
#   '罩杯',
#   '正妹',
#   '女友',
#   '啪',
#   '感覺',
#   '職業',
#   '空姐',
#   '櫃姐',
#   '這種',
#   '正妹',
#   '女友',
#   '小魯',
#   '真心',
#   '想要',
#   '問',
#   '一下',
#   '喔',
#   '這種',
#   'D',
#   '罩杯',
#   '高挑',
#   '外送',
#   '茶',
#   '小時',
#   '一萬塊',
#   '錢',
#   '正確',
#   '行情',
#   '分享',
#   '一下',
#   '謝謝'],
#  ['小妹',
#   '之前',
#   '煮',
#   '麵',
#   '滑倒',
#   '燙',
#   '水泡',
#   '消',
#   '剩下',
#   '一塊',
#   '很大',
#   '疤',
#   '之前',
#   '手賤',
#   '皮',
#   '扯破',
#   '現在',
#   '傷口',
#   '超級',
#   '癢',
#   '抓',
#   '好',
#   '蘇服',
#   '好像',
#   '不太好',
#   '放',
#   '毛巾',
#   '加點',
#   '冰塊',
#   '舒服',
#   '一點',
#   '傷口',
#   '癢',
#   'R'],
#  ['魯哥',
#   '魯姐',
#   '好',
#   '魯弟',
#   '有個',
#   '疑問',
#   '一休',
#   '和尚',
#   '卡通版',
#   '看過',
#   '長大',
#   '後',
#   '版本',
#   '演',
#   '長大',
#   '版',
#   '成人版',
#   '想',
#   '知道',
#   '一休',
#   '家裡',
#   '有錢',
#   '引誘',
#   '一休',
#   '捉弄',
#   '一休',
#   '實際上',
#   '偷偷',
#   '暗戀',
#   '一休',
#   '千金',
#   '姑娘',
#   '窮',
#   '農夫',
#   '孫女',
#   '一休',
#   '真',
#   '青梅竹馬',
#   '大方',
#   '承認',
#   '喜歡',
#   '一休',
#   '窮',
#   '身材',
#   '好',
#   '一個',
#   '安國',
#   '寺',
#   '變成',
#   '大廟',
#   '千金',
#   '一個',
#   '遇到',
#   '真',
#   '心愛',
#   '人',
#   '一休',
#   '最後',
#   '選',
#   '有沒有',
#   '八卦',
#   '答案',
#   '接受',
#   '公主',
#   '戲分',
#   '太少',
#   '結局',
#   '變成',
#   '路人',
#   '公主',
#   '粉絲',
#   '糞作',
#   '耶',
#   '美化',
#   '意思',
#   '還俗',
#   '出家',
#   '日本',
#   '和尚',
#   '變成',
#   '辜負',
#   '大師',
#   '栽培',
#   '已經',
#   '開葷',
#   '知道',
#   '有沒有',
#   '子嗣',
#   '存在',
#   '處理',
#   '掉'],
#  ['浦島',
#   '太郎',
#   '日本',
#   '童話故事',
#   '浦島',
#   '太郎',
#   '陸地',
#   '一隻',
#   '烏龜',
#   '受邀',
#   '龍宮',
#   '結婚',
#   '幸福',
#   '厭倦',
#   '一成不變',
#   '生活',
#   '想家',
#   '提出',
#   '上岸',
#   '請求',
#   '上岸',
#   '並給',
#   '盒子',
#   '告訴',
#   '他裡面',
#   '還說',
#   '不行',
#   '打開',
#   '喔',
#   '人',
#   '總是',
#   '好奇',
#   '浦島',
#   '太郎',
#   '回到',
#   '陸上',
#   '看到',
#   '人',
#   '事物',
#   '變',
#   '開',
#   '盒子',
#   '變',
#   '歲',
#   '老頭',
#   '盒子',
#   '舉動',
#   '是不是',
#   '得不到',
#   '就要',
#   '毀了',
#   '心態',
#   '還讓',
#   '變老',
#   '胃口',
#   '給了',
#   '東西',
#   '不讓',
#   '人',
#   '打開',
#   '這是',
#   '鄉民',
#   '所說',
#   '母',
#   'X'],
#  ['欸',
#   '說',
#   '女友',
#   '幫',
#   '完',
#   '寶貝',
#   '男森',
#   '接吻',
#   '男森',
#   '間接',
#   '幫',
#   '口交',
#   '人覺',
#   '怪怪的'],
#  ['遊戲',
#   '公司',
#   '大小',
#   '嚴重',
#   '其他人',
#   '劇情',
#   '曖昧',
#   '尤其',
#   '花音',
#   '只差',
#   '主動',
#   '騎上',
#   '狼師',
#   '惹',
#   '給給',
#   '部分',
#   '幾個',
#   '臉紅',
#   '想',
#   '草草',
#   '帶過',
#   '太過分',
#   '怎看',
#   'QQ',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意',
#   '奶',
#   '說',
#   '不夠',
#   'coser',
#   'QQ'],
#  ['發現',
#   '公司',
#   '裡有',
#   '一個',
#   '記者',
#   '超人',
#   '長',
#   '超像',
#   '別以',
#   '戴',
#   '眼鏡',
#   '看不出來',
#   '請問',
#   '我要',
#   '注意'],
#  ['好',
#   '社會',
#   '正義',
#   '魔人',
#   '當道',
#   '手機',
#   '在手',
#   '記者',
#   '爆料',
#   '想問',
#   '今天',
#   '肥宅',
#   '真的',
#   '舒服',
#   '坐',
#   '一下',
#   '博愛',
#   '座'],
#  ['現在',
#   '網路',
#   '社群',
#   '發達',
#   '一堆',
#   '文組要',
#   '網路',
#   '生存',
#   '風向',
#   '做文章',
#   '想',
#   '美國',
#   '就讓',
#   '欲求',
#   '做起',
#   '生意',
#   '大肆',
#   '崛起',
#   '文字遊戲',
#   '好好',
#   '幹',
#   '一票',
#   '聰明',
#   '記者',
#   '訪問',
#   '時',
#   '應對',
#   '只會',
#   '敏感',
#   '問題',
#   '時',
#   '答',
#   '知道',
#   '知道',
#   '真的',
#   '越老越',
#   '掏心',
#   '掏肺',
#   '連話都',
#   '說不清楚',
#   'Jay',
#   'Chou',
#   'PTT',
#   '說',
#   '中文',
#   '問題',
#   '笑',
#   '已經',
#   '年',
#   '還被',
#   '這版',
#   '水桶',
#   '超過',
#   '一年',
#   '移民',
#   '美國',
#   '拖',
#   '幾年',
#   '就當',
#   '這是',
#   '版',
#   '看不起',
#   '中'],
#  ['階級',
#   '流動',
#   '一件',
#   '勵志',
#   '事',
#   '窮',
#   '小孩',
#   '後天',
#   '努力',
#   '成為',
#   '一介',
#   '富人',
#   '這種',
#   '例子',
#   '現在',
#   '已經',
#   '越來越少',
#   '原因',
#   '原生',
#   '家庭',
#   '菁英',
#   '教育',
#   '事實上',
#   '造成',
#   '臺灣',
#   '進步',
#   '正是',
#   '菁英',
#   '教育',
#   '下',
#   '出生',
#   '家庭',
#   '那為',
#   '禮遇',
#   '想要',
#   '一些',
#   '像是',
#   '繁星',
#   '這類',
#   '骯髒',
#   '手段',
#   '原本',
#   '菁英',
#   '家庭',
#   '缺額',
#   '擠掉',
#   '知道',
#   '臺灣',
#   '進步',
#   '窮人',
#   '好處',
#   '菁英',
#   '發展',
#   '核電',
#   '臺灣人',
#   '享受',
#   '便宜',
#   '的電',
#   '吹',
#   '錢',
#   '冷氣',
#   '刻意',
#   '造成',
#   '階級',
#   '流動',
#   '好'],
#  ['電影',
#   '電視劇',
#   '裡',
#   '黑道',
#   '出獄',
#   '找',
#   '法官',
#   '報仇',
#   '台灣',
#   '黑道',
#   '檢察官',
#   '起訴',
#   '法官',
#   '判刑',
#   '好像',
#   '聽到',
#   '黑道',
#   '出獄',
#   '後',
#   '找',
#   '檢察官',
#   '法官',
#   '報仇',
#   '判他',
#   '刑',
#   '法官',
#   '已經',
#   '退休',
#   '黑道',
#   '好像',
#   '想',
#   '找',
#   '報仇',
#   '有沒有',
#   '八卦'],
#  ['拉',
#   '一個',
#   '住',
#   '日本',
#   '朋友',
#   '一支',
#   '武士刀',
#   '送',
#   '當作',
#   '收藏',
#   '查',
#   '一下',
#   '法令',
#   '東西',
#   '需要',
#   '警局',
#   '申請',
#   '持刀',
#   '證',
#   '還要',
#   '送',
#   '鑑定',
#   '辦',
#   '一張',
#   '身分證',
#   '前科',
#   '好像',
#   '先決條件',
#   '知道',
#   '持刀',
#   '容易',
#   '辦'],
#  ['每次',
#   '加油',
#   '加油站',
#   '員工',
#   '會問',
#   '加',
#   '一瓶',
#   '汽油',
#   '精',
#   '去除',
#   '比較',
#   '省油',
#   '有沒有',
#   'r',
#   '真的',
#   '比較',
#   '省油',
#   'ㄇ',
#   'u',
#   'mi',
#   'u',
#   'gua',
#   'r',
#   '廢文',
#   '產生器',
#   '小弟',
#   '多餘'],
#  ['好',
#   '自介',
#   '肥宅',
#   '女兒',
#   '老婆',
#   '肥宅',
#   '老家',
#   '附近',
#   '夜市',
#   '一攤',
#   '東山',
#   '鴨頭',
#   '還蠻',
#   '好吃',
#   '老闆娘',
#   '單親',
#   '媽媽',
#   '每天',
#   '中午',
#   '一過',
#   '擺攤',
#   '半夜',
#   '一次',
#   '肥宅',
#   '準備',
#   '買',
#   '宵夜',
#   '老闆娘',
#   '泣不成聲',
#   '說',
#   '女兒',
#   '交到',
#   '壞',
#   '朋友',
#   '跑',
#   '去當',
#   '太妹',
#   '八嘎',
#   '囧',
#   '拐走',
#   '辛辛苦苦',
#   '女兒',
#   '養',
#   '人',
#   '騙走',
#   '看到',
#   '努力',
#   '養大',
#   '孩子',
#   '變成',
#   '太妹',
#   '八卦'],
#  ['小',
#   '沒交過',
#   '女',
#   '碰友',
#   '常聽到',
#   '有人',
#   '說',
#   '交往',
#   '後',
#   '發現',
#   '不合',
#   '分手',
#   '一個',
#   '黑人',
#   '問號',
#   '一個',
#   '人',
#   '不合',
#   '交往',
#   '前',
#   '知道',
#   '相處',
#   '知道',
#   '合',
#   '不合',
#   '交往',
#   '後',
#   '現出原形',
#   '真',
#   '不知',
#   '太',
#   '無知'],
#  ['標題',
#   '今天',
#   '去逛',
#   '看到',
#   '下圖',
#   '所示',
#   '位置',
#   '西屯區',
#   '二段',
#   '號',
#   '少',
#   '一個',
#   '看書',
#   '地方'],
#  ['台灣',
#   '當年',
#   '鄭成功',
#   '家族',
#   '統治',
#   '心想',
#   '反攻大陸',
#   '政績',
#   '當年',
#   '施琅',
#   '征戰',
#   '台灣',
#   '未果',
#   '延續',
#   '至今',
#   '東寧',
#   '國'],
#  ['鑒',
#   '社會',
#   '貧富',
#   '城鄉',
#   '差距',
#   '過大',
#   '階級',
#   '複製',
#   '狀況',
#   '嚴重',
#   '今天',
#   '立法',
#   '家庭',
#   '年收',
#   '萬',
#   '以上',
#   '小孩',
#   '念',
#   '台大',
#   '台大',
#   '只收',
#   '小孩',
#   '以下',
#   '貧困',
#   '小孩',
#   '翻身',
#   '成為',
#   '中流砥柱',
#   '促成',
#   '台灣',
#   '階級',
#   '流動',
#   '台大',
#   '出現',
#   '宮廟',
#   '社團',
#   '進',
#   '台大',
#   '發揚',
#   '傳統',
#   '文化',
#   '台大',
#   '變成',
#   '全國',
#   '最大',
#   '陣頭',
#   '有錢人',
#   '學校',
#   '念',
#   '只好',
#   '去念',
#   '亞洲',
#   '大學',
#   '私大',
#   '學校',
#   '倍',
#   '薪水',
#   '挖角',
#   '原',
#   '台大',
#   '教授',
#   '私立',
#   '大學',
#   '變台灣',
#   '常春藤',
#   '聯盟',
#   '一種',
#   '狀況',
#   '比較',
#   '發生'],
#  ['蹦',
#   '啾',
#   '妹魯喜',
#   '波納佩',
#   '梯',
#   '蹦蹦跳',
#   '姆',
#   '咪',
#   '剛剛',
#   '問我',
#   '喜不喜歡',
#   '咪',
#   '零食',
#   '請問',
#   '單兵',
#   '回答',
#   '有沒有',
#   '卦',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆'],
#  ['有時',
#   '八卦',
#   '板',
#   '探探',
#   '風氣',
#   '發現',
#   '得到',
#   '回覆',
#   '功利',
#   '弱者',
#   '欺負',
#   '正常',
#   '社會',
#   '本來',
#   '公平',
#   '一些',
#   '公平',
#   '事情',
#   '合理化',
#   '法官',
#   '做出',
#   '不合理',
#   '判決',
#   '時',
#   '罵',
#   '弱者',
#   '判他',
#   '敗訴',
#   '壞人',
#   '被判',
#   '死刑',
#   '合理',
#   '八卦',
#   '板'],
#  ['沒變',
#   '口',
#   '洨',
#   '美',
#   '妳',
#   '變',
#   '吼',
#   '妳',
#   '整形',
#   '喔',
#   '呵呵',
#   '快來',
#   '麻辣鍋',
#   '洨',
#   '美',
#   '整形',
#   '早些',
#   '前',
#   '廣告',
#   '知道',
#   '最近',
#   '凶'],
#  ['酸宅',
#   '機會',
#   '動畫',
#   '敷',
#   '徵選',
#   '酸酸',
#   '角色',
#   '聲優',
#   '這是',
#   '作品',
#   '名',
#   '場面',
#   '獅子',
#   '神',
#   '角色',
#   '日薪',
#   '高達',
#   '萬元',
#   '日幣',
#   '當天',
#   '配音',
#   '聲優',
#   '簽名',
#   '贈品',
#   '徵人',
#   '年齡',
#   '性別',
#   '學',
#   '經歷',
#   '徵人',
#   '時間',
#   '請',
#   '酸宅',
#   '踴躍',
#   '報名',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'LGE',
#   'LGH815',
#   '知道',
#   '動物',
#   '朋友',
#   '甲賽',
#   '動物',
#   '朋友',
#   '雙頭',
#   '龍',
#   '朋友'],
#  ['今天',
#   '北門',
#   '看到',
#   '一群',
#   '戴',
#   '鴨舌帽',
#   '北門',
#   '城門',
#   '玩',
#   '滑板',
#   '新蓋',
#   '階梯',
#   '表演',
#   '特技',
#   '無視',
#   '旁邊',
#   '路過',
#   '人',
#   '本魯',
#   '沒膽',
#   '嗆',
#   '只好',
#   '播',
#   '報警',
#   '五分鐘',
#   '警察',
#   '驅離',
#   '不甘',
#   '不願',
#   '離開',
#   '旁邊',
#   '玩',
#   '滑板',
#   '相信',
#   '多數',
#   '滑板',
#   '社群',
#   '高調',
#   '古蹟',
#   '牆邊',
#   '玩',
#   '滑板',
#   '推測',
#   '有人',
#   '幕後',
#   '指使',
#   '意圖',
#   '不用說',
#   '有沒有',
#   '有人',
#   '台北',
#   '街頭',
#   '作亂',
#   '八卦'],
#  ['以前',
#   '印象',
#   '隔板',
#   '男廁',
#   '經費',
#   '改善',
#   '那種',
#   '最近',
#   '看到',
#   '紫',
#   '南宮',
#   '花',
#   '多萬',
#   '建',
#   '男廁',
#   '隔板',
#   '顯然',
#   '經費',
#   '問題',
#   '設計',
#   '這是',
#   '設計師',
#   '小',
#   '巧思',
#   '世界潮流'],
#  ['登革熱',
#   '轉移',
#   '台北',
#   '全國',
#   '登革熱',
#   '本土',
#   '病例',
#   '境外',
#   '移入',
#   '病例',
#   '年',
#   '週',
#   '年',
#   '週',
#   '衛福部',
#   '網站',
#   '連結',
#   '屏東縣',
#   '病',
#   '例數',
#   '人',
#   '高雄市',
#   '病',
#   '例數',
#   '人',
#   '台南市',
#   '病',
#   '例數',
#   '人',
#   '台中市',
#   '病',
#   '例數',
#   '人',
#   '桃園市',
#   '病',
#   '例數',
#   '人',
#   '新北市',
#   '病',
#   '例數',
#   '人',
#   '台北市',
#   '病',
#   '例數',
#   '人',
#   '數據',
#   '證明',
#   '台北市',
#   '例數',
#   '全台',
#   '最多',
#   '雙北',
#   '已經',
#   '遠超過',
#   '南部',
#   '總和',
#   '南部',
#   '早已',
#   '洗刷',
#   '登革熱',
#   '汙名',
#   '有沒有',
#   '八卦'],
#  ['西卡',
#   '目前',
#   '接受',
#   '訪問',
#   '時',
#   '表示',
#   '出道',
#   '週年',
#   '最',
#   '辛苦',
#   '瞬間',
#   '少女時代',
#   '離別',
#   '回到',
#   '過去',
#   '西卡',
#   '還會',
#   '選擇',
#   '離團',
#   '卦',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['再',
#   '一個月',
#   '小大',
#   '就要',
#   '當菜',
#   '逼',
#   '惹',
#   '迎新',
#   '前',
#   '拐',
#   '繳費單',
#   '惹',
#   '邊緣',
#   '人',
#   '來說',
#   '費用',
#   '根本',
#   '有去無回',
#   '直接',
#   '噱',
#   '一票',
#   '開學',
#   '後',
#   '買',
#   '學長',
#   '二手書',
#   '再',
#   '噱',
#   '一票',
#   '有沒有',
#   '小大一',
#   '拿到',
#   '系',
#   '學會',
#   '乖乖',
#   '去繳',
#   '八卦'],
#  ['新聞來源',
#   '非核',
#   '家園',
#   '燃煤',
#   '電廠',
#   '再生能源',
#   '綠能',
#   '天然氣',
#   '發電',
#   '能源',
#   '配比',
#   '張圖',
#   '年',
#   '各國',
#   '平均',
#   '電價',
#   '國際',
#   '能源',
#   '總署',
#   '台灣',
#   '電價',
#   '便宜',
#   '張圖',
#   '年',
#   '台電',
#   '電源',
#   '成本',
#   '燃煤',
#   '天然氣',
#   '綠能',
#   '至少',
#   '焚化',
#   '廠',
#   'or',
#   '搞',
#   '熱能',
#   '再',
#   '利用',
#   '等於',
#   '能源',
#   '用燒',
#   '冬天',
#   '夏天',
#   '就夠',
#   '熱了',
#   '外面',
#   '還在燒',
#   '電',
#   '不夠',
#   '拼命',
#   '燒',
#   '他媽的',
#   '更熱',
#   '減碳',
#   '全部',
#   '用燒',
#   '成本',
#   '高',
#   '說',
#   '電價',
#   '漲',
#   '來源',
#   '維基百科',
#   '張圖',
#   '世界',
#   '各國',
#   '電力',
#   '消耗',
#   '排名',
#   '前',
#   '幾名',
#   '產油國',
#   'or',
#   '寒帶',
#   '國家',
#   '產油國',
#   '跳過',
#   '提',
#   '富',
#   '流油',
#   '寒帶',
#   '國家',
#   '比較',
#   '容易',
#   '使用',
#   '高耗能',
#   '電器',
#   '用品',
#   '冰島',
#   '冰島',
#   '多座',
#   '火山',
#   '多個',
#   '溫泉',
#   '能源',
#   '水力',
#   '地熱',
#   '敦',
#   '公國',
#   '人口',
#   '萬多',
#   '人均',
#   '挪威',
#   '北海',
#   '油田',
#   '世界',
#   '第三',
#   '石油',
#   '輸出國',
#   '加拿大',
#   '產',
#   '石油',
#   '天然氣',
#   '地方',
#   '大到',
#   '玩',
#   '太陽能',
#   '板',
#   '推',
#   '骨牌',
#   '芬蘭',
#   '後續',
#   '瑞典',
#   '世界',
#   '前',
#   '核能',
#   '石油',
#   '綠能',
#   '綠能',
#   '燒',
#   '木屑',
#   '熱',
#   '廢水',
#   '美國',
#   '不用',
#   '講了',
#   '自已',
#   '國不',
#   '開採',
#   '買',
#   '外國',
#   '買不到',
#   '台灣',
#   '德國',
#   '梅克爾',
#   '非核',
#   '家園',
#   '蔡',
#   '英文',
#   '應該',
#   '學',
#   '德國',
#   '目前',
#   '電價',
#   '上漲',
#   '一度',
#   '電',
#   '元台幣',
#   '德國',
#   '燃煤',
#   '發電',
#   '團體',
#   '最愛',
#   '扯',
#   '德國',
#   '直說',
#   '非核',
#   '好',
#   '從來不',
#   '提',
#   '電價',
#   '台灣',
#   '提',
#   '一下',
#   '芬蘭',
#   '好',
#   '芬蘭',
#   '台灣',
#   '部份',
#   '發電',
#   '情況',
#   '最像',
#   '芬蘭',
#   '目前',
#   '共有',
#   '座',
#   '核電機組',
#   '處於',
#   '運轉',
#   '狀態',
#   '座',
#   '年',
#   '蓋',
#   '預算',
#   '億',
#   '歐元',
#   '最終',
#   '預算',
#   '預估',
#   '達',
#   '億',
#   '歐元',
#   '本來',
#   '年',
#   '啟用',
#   '拖到',
#   '年',
#   '延到',
#   '最後',
#   '延到',
#   '年',
#   '都還不',
#   '確定',
#   '啟用',
#   '芬蘭',
#   '發電',
#   '來源',
#   '概況',
#   '石油',
#   '天然氣',
#   '煤炭',
#   '核能',
#   '再生能源',
#   '生質',
#   '廢棄物',
#   '水力',
#   '芬蘭',
#   '廣大',
#   '森林',
#   '發達',
#   '產生',
#   '大量',
#   '木屑',
#   '生質',
#   '燒',
#   '木屑',
#   '水力',
#   '燒完',
#   '的熱',
#   '廢水',
#   '綠能',
#   '台灣',
#   '砍',
#   '一棵樹',
#   '幹',
#   '狗',
#   '燒',
#   '木屑',
#   'zzzz',
#   '廢核',
#   '之後',
#   '能源',
#   '替代',
#   '綠能',
#   '用燒',
#   '減碳',
#   '不用',
#   '火力',
#   '燃煤',
#   '核能',
#   '燃煤',
#   '台灣',
#   '能源',
#   '缺口',
#   '賭',
#   '天然氣',
#   '綠能',
#   '用燒',
#   '綠能',
#   '先',
#   '說',
#   '天然氣',
#   '發電',
#   '天然氣',
#   '應該',
#   '台灣',
#   '武器',
#   '目前',
#   '有效',
#   '乾淨',
#   '能源',
#   '還在',
#   '開發',
#   '中',
#   '天然氣',
#   '應該',
#   '能源危機',
#   '時才',
#   '拿來',
#   '發電',
#   '....',
#   '有人',
#   '說',
#   '買',
#   '台灣',
#   '海島',
#   '國家',
#   '運輸成本',
#   '加一加',
#   '說',
#   '電費',
#   '漲',
#   'ZZ',
#   '漲',
#   '電費',
#   '買',
#   '漲',
#   '自已',
#   '燒',
#   '自已',
#   '台灣',
#   '天然氣',
#   '燒完',
#   '台灣',
#   'GG',
#   '直接',
#   '統一',
#   '補',
#   '一個',
#   '小常識',
#   '天然氣',
#   '輸出國',
#   '最大',
#   '俄羅斯',
#   '超過',
#   '台灣',
#   '倍',
#   '以上',
#   '中',
#   '俄',
#   '簽訂',
#   '億美元',
#   '天然氣',
#   '協議',
#   '年',
#   '俄羅斯',
#   '中國',
#   '連續',
#   '年',
#   '每年',
#   '輸出',
#   '天然氣',
#   '中國',
#   '天然氣',
#   '石油',
#   '煤礦',
#   '還跟',
#   '俄羅斯',
#   '買',
#   '天然氣',
#   '瑞典',
#   '禁用',
#   '石油',
#   '德國',
#   '非核',
#   '家園',
#   '挪威',
#   '年',
#   '禁售',
#   '內燃機',
#   '汽車',
#   '挪威',
#   '世界',
#   '第三',
#   '石油',
#   '輸出國',
#   '芬蘭',
#   '擬',
#   '率先',
#   '立法',
#   '年',
#   '禁止',
#   '燃煤',
#   '發電',
#   '實現',
#   '巴黎',
#   '協議',
#   '承諾',
#   '台灣',
#   '非核',
#   '家園',
#   '節能',
#   '減碳',
#   '電費',
#   '漲',
#   '信',
#   'ps',
#   '看到',
#   '回',
#   '文才',
#   '想',
#   '從頭到尾',
#   '提到',
#   '擁核',
#   'or',
#   '支持',
#   '核四',
#   '針對',
#   '電價',
#   '漲',
#   '部分',
#   '提出',
#   '質疑',
#   '一件',
#   '事情',
#   '愛',
#   '發電',
#   '可行',
#   '屁',
#   '甲烷',
#   '一種',
#   '考慮',
#   '用屁',
#   '發電',
#   '收集',
#   '問題',
#   '愛',
#   '發電',
#   '假',
#   '用屁',
#   '發電',
#   '比較',
#   '可行',
#   '自殺',
#   '應該',
#   '企業',
#   '出走',
#   '用電',
#   '辛苦',
#   '台灣',
#   '經濟',
#   '垮',
#   'M',
#   '六個',
#   '字',
#   '精闢',
#   '解釋',
#   '合理',
#   '反映',
#   '成本',
#   '說',
#   '實在',
#   '台灣',
#   '能源',
#   '全部',
#   '仰賴',
#   '進口',
#   '天然氣',
#   '完',
#   '發生',
#   '戰爭',
#   '提了',
#   '能源危機',
#   '台灣',
#   '就要',
#   '垮',
#   '陳',
#   '其邁',
#   '說',
#   '吸',
#   '二氧化碳',
#   '會腦',
#   '殘',
#   '發現',
#   '盲腸',
#   '說真的',
#   '北部',
#   '房價',
#   '降價',
#   '真的',
#   '一招',
#   '民生問題',
#   '沒錯',
#   '製造',
#   '電呢',
#   '請問',
#   '辦法',
#   '替代',
#   '天然氣',
#   '漲',
#   '喔',
#   '主軸',
#   '電價',
#   '漲',
#   '知道',
#   '一直',
#   '扯',
#   '核能',
#   '說真的',
#   '林淑芬',
#   '很棒'],
#  ['世界',
#   '三大',
#   '無人',
#   '知道',
#   '秘密',
#   '配方',
#   '可口可樂',
#   '美味',
#   '蟹堡',
#   '麥當勞',
#   '糖醋',
#   '醬',
#   '破解',
#   '麥當勞',
#   '糖醋',
#   '醬',
#   '自用',
#   '送人',
#   '兩相宜',
#   '神秘',
#   '配方',
#   '原稿',
#   '藏',
#   '哪裡'],
#  ['注意',
#   '注意',
#   '還動',
#   '噓文',
#   '特別',
#   '半夜',
#   '肥宅',
#   '弟兄',
#   '觀念',
#   '遇到',
#   '學長',
#   '推文',
#   '第一次',
#   '良性',
#   '勸導',
#   '希望',
#   '再犯',
#   '推文',
#   '之後',
#   '敬禮',
#   '解散'],
#  ['三井',
#   '壽',
#   '體能',
#   '很差',
#   '球場',
#   '昏倒',
#   '沒力',
#   '退場',
#   '三井',
#   '壽',
#   '彈性',
#   '球星',
#   '差',
#   '灌籃高手',
#   '以上',
#   '球員',
#   '灌籃',
#   '三井',
#   '身高',
#   '卻',
#   '無法',
#   '灌籃',
#   '三井',
#   '卻',
#   '守住',
#   '流川楓',
#   '阿福',
#   '飛人',
#   '球星',
#   '八卦'],
#  ['朋友',
#   '說',
#   '淡水',
#   '騎去',
#   '永和',
#   '河北',
#   '今天',
#   '河北',
#   '警察',
#   '攔',
#   '下來',
#   '冥冥之中',
#   '想起',
#   '說',
#   '穿過',
#   '一個',
#   '門',
#   '走',
#   '請問',
#   '門',
#   '耍',
#   '機車',
#   '河北',
#   '幹',
#   '有沒有',
#   '認真',
#   '鄉民',
#   '門',
#   '嘻嘻',
#   '真',
#   '好',
#   '謝謝'],
#  ['一天',
#   '壘上',
#   '有人',
#   '雙方',
#   '平手',
#   '狀況',
#   '一個',
#   '投手',
#   '投',
#   '一個',
#   '姚明',
#   '接',
#   '不到',
#   '爆',
#   '投',
#   '可想而知',
#   '失',
#   '一分',
#   '沒想到',
#   '捕手',
#   '撿',
#   '完球',
#   '球',
#   '傳給',
#   '投手',
#   '發現',
#   '投手',
#   '散步',
#   '補',
#   '本壘',
#   '失',
#   '一分',
#   '請問',
#   '投手',
#   '散步',
#   '想',
#   '捕手',
#   '想',
#   '總教練',
#   '想',
#   '這是',
#   '假球',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Samsung',
#   'SMN9208'],
#  ['最',
#   '早期',
#   '恐怖片',
#   '服裝',
#   '造型',
#   '化妝',
#   '技術',
#   '都還',
#   '普普通通',
#   '現在',
#   '鬼',
#   '殺人',
#   '魔',
#   '造型',
#   '越來越',
#   '噁',
#   '爛',
#   '音效',
#   '特效',
#   '配合',
#   '恐怖片',
#   '場景',
#   '變得',
#   '真實',
#   '有時候',
#   '總會',
#   '覺得',
#   '嚇人',
#   '時間',
#   '點',
#   '越來越',
#   '好',
#   '掌握',
#   '感覺',
#   '這時候',
#   '嚇人',
#   '恐怖片',
#   '天花板'],
#  ['昨天',
#   '第一次',
#   '小天使',
#   '說話',
#   '已經',
#   '半夜',
#   '三點',
#   '真是',
#   '謝謝',
#   '喔',
#   '有沒有',
#   '小天使',
#   '分享',
#   '一下',
#   '心得',
#   '好玩',
#   '累',
#   '推薦',
#   '當嗎',
#   '有人',
#   '分享',
#   '小天使',
#   '互動',
#   '經驗',
#   '歡迎',
#   '喔',
#   '問',
#   '一些',
#   'PTT',
#   '使用',
#   '問題'],
#  ['號稱',
#   '當代',
#   '古典',
#   '小提琴',
#   '第一把',
#   '交椅',
#   '雙腳',
#   '不良',
#   '行',
#   '小提琴',
#   '技法',
#   '高超',
#   '一次',
#   '演奏',
#   '一根',
#   '三條',
#   '弦',
#   '演奏',
#   '完',
#   '剩下',
#   '部分',
#   '有沒有',
#   '八卦',
#   '辛德勒',
#   '名單',
#   '拉',
#   '好好',
#   '聽',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Sony',
#   'D6503',
#   'You',
#   'want',
#   'to',
#   'know',
#   'how',
#   'I',
#   'did',
#   'it',
#   'This',
#   'is',
#   'how',
#   'I',
#   'did',
#   'it',
#   'I',
#   'never',
#   'saved',
#   'anything',
#   'for',
#   'the',
#   'swim',
#   'back'],
#  ['上次',
#   '吃飯',
#   '爸',
#   '討論',
#   '接球',
#   '說',
#   '接球',
#   '位置',
#   '痛',
#   '公里',
#   '痛',
#   '接',
#   '手套',
#   '點',
#   '說',
#   '時速',
#   '會痛',
#   '反應',
#   '很快',
#   '有沒有',
#   '接過',
#   '時速',
#   '以上',
#   '說明',
#   '一下',
#   '痛',
#   '有沒有',
#   'o',
#   'o'],
#  ['買',
#   '宵夜',
#   '設定',
#   '預算',
#   '元',
#   '實際',
#   '現場',
#   '預算',
#   '爆表',
#   '失去',
#   '理智',
#   '本來',
#   '預計',
#   '購買',
#   '名單',
#   '裡的',
#   '食物',
#   '加點',
#   '買',
#   '回家',
#   '慾望',
#   '戰勝',
#   '熱量',
#   '爆表',
#   '惹',
#   '預算',
#   '慾望',
#   '慾望',
#   '預算',
#   '惹',
#   '多買',
#   '一杯',
#   '無糖',
#   '手搖',
#   '茶',
#   '不知',
#   '減低',
#   '罪惡感',
#   '....'],
#  ['安安',
#   '肥宅',
#   '今天',
#   '出差',
#   '台南',
#   '客戶',
#   '洗臉',
#   '後',
#   '點多',
#   '聽說',
#   '台南',
#   '美食',
#   '找',
#   '路邊攤',
#   '坐',
#   '下來',
#   '吃',
#   '蝦',
#   '捲',
#   '撇到',
#   '旁邊',
#   '一個',
#   '阿伯',
#   '年輕人',
#   '弄',
#   '醬油膏',
#   '蝦',
#   '捲',
#   '胡椒',
#   '夠味',
#   '沒想到',
#   '台南人',
#   '口味',
#   '桌',
#   '一盤',
#   '牛',
#   '番茄',
#   '幹',
#   '醬油膏',
#   '沾',
#   '番茄',
#   '吃',
#   '好',
#   '噁心',
#   '看不下去',
#   '害',
#   '老闆娘',
#   '說',
#   '包',
#   '拿到',
#   '車上',
#   '吃',
#   '這種',
#   '想',
#   '八卦'],
#  ['聽說',
#   '首歌',
#   '歡喜',
#   '好',
#   '算是',
#   '陳',
#   '出名',
#   '代表',
#   '歌曲',
#   '歌詞',
#   '聽',
#   '感覺',
#   '綠綠的',
#   '有沒有',
#   '首歌',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Asus',
#   'ASUS',
#   'Z012DA'],
#  ['題',
#   '三者',
#   '屬於',
#   '年代',
#   '美國',
#   '經典',
#   '樂團',
#   '當時',
#   '排名',
#   '聽說',
#   '超脫',
#   '邦',
#   '喬飛',
#   '槍花',
#   '小弟',
#   '最愛',
#   '槍',
#   '玫瑰',
#   '請問',
#   '哪團',
#   '鄉民',
#   '心中',
#   '經典'],
#  ['獵人',
#   '世界',
#   '相傳',
#   '東巴',
#   '西索',
#   '剩下',
#   '南北',
#   '中',
#   '有沒有',
#   '獵人',
#   '五絕',
#   '剩下',
#   '八卦'],
#  ['同事',
#   '只來',
#   '天',
#   '提出',
#   '離職',
#   '老闆',
#   '不想',
#   '慰留',
#   '但過',
#   '幾天',
#   '卻',
#   '打電話',
#   '回來',
#   '問',
#   '天',
#   '工資',
#   '現在',
#   '試用期',
#   '還要',
#   '錢',
#   '東西',
#   '還學',
#   '還要',
#   '領錢',
#   '十天',
#   '搖',
#   '東西',
#   '還沒',
#   '背熟',
#   '制服',
#   '還被',
#   '穿',
#   '髒'],
#  ['胎嘎',
#   '後',
#   '想問',
#   '一下',
#   '吃',
#   '壽司',
#   '看到',
#   '很俗',
#   '南部',
#   '人',
#   '芥末',
#   '醬油',
#   '攪和',
#   '一起',
#   '沾',
#   '驚呆',
#   '吃',
#   '根本',
#   '吃不出',
#   '芥末',
#   '清香',
#   '醬油',
#   '提',
#   '鮮味',
#   '有沒有',
#   '南部',
#   '台北市',
#   '中正',
#   '中山',
#   '大安',
#   '天母',
#   '朋友',
#   '幫',
#   '回答',
#   '一下',
#   '感恩',
#   '這位',
#   '朋友',
#   '想法',
#   'ㄋ',
#   '南部',
#   '土豪',
#   '比較',
#   '吃',
#   '汗味',
#   '唷',
#   '三味',
#   '食堂',
#   '粗飽',
#   'ㄋ',
#   '挖',
#   '鄭公',
#   '吃',
#   '牛肉',
#   '厚片',
#   '炙燒',
#   '後',
#   '加一點',
#   '玫瑰',
#   '鹽',
#   '吃',
#   '牛排'],
#  ['先',
#   '定義',
#   '分界線',
#   '好',
#   '公司',
#   '負責人',
#   '佔',
#   '公司',
#   '資本額',
#   '以上',
#   '淨收入',
#   '一年',
#   '超過',
#   '萬',
#   '親友',
#   '資助',
#   '萬',
#   '以內',
#   '存',
#   '銀行貸款',
#   '政府',
#   '補助',
#   '合夥',
#   '天使',
#   '投資人',
#   '法律',
#   '合法',
#   '社會',
#   '反感',
#   '產業',
#   '歲',
#   '以內',
#   '身邊',
#   '例子',
#   '有沒有',
#   '八卦'],
#  ['小嚕',
#   '朋友',
#   '睡覺',
#   '聞',
#   '腳',
#   '真的',
#   '奇怪',
#   '抓',
#   '聞',
#   '一聞',
#   '特別',
#   '好聞',
#   '有沒有',
#   '八卦',
#   'hi',
#   '謝謝',
#   '感受',
#   '心意',
#   '懶覺',
#   '五歲',
#   '好險',
#   '女',
#   '妹妹',
#   '綠水',
#   '喜歡',
#   '浴室',
#   '超',
#   '可愛'],
#  ['間',
#   '幹嘛',
#   '東上',
#   '分鐘',
#   '真的',
#   '好',
#   '想',
#   '尿',
#   '尿',
#   '啊啊啊',
#   '啊啊啊',
#   '是否',
#   '專板',
#   '本板',
#   '萬能',
#   '問板',
#   '兩則',
#   '問卦',
#   '自刪',
#   '被刪',
#   '算',
#   '兩篇',
#   '之內',
#   '看板',
#   '嚴格',
#   '禁止',
#   '政治',
#   '問卦',
#   '發文',
#   '問卦',
#   '前',
#   '請',
#   '先',
#   '仔細閱讀',
#   '相關',
#   '板規',
#   '行文',
#   '未滿',
#   '字',
#   '視同',
#   '鬧板',
#   '請',
#   '注意'],
#  ['發現自己',
#   '常在',
#   'ptt',
#   '上拉',
#   '仇恨',
#   '三不五時',
#   '嘴',
#   '一下',
#   '甲甲',
#   '南部',
#   '人',
#   '母豬',
#   '這有',
#   '辦法',
#   '停止',
#   '我怕',
#   '一天',
#   '現實',
#   '中',
#   '小心',
#   '脫口而出'],
#  ['屏東', '潮州', '冷熱', '冰', '有名', '圓環', '兩家', '自稱', '老店', '請問', '吃', '哪家', '正統'],
#  ['乳題',
#   '最近',
#   'FB',
#   '出現',
#   '好像',
#   '馬來西亞',
#   '圖文',
#   '作家',
#   '叫做',
#   '幹',
#   '幹貓',
#   '底下',
#   '瘋狂',
#   '戰',
#   '父權',
#   '定義',
#   '一堆',
#   '有沒有',
#   '八卦'],
#  ['鹽',
#   '酥',
#   '奶油',
#   '新',
#   '吃法',
#   '有人',
#   '試過',
#   '利亞',
#   '奶油',
#   '好吃',
#   '人想過',
#   '台灣',
#   '鹽',
#   '酥',
#   '雞',
#   '太',
#   '故步自封',
#   '開發',
#   '一些',
#   '新',
#   '吃法'],
#  ['安安',
#   '最近',
#   '禮拜',
#   '一直',
#   '看到',
#   '電視',
#   '在講',
#   '用電量',
#   '新聞',
#   '一所',
#   '大學',
#   '裡面',
#   '起碼',
#   '幾千',
#   '台',
#   '電腦',
#   '電腦',
#   '電燈',
#   '冷氣',
#   '飲水機',
#   '電梯',
#   '一些',
#   '沒得',
#   '用電',
#   '加',
#   '電費',
#   '應該',
#   '可怕',
#   '有沒有',
#   '一所',
#   '大學',
#   '夏天',
#   '一個月',
#   '電費',
#   '八卦',
#   '作者',
#   'Not',
#   'my',
#   'fault',
#   '板',
#   'Gossiping',
#   '標題',
#   'Re',
#   '問卦',
#   '妹妹',
#   '懷孕',
#   '肚子',
#   '撐得',
#   '好大',
#   '整天',
#   '說',
#   '低能',
#   '卡',
#   '一堆',
#   '幻想',
#   '文',
#   '八卦',
#   '充斥',
#   '妹妹',
#   '戰女',
#   '姐姐',
#   '學姊',
#   '意淫',
#   '文',
#   '真是',
#   '可悲'],
#  ['雞',
#   '出現',
#   '街頭巷尾',
#   '燒臘',
#   '店中',
#   '本體',
#   '滷雞',
#   '腿',
#   '看不到',
#   '玫瑰',
#   '紅色',
#   '烤雞',
#   '腿',
#   '命名',
#   '分隔',
#   '說',
#   '烤雞',
#   '腿',
#   '紅紅的',
#   '有加',
#   '玫瑰',
#   '我還',
#   '相信',
#   '有沒有',
#   '雞',
#   '八卦',
#   '太陽',
#   '餅',
#   '太陽',
#   '概念',
#   '蜂蜜',
#   '醃',
#   '香蕉'],
#  ['牽',
#   '一台',
#   '新',
#   '摩托車',
#   '車行',
#   '老闆',
#   '說',
#   '記得',
#   '汽油',
#   '要加',
#   '附帶',
#   '開車',
#   '行',
#   '幾十年',
#   '聽',
#   '沒錯',
#   '一旁',
#   '學徒',
#   '猛',
#   '點頭',
#   '騎去',
#   '加油',
#   '騎',
#   '一半',
#   '想到',
#   '油箱蓋',
#   '明明',
#   '寫',
#   '建議',
#   '使用',
#   '無鉛',
#   '汽油',
#   '一個',
#   '一個',
#   '車行',
#   '老闆',
#   '老老',
#   '經驗豐富',
#   '沒錯',
#   '引擎',
#   '廠商',
#   '設計',
#   '耶',
#   '該加',
#   '一種',
#   '加',
#   '一半',
#   '一半'],
#  ['全台灣',
#   '成功',
#   '園區',
#   '竹科',
#   '南科',
#   '中科',
#   '普普通通',
#   '有點',
#   '雞肋',
#   '產業',
#   '聚落',
#   '沒什麼',
#   '特別',
#   '幫助',
#   '聽說',
#   '高雄要',
#   '弄',
#   '個體',
#   '感',
#   '園區',
#   '整個',
#   '問號',
#   '軟體',
#   '為主',
#   '公司',
#   '聚落',
#   '有個',
#   '冷氣',
#   '網路',
#   '地方',
#   '一堆',
#   '阿宅',
#   '裡面',
#   '電腦',
#   '就行了',
#   '最多',
#   '硬體',
#   '需求',
#   '電腦',
#   '感測器',
#   '路竹',
#   '園區',
#   '木柵',
#   '園區',
#   '園區',
#   '木柵',
#   '園區',
#   '說',
#   '產值',
#   '不錯',
#   '園區',
#   '幹嘛',
#   '總',
#   '想',
#   '炒地皮',
#   '民調',
#   '第一名',
#   '市長',
#   '幹',
#   '這種',
#   '事',
#   '不用',
#   '園區',
#   '成長',
#   '直轄市',
#   '亂搞',
#   '本來',
#   '成長',
#   '直轄市',
#   '資源',
#   '亂蓋',
#   '東西',
#   '亂',
#   '放煙火',
#   '用來',
#   '做',
#   '基礎',
#   '建設',
#   '工作',
#   '機會',
#   '臺中',
#   '精密',
#   '工業',
#   '園區',
#   '聚集',
#   '捷安特',
#   '美利達',
#   '一堆',
#   '精密',
#   '自然',
#   '群聚',
#   '根本',
#   '園區',
#   '沒關係',
#   '園區',
#   '廠商',
#   'c',
#   'p',
#   '值',
#   '園區'],
#  ['本魯宅',
#   '吃',
#   '麥當勞',
#   '推出',
#   '點點',
#   '卡',
#   '後',
#   '更是',
#   '消費',
#   '再',
#   '送',
#   '一個',
#   '套餐',
#   '計算',
#   '之後',
#   '吃',
#   '銅板',
#   '餐點',
#   '兩份',
#   '一張',
#   '鈔票',
#   '打發',
#   'app',
#   '抽到',
#   '買',
#   '一送',
#   '一時',
#   '買',
#   '有沒有',
#   '麥當勞',
#   '吃',
#   '最',
#   '划算',
#   '八卦',
#   '人稱',
#   '交大',
#   '薛之謙',
#   '附上',
#   '自拍照',
#   '一張'],
#  ['安安',
#   '小弟',
#   '發現',
#   '台北',
#   '車站',
#   '一堆',
#   '消防車',
#   '消防員',
#   '進出',
#   '車站',
#   '有人',
#   '知道',
#   '小',
#   '失火',
#   '好',
#   '幹',
#   '嚇死',
#   '陰毛'],
#  ['現在', '天氣', '很熱', '沒人要', '菜', '工作', '請問', '有沒有', '薪水', '請', '人', '八卦'],
#  ['今天',
#   '新聞',
#   '看到',
#   '有甲甲',
#   '想',
#   '捐血',
#   '護理',
#   '師',
#   '拒絕',
#   '上網',
#   '抱怨',
#   '說',
#   '歧視',
#   '想',
#   '說',
#   '低能',
#   '卡',
#   '點過',
#   '看看',
#   '發現',
#   '低能',
#   '卡',
#   '彩虹',
#   '版',
#   '記得',
#   '類似',
#   '文說',
#   '一袋',
#   '女王',
#   '節目',
#   '一集',
#   '有個',
#   '來賓',
#   '說',
#   '兒子',
#   '歲',
#   '不好',
#   '女生',
#   '抱',
#   '安靜',
#   '曾',
#   'x',
#   '句',
#   '摁',
#   '不錯',
#   '性',
#   '正確',
#   '甲甲',
#   '發文',
#   '抨擊',
#   '說',
#   '歧視',
#   '有沒有',
#   '好像',
#   '甲甲',
#   '就要',
#   '百依百順',
#   '看清楚',
#   '規定',
#   '補',
#   '玻璃心',
#   '違反規定',
#   '討拍',
#   '說',
#   '歧視',
#   '低能',
#   '人氣',
#   '高',
#   '沒道理'],
#  ['每次',
#   '飛機',
#   '失事',
#   '全組',
#   '人員',
#   '葬身',
#   '那位',
#   '每個',
#   '人',
#   '發',
#   '一副',
#   '降落傘',
#   '椅子',
#   '裝上',
#   '彈跳',
#   '裝置',
#   '飛機',
#   '失事',
#   '直接',
#   '全部',
#   '人',
#   '彈跳',
#   '再開',
#   '降落傘',
#   '想法',
#   '是不是',
#   '天才',
#   'O',
#   'O'],
#  ['正在',
#   '直播',
#   '人氣',
#   '高',
#   '找',
#   '網路',
#   '資料',
#   '原來',
#   '悟空',
#   '妹',
#   '之前',
#   '曉得',
#   '幹嘛',
#   '有沒有',
#   '悟空',
#   '妹',
#   '八卦'],
#  ['看到',
#   '一個',
#   '大奶妹',
#   '人',
#   '說',
#   '奶大',
#   '人',
#   '說',
#   '豐滿',
#   '本魯',
#   '覺得',
#   '奶大',
#   '說',
#   '奶大',
#   '豐滿',
#   '講話',
#   '好處',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Samsung',
#   'SMJ710GN'],
#  ['國家',
#   '窮',
#   '桃園',
#   '還想',
#   '鐵路',
#   '地下',
#   '化',
#   '當成',
#   '首都',
#   '當成',
#   '台北',
#   '囉',
#   '台中',
#   '高架',
#   '化',
#   '桃園',
#   '地下',
#   '化',
#   '一個',
#   '地下',
#   '化',
#   '多少錢',
#   '花',
#   '錢',
#   '很爽',
#   '原本',
#   '高架',
#   '化',
#   '預定',
#   '明年',
#   '通車',
#   '拆掉',
#   '重來',
#   '國家',
#   '有錢',
#   '利益',
#   '犧牲',
#   '地方',
#   '桃園',
#   '資格',
#   '花',
#   '多錢',
#   '桃園',
#   '想',
#   '真的',
#   '以為',
#   '變成',
#   '首都',
#   '想學',
#   '高雄',
#   '欠',
#   '國家',
#   '最多到',
#   '兩個',
#   '阿斗',
#   '城市',
#   '桃園',
#   '真的',
#   '鄉下',
#   '沿路',
#   '一片',
#   '田',
#   '知道',
#   '地下',
#   '化',
#   '搞',
#   '燦神',
#   '嘴'],
#  ['今天',
#   '照常',
#   '摸摸',
#   '學生',
#   '的頭',
#   '卻',
#   '一個',
#   '太妹',
#   '嫌',
#   '噁心',
#   '這是',
#   '真的',
#   '真的',
#   '覺得',
#   '認真',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆',
#   '老婆'],
#  ['歲',
#   '已經',
#   '醫學界',
# ...
#   '好看',
#   '垃圾',
#   '是不是',
#   '文創',
#   '這方面',
#   '八卦'],
#  ['龔重安',
#   '女童',
#   '割',
#   '喉案',
#   '兇手',
#   '無期徒刑',
#   '讞',
#   '法官',
#   '不敢',
#   '判死',
#   '廢死',
#   '腰',
#   '執行',
#   '死刑',
#   '劊子手',
#   '留下',
#   '陰影',
#   '不想',
#   '背上',
#   '一條',
#   '人命',
#   '好',
#   '今天',
#   '改成',
#   '被害',
#   '家屬',
#   '選擇權',
#   '死刑',
#   '無期徒刑',
#   '兩種',
#   '家屬',
#   '選擇',
#   '原諒',
#   '無期徒刑',
#   '選擇',
#   '死刑',
#   '擊斃',
#   '兇手',
#   '不敢',
#   '殺',
#   '代表',
#   '決心',
#   '不夠',
#   '原諒',
#   '家屬',
#   '選擇',
#   '民眾',
#   '腰',
#   '司法',
#   '不公',
#   '對方',
#   '有錢',
#   '權',
#   '家屬',
#   '賺',
#   '一筆',
#   '好',
#   '廢死',
#   '理由',
#   '腰',
#   '正義',
#   '大旗',
#   '廢死',
#   '腰',
#   '有沒有',
#   '卦',
#   '廢死',
#   '幹',
#   '娘',
#   '卒',
#   '帥',
#   '馬',
#   '此時',
#   '車',
#   '帥有',
#   '何用',
#   '有車',
#   '馬',
#   '馬子',
#   '狡兔',
#   '三窟',
#   '馬子',
#   '一個',
#   '加害者',
#   '裝瘋',
#   '逃離',
#   '司法',
#   '制裁',
#   '家屬',
#   '選擇',
#   '原諒',
#   '不好',
#   '心裡',
#   '學上',
#   '家屬',
#   '產生',
#   '失調',
#   '真正',
#   '原諒',
#   '兇手',
#   '不好',
#   '消除',
#   '仇恨',
#   '不好',
#   '選',
#   '立委',
#   '有人',
#   '投',
#   '參政',
#   '管道',
#   '樂意',
#   '嘻嘻',
#   '反智',
#   '摳連',
#   '反智',
#   '嘻嘻',
#   '拜託',
#   '拉低',
#   '我方',
#   '水準',
#   '好',
#   '認真',
#   '說',
#   '開玩笑',
#   '謝謝',
#   '喔',
#   '喔',
#   '喔',
#   '湊',
#   '人',
#   '誤',
#   '喔',
#   '好',
#   '說',
#   '說',
#   '哪裡',
#   '反智',
#   '說',
#   '連個',
#   '屁',
#   '說不出來',
#   '反智',
#   '摳連',
#   '哭哭',
#   '是不是',
#   '小學',
#   '還沒',
#   '畢業',
#   '刑罰',
#   '存在',
#   '知道',
#   '刑罰',
#   '存在',
#   '意義',
#   '知道',
#   '還敢',
#   '犯人',
#   '改過',
#   '向善',
#   '該是',
#   '出家',
#   '關在',
#   '牢裡',
#   '刑罰',
#   '主要',
#   '安定',
#   '社會',
#   '功能',
#   '知不知道',
#   '喔',
#   '忘記',
#   '現在',
#   '正在',
#   '放暑假',
#   '喔',
#   '喔',
#   '逃過',
#   '重',
#   '制裁',
#   '逃',
#   '喔',
#   '胃',
#   '硬衝',
#   '輕判',
#   '逃過',
#   '喔',
#   '好',
#   '棒棒',
#   '滑坡',
#   '摳連',
#   '說',
#   '只會',
#   '說',
#   '反智',
#   '卻',
#   '思考',
#   '人',
#   '反智',
#   '幫',
#   '改錯',
#   '字',
#   '嘻嘻',
#   '終於',
#   '釣到',
#   '這種',
#   '人',
#   '先',
#   '檢討',
#   '說話',
#   '人',
#   '先',
#   '討論',
#   '事情',
#   '標準',
#   '人',
#   '事',
#   '叫做',
#   '思考',
#   '人',
#   '這不',
#   '一個',
#   '例子',
#   '哭哭',
#   '喔',
#   '釣到',
#   'www',
#   '可惜',
#   '根本',
#   '認識',
#   '政治',
#   '人物',
#   'www'],
#  ['本魯',
#   '早上',
#   '睡',
#   '一半',
#   '發現',
#   '電風扇',
#   '沒動靜',
#   '發現',
#   '家裡',
#   '整棟',
#   '沒電',
#   '總開關',
#   '開關',
#   '過了',
#   '沒用',
#   '本魯要',
#   '熱死',
#   '電源',
#   '恢復正常',
#   '愛',
#   '發電'],
#  ['最近',
#   '讀',
#   '希臘神話',
#   '讀',
#   '章',
#   '節時',
#   '總覺',
#   '帕里斯',
#   '評判',
#   '實在',
#   '有意思',
#   '赫拉',
#   '說',
#   '要給',
#   '帕里斯',
#   '成為',
#   '統領',
#   '全',
#   '亞洲',
#   '國王',
#   '給予',
#   '至高無上',
#   '權力',
#   '雅典娜',
#   '說',
#   '要給',
#   '帕里斯',
#   '智慧',
#   '戰場',
#   '時',
#   '戰無不勝',
#   '要給',
#   '帕里斯',
#   '全世界',
#   '最美',
#   '女人',
#   '愛情',
#   '覺得',
#   '命題',
#   '邏輯',
#   '有點',
#   '問題',
#   '真的',
#   '至高無上',
#   '權力',
#   '打仗',
#   '時',
#   '真的',
#   '戰無不勝',
#   '還怕',
#   '得不到',
#   '世界',
#   '最美',
#   '女子',
#   '鑽牛角尖',
#   '肥宅會',
#   '選擇',
#   '八卦'],
#  ['鄉民',
#   '神人',
#   '早安',
#   '事情',
#   '子',
#   '小弟',
#   '受託',
#   '幫',
#   '買',
#   '營養品',
#   '一瓶',
#   '銀杏',
#   '魚油',
#   '瓶裝',
#   '膠囊',
#   'Costco',
#   '賣',
#   '小弟',
#   '翻遍',
#   'Costco',
#   '找',
#   '不到',
#   '線索',
#   '一張',
#   '圖片',
#   '上網',
#   '找遍',
#   '各大',
#   '購物網',
#   '找',
#   '不到',
#   '相同',
#   '圖片',
#   '營養品',
#   '想',
#   '請',
#   '神',
#   '人們',
#   '看看',
#   '有沒有',
#   '人',
#   '知道',
#   '一瓶',
#   '品牌',
#   '看過',
#   '賣',
#   '小弟',
#   '.....',
#   '以下',
#   '瓶裝',
#   '圖片'],
#  ['小弟',
#   '今天',
#   '搭',
#   '捷運',
#   '等車',
#   '一個',
#   '開',
#   '電動',
#   '代步車',
#   '阿伯',
#   '連路',
#   '直接',
#   '背後',
#   '衝',
#   '害',
#   '直接',
#   '撞倒',
#   '還好',
#   '背包',
#   '包',
#   '送',
#   '醫院',
#   '阿伯',
#   '一聲',
#   '對不起',
#   '說',
#   '直接',
#   '肇事',
#   '逃逸',
#   '有沒有',
#   '捷運',
#   '開',
#   '電動',
#   '代步車',
#   '還不看',
#   '路',
#   '人',
#   '想',
#   '八卦',
#   '車站',
#   '等車',
#   '撞',
#   '行動不便',
#   '看路',
#   '車來',
#   '我要',
#   '趕上',
#   '車',
#   '搭',
#   '電梯',
#   '門',
#   '直接',
#   '關上',
#   '真的',
#   '討厭',
#   '忠孝',
#   '新生',
#   '電梯',
#   '設計',
#   '真的',
#   '騎車',
#   '開車',
#   '遇過',
#   '開',
#   '大客車',
#   '砂石車',
#   '還兇',
#   '看路',
#   '現在',
#   '背',
#   '還會痛',
#   '還蠻',
#   '大台',
#   '道路交通',
#   '法有',
#   '管到',
#   '代步車',
#   '代步車',
#   '確定'],
#  ['問卦',
#   '中國',
#   '人',
#   '驕傲',
#   '年代',
#   '是不是',
#   '已經',
#   '來到',
#   '先說',
#   '前面',
#   '獨派',
#   '昨天',
#   '朋友',
#   '吃飯',
#   '朋友',
#   '一個',
#   '香港',
#   '人住',
#   '上海',
#   '一個',
#   '浙江人',
#   '聊著',
#   '聊著',
#   '國內',
#   '大陸',
#   '進步',
#   '壯大',
#   '身為',
#   '炎黃子孫',
#   '心情',
#   '真',
#   '好',
#   '深感',
#   '驕傲',
#   '問卦',
#   '中國',
#   '人',
#   '驕傲',
#   '年代',
#   '是不是',
#   '已經',
#   '來到',
#   '萬惡',
#   '無能',
#   '蔡',
#   '英文',
#   '給我',
#   '下台',
#   '國民黨',
#   '相關',
#   '經濟犯罪',
#   '起訴',
#   '判刑',
#   '潛逃',
#   '列表',
#   '全員',
#   '逃走',
#   '中',
#   '牠',
#   '萬惡',
#   '國民黨',
#   '共識',
#   '共識',
#   '一中',
#   '框架',
#   '一中',
#   '同表',
#   '賣國',
#   '賣台',
#   '台',
#   '中',
#   '吃飯',
#   '聊天'],
#  ['廢', '文章', '發錢', '爆文', '是不是', '真的', '想', '測試', '一下', '看看', '推爆', '樓給'],
#  ['安安',
#   '最近',
#   '核能',
#   '議題',
#   '浮現',
#   '拉',
#   '核能',
#   '反對',
#   '原因',
#   '兩個',
#   '一個',
#   '安全性',
#   '最',
#   '先進',
#   '核四是',
#   '多家',
#   '廠商',
#   '合作',
#   '蓋起來',
#   '政治',
#   '因素',
#   '工期',
#   '太長',
#   '導致',
#   '安全',
#   '疑慮',
#   '越來越',
#   '高',
#   '民眾',
#   '感性',
#   '層面',
#   '福島',
#   '核災',
#   '嚇到',
#   '核災',
#   '管控',
#   '高',
#   '不信任感',
#   '一個',
#   '環保',
#   '性',
#   '科技進步',
#   '核廢料',
#   '再',
#   '處理',
#   '科技',
#   '發展',
#   '高階',
#   '核廢料',
#   '能夠',
#   '處理',
#   '再次',
#   '發電',
#   '處理',
#   '後',
#   '高',
#   '高階',
#   '核廢料',
#   '需要',
#   '處理',
#   '台灣',
#   '最新',
#   '核四',
#   '辦法',
#   '做到',
#   '高階',
#   '再',
#   '處理',
#   '政治',
#   '因素',
#   '辦法',
#   '發展',
#   '內部',
#   '因素',
#   '立法',
#   '蓋',
#   '新',
#   '核電廠',
#   '外',
#   '再',
#   '處理',
#   '技術',
#   '製做',
#   '核彈',
#   '原料',
#   '相關',
#   '核電廠',
#   '安全性',
#   '問題',
#   '淪',
#   '理組',
#   '文組',
#   '口水戰',
#   '認真',
#   '討論一下',
#   '環保',
#   '性',
#   '問題',
#   '結論',
#   '繼續',
#   '使用',
#   '核電',
#   '技術',
#   '減少',
#   '高階',
#   '核廢料',
#   '情況',
#   '下',
#   '勢必',
#   '找到',
#   '貯存',
#   '高階',
#   '核廢料',
#   '方法',
#   '海運',
#   '不太可能',
#   '發生',
#   '目前',
#   '高階',
#   '核廢料',
#   '暫時',
#   '放在',
#   '核電廠',
#   '裡',
#   '好像',
#   '已經',
#   '快滿',
#   '最好',
#   '方式',
#   '乾式',
#   '貯存',
#   '存在',
#   '地震帶',
#   '沙漠',
#   '裡',
#   '需要',
#   '解決',
#   '問題',
#   '找到',
#   '一塊',
#   '好',
#   '好好',
#   '收藏',
#   '台灣',
#   '最',
#   '適合',
#   '乾式',
#   '貯存',
#   '地點',
#   '哪裡',
#   '考慮',
#   '容量',
#   '太小',
#   '核廢料',
#   '只會',
#   '增加',
#   '減少',
#   '安全',
#   '至少',
#   '耐震',
#   '土石',
#   '鬆動',
#   '政治',
#   '附近',
#   '有太多',
#   '居民',
#   '沒完沒了',
#   '環保',
#   '衝擊',
#   '小',
#   '影響',
#   '棲地',
#   '水源',
#   '知道',
#   '考量',
#   '別嘴',
#   '砲',
#   '說',
#   '放',
#   '你家',
#   '放',
#   '我家',
#   '拉',
#   '你家',
#   '路線',
#   '能夠',
#   '發廢文',
#   '適合',
#   '放',
#   '台灣',
#   '地點',
#   '能夠',
#   '放個',
#   '幾千年',
#   '核廢料',
#   '咧',
#   '放',
#   '核電廠',
#   '裡面',
#   '欸',
#   '高階',
#   '好像',
#   '上船',
#   '過海',
#   '誤會',
#   '拉',
#   '這是',
#   '一個',
#   '全台灣',
#   '一起',
#   '面對',
#   '議題',
#   '放',
#   '她家',
#   '放',
#   '你家',
#   '放',
#   '我家',
#   '搞不好',
#   '鄰居',
#   '痾',
#   '將你',
#   '意見',
#   '歸納',
#   '發展',
#   '高階',
#   '核廢料',
#   '新',
#   '用途',
#   '科技',
#   '研發',
#   '做成',
#   '武器',
#   '好像',
#   '人類',
#   '福祉',
#   '太好',
#   '幫助',
#   '連噓',
#   '兩次',
#   '辛苦',
#   '笑',
#   '恩',
#   '公布',
#   '一下',
#   '你家',
#   '住址',
#   '地方',
#   '看看',
#   '喔',
#   '喔',
#   '喔',
#   '第一次',
#   '聽到',
#   '多一點',
#   '資訊',
#   '政治',
#   '因素',
#   '太強',
#   '不太可能',
#   '高階',
#   '核廢料',
#   '上船',
#   '痾',
#   '目前',
#   '實質',
#   '比較',
#   '可行',
#   '高階',
#   '核廢料',
#   '火力',
#   '爐渣',
#   '好像',
#   '不太',
#   '埋',
#   '爐渣',
#   '放',
#   '高階',
#   '核廢料',
#   '場地',
#   '考量',
#   '應該',
#   '先',
#   '跳',
#   '無法',
#   '聚焦',
#   '討論',
#   '離島',
#   '運送',
#   '東部',
#   '地質',
#   '獲得',
#   '認可',
#   '第三點',
#   '值得',
#   '仔細',
#   '討論',
#   '內容',
#   '有點',
#   '濫情',
#   'OK',
#   '....',
#   '議題',
#   '重要',
#   '台灣',
#   '太空',
#   '科技',
#   '已經',
#   '製造',
#   '衛星',
#   '囉',
#   '火箭',
#   '運送',
#   '核',
#   '廢',
#   '限制',
#   '好像',
#   '找到',
#   '合適',
#   '地點',
#   '困難'],
#  ['如題',
#   '公家',
#   '單位',
#   '下午',
#   '開',
#   '冷氣',
#   '耗電量',
#   '佔',
#   '台電',
#   '用電量',
#   '影響',
#   '根本',
#   '本來',
#   '還說',
#   '兩個',
#   '禮拜',
#   '冷氣',
#   '一個',
#   '禮拜',
#   '達成',
#   '今天',
#   '開',
#   '冷氣',
#   '自打',
#   '臉',
#   '行政院長',
#   '檢討',
#   '這條',
#   '命令',
#   '這條',
#   '命令',
#   '負責',
#   '辦',
#   '家家酒',
#   '荒謬',
#   '腦殘',
#   '真是',
#   '極限',
#   '說明',
#   '開',
#   '冷氣',
#   '幫助',
#   '姑婆',
#   '芋',
#   '發言人',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'OPPO',
#   'X9079'],
#  ['蛤', '黑心', '內幕', '一種', '肉類', '火腿', '勒', '吃個', '早餐'],
#  ['標題',
#   '寫',
#   '台獨',
#   '有人',
#   '堅持',
#   '說',
#   '建國',
#   '正確',
#   '想',
#   '表達',
#   '台灣',
#   '變成',
#   '主權',
#   '獨立國家',
#   '記得',
#   '以前',
#   '終止',
#   '代管',
#   '自決',
#   '建國',
#   '文章',
#   '一直',
#   '推爆',
#   '好像',
#   '覺得',
#   '台灣',
#   '唯有',
#   '建國',
#   '未來',
#   '可言',
#   '最近',
#   '建國',
#   '派',
#   '好像',
#   '式微',
#   '人理',
#   '台灣',
#   '人',
#   '真的',
#   '想要',
#   '獨立',
#   '中共',
#   '統一',
#   '好',
#   '感覺',
#   '多數',
#   '台灣',
#   '人',
#   '好像',
#   '後者',
#   '好',
#   '耶',
#   '好像',
#   '昨天',
#   '打槍',
#   '確定',
#   '台灣成',
#   '美國',
#   '州',
#   '政治',
#   '自由',
#   '時報',
#   '電子報',
#   '感覺',
#   '台灣',
#   '位置',
#   '太',
#   '重要',
#   '非',
#   '拿到',
#   '手',
#   '不可',
#   '中華民國',
#   '非',
#   '聯合國',
#   '會員國',
#   '觀察員',
#   '主權',
#   '獨立國家',
#   '政治',
#   '實體',
#   '聶',
#   '斯特',
#   '河',
#   '沿岸',
#   '卡拉',
#   '巴克',
#   '提亞',
#   '阿布哈茲',
#   '北賽',
#   '普',
#   '勒斯',
#   '索',
#   '馬利蘭',
#   '阿拉伯',
#   '撒哈拉',
#   '民主',
#   '共和國',
#   '馬爾他',
#   '騎士團',
#   '庫克',
#   '群島',
#   '人民共和國',
#   '克',
#   '人民共和國',
#   '中華民國',
#   '馬爾他',
#   '騎士團',
#   '真的',
#   '聽過',
#   '找',
#   '俄羅斯',
#   '正妹',
#   '耶'],
#  ['立委',
#   '說',
#   '核一核',
#   '形同',
#   '提前',
#   '除役',
#   '再',
#   '啟動',
#   '囉',
#   '行政院',
#   '發言人',
#   '說',
#   '葉克膜',
#   '囉',
#   '同志',
#   '說',
#   '提前',
#   '除役',
#   '囉',
#   '台積電',
#   '全省',
#   '約',
#   '萬千瓦',
#   '占',
#   '台電',
#   '供電',
#   '相當',
#   '核電廠',
#   '一部',
#   '機組',
#   '現在',
#   '已經',
#   '橘燈',
#   '前',
#   '陣子',
#   '紅燈',
#   '台積',
#   '米廠',
#   '沒電',
#   '可用',
#   '掰掰',
#   '囉',
#   'ω',
#   '阿災',
#   '林全',
#   '離岸',
#   '風機',
#   '先',
#   '要說',
#   '有沒有',
#   '插',
#   '還要',
#   '年'],
#  ['ㄤ',
#   'ㄤ',
#   '肥宅',
#   '窩',
#   '大阪',
#   '環球',
#   '影城',
#   '排',
#   '蜘蛛人',
#   '噗',
#   'ㄓ',
#   '噗',
#   'ㄓ',
#   '要排',
#   '分鐘',
#   '欸',
#   '這段',
#   '時間',
#   '窩要',
#   '幹嘛',
#   '肝',
#   '卦',
#   '真的',
#   'QQ',
#   '窩',
#   '剛剛',
#   '小小',
#   '買',
#   '花'],
#  ['小時候',
#   '夢想',
#   '職業',
#   '太空人',
#   '醫生',
#   '長大',
#   '比較',
#   '實際',
#   '有個',
#   '喜歡',
#   '公司',
#   '喜歡',
#   '牌子',
#   '高',
#   '中時',
#   '進',
#   '航空公司',
#   '嚮往',
#   'ㄉ',
#   '像是',
#   '長榮',
#   '阿聯酋',
#   '這種',
#   '只',
#   '是不是',
#   '空服員',
#   '機師',
#   '這類',
#   '工作',
#   '惹',
#   '夢想',
#   '進入',
#   '公司',
#   '我想',
#   '過當',
#   '導遊',
#   '覺得',
#   '最後',
#   '旅行',
#   '熱忱',
#   '覺得',
#   '出差',
#   '工作',
#   '好'],
#  ['剛看',
#   '一個',
#   'Youtuber',
#   '台主',
#   '大學',
#   '連成',
#   '北科',
#   '台科',
#   '沒考上',
#   '鄉民',
#   '眼裡',
#   '廢物',
#   '鄉民',
#   '邏輯',
#   '夾著',
#   '懶蛋',
#   '跑',
#   '日本',
#   '大學',
#   '畢業',
#   '後',
#   '日本',
#   '工作',
#   '現在',
#   '辭掉',
#   '工作',
#   '專心',
#   '大學畢業',
#   '後',
#   '挾著',
#   '雙語',
#   '優勢',
#   '日本',
#   '企業',
#   '超',
#   '愛用',
#   '留在',
#   '日本',
#   '賺',
#   '日幣',
#   '念台',
#   '科大',
#   '優勢',
#   '哪裡',
#   '抬',
#   '蚵',
#   '台科',
#   '沒考上',
#   '廢物',
#   '鄉民',
#   '邏輯',
#   '通通',
#   '出國',
#   '念書',
#   '賺',
#   '外幣',
#   '留在',
#   '台灣戰',
#   '學校',
#   '領',
#   '作',
#   '甚'],
#  ['資深',
#   '蠕動',
#   '有點',
#   '頻繁',
#   '是不是',
#   '以為',
#   '民進黨',
#   '黑',
#   '國民黨',
#   '有救',
#   '林',
#   '真的',
#   '投',
#   '知道',
#   '有腦',
#   '人',
#   '幹',
#   '譙',
#   '民進黨',
#   '譙',
#   '下次',
#   '投票',
#   '最',
#   '投',
#   '投給',
#   '心裡',
#   '奉',
#   '圭臬',
#   '那塊',
#   '垃圾',
#   '醒',
#   '回',
#   '祖國',
#   '是不是',
#   '慘啊',
#   '黑',
#   '民進黨',
#   '永遠',
#   '垃圾',
#   '黨',
#   '抱歉',
#   '第一句',
#   '邏輯',
#   '完全',
#   '相反',
#   '典型',
#   '症狀',
#   '可憐',
#   '示範',
#   '內文',
#   '扯',
#   '喔',
#   '邏輯',
#   '真棒'],
#  ['好',
#   '小弟',
#   '買',
#   '東西',
#   '被叫',
#   '成',
#   '弟弟',
#   '已經',
#   'ㄍ',
#   '大學',
#   '知道',
#   '這種',
#   '外表',
#   '年輕',
#   '肥宅',
#   '有加',
#   '分',
#   'ㄇ'],
#  ['幾年',
#   'R',
#   '時不時',
#   '各大',
#   '社群',
#   '媒體',
#   '看到',
#   '辛苦',
#   '工地',
#   '人',
#   '辛苦',
#   '水電',
#   '師傅',
#   '努力',
#   '學徒',
#   '這類',
#   '標題',
#   '底下',
#   '嘴',
#   '坐',
#   '辦公室',
#   '年輕人',
#   '好逸惡勞',
#   '看不起',
#   '藍領',
#   '階級',
#   '再',
#   '嘴',
#   '一下',
#   '薪水',
#   '藍領',
#   '高',
#   '人',
#   '行政',
#   '職',
#   '批鬥',
#   '拿來',
#   '師傅',
#   '級',
#   '小圈圈',
#   '自慰',
#   '好爽',
#   '想過',
#   '藍領',
#   '看不起',
#   'R',
#   '有沒有',
#   '同情',
#   '藍領',
#   '趨勢',
#   'DER',
#   '八卦',
#   '兄弟',
#   '藍領',
#   '瞧不起',
#   '低薪',
#   '白領',
#   '藍領',
#   '社會',
#   '唾棄',
#   '調調',
#   '在家',
#   '裡',
#   '上班',
#   '低階',
#   '白領'],
#  ['昨日',
#   '大林',
#   '電廠',
#   '加入',
#   '救援',
#   '行列',
#   '燈號',
#   '瞬間',
#   '橘',
#   '度',
#   '信徒',
#   '好像',
#   '甩',
#   '一個',
#   '耳光',
#   '今日',
#   '下起',
#   '豪',
#   '大雨',
#   '更是',
#   '機會',
#   '度',
#   '信徒',
#   '限電',
#   '夢',
#   '是不是',
#   '醒'],
#  ['ㄤ',
#   '風箏',
#   '陰天',
#   '擱淺',
#   '想念',
#   '還在',
#   '等待',
#   '救援',
#   '文山',
#   '不太會',
#   '放風箏',
#   '風箏',
#   '飛',
#   '躺',
#   '地上',
#   '還要',
#   '笑',
#   '擱淺',
#   '放風箏',
#   '技巧',
#   '太爛',
#   'ㄅ',
#   '有掛'],
#  ['咖啡',
#   '套',
#   '蜂蜜',
#   '布',
#   '人試過',
#   '感覺',
#   '怪怪的',
#   '試試',
#   '覺得',
#   '人間',
#   '美味',
#   '是不是',
#   '超想',
#   '試',
#   '咖啡',
#   '套',
#   '蜂蜜',
#   'best',
#   'coffee'],
#  ['崩崩',
#   '爽歪歪',
#   '這盤',
#   '沒救',
#   '惹',
#   '年',
#   '新高',
#   '嘻嘻',
#   '有沒有',
#   '八卦',
#   '草本',
#   '綱目',
#   '聽過',
#   '本草綱目',
#   '萬點',
#   '時',
#   '咻',
#   '真',
#   'der',
#   '還好',
#   '草本',
#   '綱目',
#   '聽過',
#   '本草綱目'],
#  ['台灣',
#   '國際',
#   '視為',
#   '正常',
#   '國家',
#   '做起',
#   '事情',
#   '綁',
#   '手',
#   '綁腳',
#   '國家',
#   '定位',
#   '不明',
#   '容易',
#   '產出',
#   '吃裡',
#   '扒',
#   '外',
#   '商人',
#   '台灣',
#   '很棒',
#   '一點',
#   '不輸',
#   '日韓',
#   '平起平坐',
#   '本錢',
#   '重點',
#   '定位',
#   '明確',
#   '力量',
#   '獨立',
#   '不用',
#   '天天',
#   '中國',
#   '套',
#   '小鞋',
#   '一個',
#   '天天',
#   '被套',
#   '小鞋',
#   '人',
#   '能力',
#   '無法',
#   '得到',
#   '充份',
#   '釋放',
#   '美國',
#   '支',
#   '支持',
#   '辦法',
#   '說服',
#   '世界',
#   '國家',
#   '全部',
#   '支持',
#   '美國',
#   '吞下去',
#   '人因',
#   '夢想',
#   '偉大',
#   '東西',
#   '慢慢來',
#   '羅馬不是',
#   '一天',
#   '造成',
#   '天然',
#   '世代',
#   '掌權',
#   '勢頭',
#   '老人',
#   '總會',
#   '死',
#   '台灣',
#   '猛',
#   '地方',
#   '缺',
#   '世界',
#   '佔有',
#   '一席之地',
#   '你換',
#   '一個',
#   '角度',
#   '日韓',
#   '石油',
#   '台灣',
#   '旁邊',
#   '先',
#   '美不美',
#   '好',
#   '國家',
#   '決定',
#   '整天',
#   '威脅',
#   '套',
#   '小鞋',
#   '就要',
#   '這種',
#   '脫離',
#   '霸凌',
#   '過程',
#   '值得',
#   '獨立',
#   '後',
#   '一個',
#   '階段',
#   '長大',
#   '離開',
#   '爸',
#   '媽',
#   '比較',
#   '長大',
#   '後',
#   '小時候',
#   '景況',
#   '嘻嘻',
#   '日',
#   '韓客',
#   '臉色',
#   '決定',
#   '世界',
#   '小',
#   '中國',
#   '選擇',
#   '方向',
#   '沒聽',
#   '起跑點',
#   '至少',
#   '已經',
#   '贏在',
#   '起跑點',
#   '繼續',
#   '維持',
#   '不讓',
#   '中國',
#   '趕上',
#   '好',
#   '中國',
#   '不用',
#   '產業',
#   '幾項',
#   '贏',
#   '就夠',
#   '說得好',
#   '想',
#   '辦法',
#   '起飛',
#   '嘻嘻',
#   '選擇',
#   '獨立',
#   '不用',
#   '付出',
#   '代價',
#   '想要',
#   '選擇',
#   '獨立',
#   '雄',
#   '整天',
#   '胖虎',
#   '打壓',
#   '大雄',
#   '打壓',
#   '打壓',
#   '獨立',
#   '獨立',
#   '打壓',
#   '不想',
#   '獨立',
#   '軟弱',
#   '呈現',
#   '期待',
#   '中國',
#   '垮台',
#   '變成',
#   '民主制度',
#   '印度',
#   '亂',
#   '不用',
#   '嘻嘻',
#   'XD',
#   '好笑'],
#  ['下雨', '惹', '溫度', '降', '蔡', '政府', '解套', '台', '套', '安心', '開', '度'],
#  ['嘻哈是',
#   '嘻哈是',
#   '一種',
#   '態度',
#   '搖滾',
#   '搖滾',
#   '一種',
#   '態度',
#   '金屬',
#   '金屬',
#   '一種',
#   '態度',
#   '龐克',
#   '龐克',
#   '一種',
#   '態度',
#   '饒舌',
#   '饒舌',
#   '一種',
#   '態度',
#   '態度',
#   '帶有',
#   '批判',
#   '社會',
#   '態度',
#   '他媽',
#   '每次',
#   '問',
#   '這種',
#   '問題',
#   '得到',
#   '答案',
#   '好像',
#   '屌',
#   '膩嗎',
#   '好好',
#   '回答',
#   '名詞',
#   '定義',
#   '說',
#   '搖滾',
#   '態度',
#   '樂器',
#   '玩',
#   '搖滾',
#   '好',
#   '有沒有',
#   '八卦'],
#  ['政府',
#   '正',
#   '積極',
#   '推動',
#   '離岸',
#   '風電',
#   '建設',
#   '看看',
#   '離岸',
#   '風電',
#   '機組',
#   '一支',
#   '支',
#   '風機',
#   '海上',
#   '多麼',
#   '壯觀',
#   '大支',
#   '風電',
#   '機組',
#   '安裝',
#   '海上',
#   '何不',
#   '安裝',
#   '太陽能',
#   '板',
#   '相信',
#   '安裝',
#   '太陽能',
#   '板',
#   '建設',
#   '成本',
#   '應該',
#   '單價',
#   '風電',
#   '機組',
#   '便宜',
#   '台灣',
#   '島內',
#   '裝設',
#   '太陽能',
#   '電廠',
#   '土地',
#   '應該',
#   '接近',
#   '飽和',
#   '太陽能',
#   '板',
#   '風電',
#   '機組',
#   '不易',
#   '颱風',
#   '吹壞',
#   '發展',
#   '離岸',
#   '太陽能'],
#  ['幾個',
#   '星期',
#   '前',
#   '小盛',
#   '開台',
#   '開台',
#   '小時',
#   '抖內',
#   '好幾',
#   '鎂',
#   '算',
#   '打工',
#   '還賺',
#   '還要',
#   '打工',
#   '天天',
#   '開',
#   'lol',
#   '賺',
#   '有沒有',
#   '卦'],
#  ['乳蹄',
#   '現在',
#   '治安',
#   '噗',
#   '好',
#   '防身術',
#   '重要',
#   '技能',
#   '節錄自',
#   '時報',
#   '新聞',
#   '人力',
#   '銀行',
#   '刊登',
#   '美編',
#   '徵才',
#   '廣告',
#   '月薪',
#   '月',
#   '休',
#   '天',
#   '工作',
#   '內容',
#   '包含',
#   '巡邏',
#   '建築物',
#   '周遭',
#   '環境',
#   '保護',
#   '保全',
#   '之人',
#   '安全',
#   '監視器',
#   '畫面',
#   '監看',
#   '出入',
#   '份子',
#   '給予',
#   '意圖',
#   '不良',
#   '人士',
#   '入侵者',
#   '警告',
#   '必要',
#   '時',
#   '使用',
#   '武力',
#   '看出',
#   '現在',
#   '職場',
#   '漸漸',
#   '第二',
#   '專長',
#   '轉為',
#   '需要',
#   '防禦',
#   '技能',
#   '人才',
#   '學會',
#   '雙手',
#   '扣住',
#   '對方',
#   '頸部',
#   '利用',
#   '全身',
#   '重量',
#   '對方',
#   '地面',
#   '順勢',
#   '摔倒',
#   '脖子',
#   '勢必會',
#   '斷掉',
#   '扣住',
#   '瞬間',
#   '掙脫',
#   '一定',
#   '吃',
#   '下',
#   '這招',
#   '危險',
#   '招式',
#   '人',
#   '模仿',
#   '學會',
#   '美編',
#   '人才',
#   '起薪',
#   '有沒有',
#   '八卦',
#   '肥肥',
#   '宅',
#   '好',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   'ˋ',
#   'ˊ',
#   '堅持',
#   '手打',
#   '簽名檔',
#   '設定',
#   '印章',
#   '檔',
#   '新聞',
#   '說',
#   '美編',
#   '職務',
#   '內容',
#   '包含',
#   '使用',
#   '武力',
#   '保護',
#   '公司',
#   '財產'],
#  ['早',
#   '夏天',
#   '台灣',
#   '政府',
#   '顯得',
#   '有點',
#   '焦頭爛額',
#   '一下',
#   '墾丁',
#   '觀光',
#   '雪崩',
#   '式',
#   '下跌',
#   '一下',
#   '限電',
#   '危機',
#   '先講',
#   '墾丁',
#   '觀光',
#   '部分',
#   '說',
#   '墾丁',
#   '特色',
#   '貴',
#   '墾丁',
#   '沖繩',
#   '限電',
#   '方面',
#   '政府',
#   '現在',
#   '重啟',
#   '核四',
#   '限電',
#   '問題',
#   '卻',
#   '焦頭爛額',
#   '能夠',
#   '一個',
#   '新',
#   '核災',
#   '話題',
#   '炒',
#   '勢必',
#   '是場',
#   '肥宅',
#   '想',
#   '政府',
#   '現在',
#   '派',
#   '中國',
#   '懇求',
#   '中共',
#   '找',
#   '一天',
#   '砲',
#   '墾丁',
#   '避開',
#   '核三廠',
#   '好',
#   '為習',
#   '包子',
#   '核災',
#   '問題',
#   '勢必',
#   '再度',
#   '引起',
#   '討論',
#   '風向',
#   '勢必',
#   '反核',
#   '一面倒',
#   '之後',
#   '全民',
#   '關',
#   '冷氣',
#   '沒人敢',
#   '說',
#   '最後',
#   '墾丁',
#   '再',
#   '一陣子',
#   '砲',
#   '完',
#   '之後',
#   '戰地',
#   '風情',
#   '主題',
#   '號召',
#   '重振',
#   '觀光',
#   '阿共',
#   '砲',
#   '菜刀',
#   '墾丁',
#   '之後',
#   '特色',
#   '戰地',
#   '風情',
#   '本島',
#   '金門',
#   '之稱',
#   '沖繩',
#   '做出',
#   '市場',
#   '區隔',
#   '重振',
#   '觀光',
#   '產業',
#   '暗黑',
#   '兵法',
#   '請',
#   '墾丁',
#   '獻頭',
#   '之計',
#   '台灣',
#   '政府',
#   '解套',
#   'posted',
#   'from',
#   'bbs',
#   'reader',
#   'hybrid',
#   'on',
#   'my',
#   'HTC',
#   'M9u'],
#  ...]

# %%
## compute average word vector
# 取文章的word_to_vector即平均

avg_vector = []

for l in data_filtered:
    if len(l)==0:
        avg_vector.append(np.array([0]*256))
    else:
        avg_vector.append(np.mean([model.wv[w] for w in l], axis=0))

# %%
## print result
avg_vector[0]
# Out:
# array([-0.68055314,  0.05094759,  0.57281476,  0.10107148,  0.3388336 ,
#        -0.01827348,  0.36960447, -0.12697896, -0.48268333, -0.36877367,
#         0.11968862,  0.01388675,  0.4214364 ,  0.11778571,  0.59997165,
#        -0.26375124,  0.48322743, -0.07498453, -0.09125967, -0.20234321,
#        -0.14534453,  0.37221536, -0.39518803,  0.04505754, -0.44199014,
#         0.17408557, -0.10395862, -0.3934876 , -0.38835168, -0.24746521,
#        -0.10790766,  0.01623107, -0.1119165 , -0.32476956,  0.10873866,
#        -0.09347805,  0.02681187,  0.45053607,  0.46996   , -0.31227395,
#         0.12117735, -0.2227672 ,  0.8154415 , -0.07444791, -0.06743594,
#         0.07066832,  0.5569929 ,  0.75086397, -0.02436471,  0.14262249,
#         0.2273726 , -0.01645747, -0.15243667, -0.0307577 , -0.07960398,
#        -0.24362792, -0.00666824,  0.17994426,  0.82434237, -0.05714604,
#         0.2403738 , -0.4537454 ,  0.01720293, -0.28141412,  0.05441887,
#         0.5716332 , -0.502425  ,  0.0756568 ,  0.12954336, -0.5898428 ,
#        -0.33270293, -0.06757332,  0.11803066,  0.39877972,  0.01655497,
#         0.12631157,  0.05355934,  0.02770187, -0.16495538, -0.13987434,
#         0.06507473,  0.2397271 , -0.15687005, -0.4362912 , -0.44061014,
#        -0.2758936 , -0.5539773 , -0.2878468 ,  0.17930347,  0.02127537,
#        -0.1857881 , -0.12740722,  0.5125901 ,  0.02480428, -0.00175567,
#         0.4008874 , -0.1418447 , -0.16628857, -0.45492518, -0.41679338,
#        -0.27412423,  0.33563468, -0.14482318,  0.7597451 , -0.41738722,
#         0.14234452, -0.60456526, -0.26220265, -0.24669035,  0.48201314,
#        -0.28358307, -0.61281157, -0.29953113, -0.03971763,  0.31786656,
#        -0.15455894, -0.2727487 , -0.16623881, -0.24842303, -0.3581269 ,
#        -0.11715704, -0.01346849,  0.560239  ,  0.17919071,  0.10717284,
#        -0.20195024, -0.69042176, -0.60633236,  0.12942977,  0.08226413,
#        -0.5302842 , -0.2210747 ,  0.22666946, -0.02734512,  0.01408837,
#         0.10601981, -0.42932233,  0.46697697,  0.09581823,  0.04174642,
#        -0.4082746 ,  0.37898546, -0.062692  ,  0.11711971, -0.05764111,
#        -0.2335329 , -0.50891936, -0.26277807, -0.16417165,  0.4162384 ,
#        -0.4041948 , -0.3539312 , -0.08280286,  0.6143684 ,  0.19242741,
#         0.3162875 ,  0.2014507 , -0.15514302, -0.24743685,  0.09995823,
#         0.5671664 ,  0.62436056, -0.10767806, -0.24798486, -0.06708775,
#         0.05235098, -0.16202946, -0.06934886, -0.2584852 , -0.31432107,
#         0.20235686, -0.58663243,  0.00854261, -0.20132986,  0.18502326,
#        -0.03275961,  0.04725447,  0.1419167 , -0.61431485, -0.29371187,
#         0.22167459, -0.4377134 , -0.01415959,  0.2992885 , -0.00898441,
#        -0.19290009, -0.07200619, -0.12525679, -0.28152004, -0.59190464,
#        -0.5996188 , -0.5185344 ,  0.12639193,  0.10999751,  0.15841067,
#         0.6012187 , -0.17278896, -0.09999143, -0.26313615, -0.17829874,
#         0.3997153 , -0.34413812, -0.4140413 , -0.10604486, -0.35840294,
#         0.3472452 , -0.47810048,  0.02983813, -0.58058935, -0.6309682 ,
#         0.4810031 , -0.42584682,  0.21489555, -0.4664134 ,  0.22011673,
#         0.07416679, -0.04501467,  0.02623248,  0.18618137, -0.02820891,
#        -0.19771378, -0.48077393,  0.30625987, -0.22154441, -0.14439143,
#        -0.37901717, -0.0663837 ,  0.11974652,  0.12190815, -0.00816903,
#        -0.03324082,  0.07128219, -0.15605475, -0.39850053, -0.13322793,
#        -0.08677938,  0.29852155,  0.01769966,  0.25804964,  0.43061015,
#         0.17839962,  0.26063514,  0.28488004,  0.11444532,  0.2633613 ,
#         0.7617592 , -0.6811303 , -0.12064756,  0.12732325,  0.7093743 ,
#         0.21981093, -0.48805803, -0.14742935, -0.18042822, -0.5969723 ,
#         0.24405713], dtype=float32)

# %%
## save result
with open('avg_article_vector', 'wb') as file:
    pickle.dump(avg_vector, file)

# %% [markdown]
# # doc2vec

# %%
## create a document id map
#創一個空集合
sentence_list = []

#sentence做id assign 對label做label_sentence 
for i, l in enumerate(data):
    sentence_list.append(doc2vec.LabeledSentence(words=l, tags=[str(i)]))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `LabeledSentence` (Class will be removed in 4.0.0, use TaggedDocument instead).
#   import sys

# %%
## print result
# [0]中所有關鍵字
sentence_list[0]
# Out:
# LabeledSentence(words=['韓瑜', '協志', '前妻', '正', '女演員', '周子', '瑜', 'TWICE', '團裡裡面', '台灣', '人', '正', '兩個', '要當', '鄉民', '老婆', '選', '五樓', '真', '勇氣'], tags=['0'])

# %%
## define 轉換器 
model = Doc2Vec(size=256, min_count=5, window=4) # Doc2Vec: The import Module
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:574: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
print(model)
# Out:
# Doc2Vec(dm/m,d256,n5,w4,mc5,s0.001,t3)

# %%
## build vocabulary
model.build_vocab(sentence_list)
# Out:
# 2020-02-08 22:33:42,561: INFO: collecting all words and their counts
# 2020-02-08 22:33:42,563: INFO: PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-02-08 22:33:42,980: INFO: PROGRESS: at example #10000, processed 450472 words (1083143/s), 62530 word types, 10000 tags
# 2020-02-08 22:33:43,385: INFO: PROGRESS: at example #20000, processed 917994 words (1158315/s), 94798 word types, 20000 tags
# 2020-02-08 22:33:43,854: INFO: PROGRESS: at example #30000, processed 1376864 words (979493/s), 119647 word types, 30000 tags
# 2020-02-08 22:33:44,323: INFO: PROGRESS: at example #40000, processed 1830843 words (977044/s), 139918 word types, 40000 tags
# 2020-02-08 22:33:44,721: INFO: PROGRESS: at example #50000, processed 2296622 words (1176661/s), 158826 word types, 50000 tags
# 2020-02-08 22:33:45,125: INFO: PROGRESS: at example #60000, processed 2758111 words (1147144/s), 175445 word types, 60000 tags
# 2020-02-08 22:33:45,503: INFO: PROGRESS: at example #70000, processed 3207991 words (1202263/s), 190133 word types, 70000 tags
# 2020-02-08 22:33:45,894: INFO: PROGRESS: at example #80000, processed 3673394 words (1194456/s), 204929 word types, 80000 tags
# 2020-02-08 22:33:46,334: INFO: PROGRESS: at example #90000, processed 4150285 words (1090240/s), 220178 word types, 90000 tags
# 2020-02-08 22:33:46,708: INFO: PROGRESS: at example #100000, processed 4586170 words (1171102/s), 232949 word types, 100000 tags
# 2020-02-08 22:33:47,080: INFO: PROGRESS: at example #110000, processed 5046757 words (1247475/s), 245237 word types, 110000 tags
# 2020-02-08 22:33:48,681: INFO: PROGRESS: at example #120000, processed 5492090 words (278360/s), 256501 word types, 120000 tags
# 2020-02-08 22:33:49,061: INFO: PROGRESS: at example #130000, processed 5940297 words (1188406/s), 267710 word types, 130000 tags
# 2020-02-08 22:33:49,485: INFO: PROGRESS: at example #140000, processed 6397077 words (1080433/s), 278552 word types, 140000 tags
# 2020-02-08 22:33:49,873: INFO: PROGRESS: at example #150000, processed 6852157 words (1178680/s), 289207 word types, 150000 tags
# 2020-02-08 22:33:50,315: INFO: PROGRESS: at example #160000, processed 7314121 words (1051006/s), 300645 word types, 160000 tags
# 2020-02-08 22:33:50,712: INFO: PROGRESS: at example #170000, processed 7778365 words (1167310/s), 311065 word types, 170000 tags
# 2020-02-08 22:33:51,164: INFO: PROGRESS: at example #180000, processed 8243928 words (1033776/s), 321562 word types, 180000 tags
# 2020-02-08 22:33:51,530: INFO: PROGRESS: at example #190000, processed 8694493 words (1240667/s), 331279 word types, 190000 tags
# 2020-02-08 22:33:51,931: INFO: PROGRESS: at example #200000, processed 9139086 words (1120296/s), 340145 word types, 200000 tags
# 2020-02-08 22:33:52,313: INFO: PROGRESS: at example #210000, processed 9593110 words (1195222/s), 349116 word types, 210000 tags
# 2020-02-08 22:33:52,749: INFO: PROGRESS: at example #220000, processed 10070866 words (1100148/s), 358685 word types, 220000 tags
# 2020-02-08 22:33:53,152: INFO: PROGRESS: at example #230000, processed 10553199 words (1196298/s), 368027 word types, 230000 tags
# 2020-02-08 22:33:53,499: INFO: PROGRESS: at example #240000, processed 11016363 words (1347220/s), 376775 word types, 240000 tags
# 2020-02-08 22:33:53,864: INFO: PROGRESS: at example #250000, processed 11477995 words (1270791/s), 385906 word types, 250000 tags
# 2020-02-08 22:33:53,965: INFO: collected 388118 word types and 252229 unique tags from a corpus of 252229 examples and 11587581 words
# 2020-02-08 22:33:53,967: INFO: Loading a fresh vocabulary
# 2020-02-08 22:33:54,934: INFO: effective_min_count=5 retains 100034 unique words (25% of original 388118, drops 288084)
# 2020-02-08 22:33:54,937: INFO: effective_min_count=5 leaves 11155104 word corpus (96% of original 11587581, drops 432477)
# 2020-02-08 22:33:56,081: INFO: deleting the raw counts dictionary of 388118 items
# 2020-02-08 22:33:56,108: INFO: sample=0.001 downsamples 18 most-common words
# 2020-02-08 22:33:56,113: INFO: downsampling leaves estimated 10810274 word corpus (96.9% of prior 11155104)
# 2020-02-08 22:33:56,975: INFO: estimated required memory for 100034 words and 256 dimensions: 563614928 bytes
# 2020-02-08 22:33:56,977: INFO: resetting layer weights

# %%
# train word2vec model ; shuffle data every epoch
for i in range(5):
    random.shuffle(sentence_list)
    model.train(sentence_list, total_examples=len(data), epochs=1)
# Out:
# 2020-02-08 22:37:31,668: INFO: training model with 3 workers on 100034 vocabulary and 256 features, using sg=0 hs=0 sample=0.001 negative=5 window=4
# 2020-02-08 22:37:32,855: INFO: EPOCH 1 - PROGRESS: at 0.56% examples, 56803 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:33,868: INFO: EPOCH 1 - PROGRESS: at 1.26% examples, 65371 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:35,200: INFO: EPOCH 1 - PROGRESS: at 1.88% examples, 59519 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:37:36,504: INFO: EPOCH 1 - PROGRESS: at 2.65% examples, 61167 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:37,539: INFO: EPOCH 1 - PROGRESS: at 3.33% examples, 63305 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:38,628: INFO: EPOCH 1 - PROGRESS: at 4.07% examples, 65739 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:39,718: INFO: EPOCH 1 - PROGRESS: at 4.75% examples, 66281 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:37:40,850: INFO: EPOCH 1 - PROGRESS: at 5.35% examples, 65338 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:41,964: INFO: EPOCH 1 - PROGRESS: at 6.03% examples, 65656 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:43,170: INFO: EPOCH 1 - PROGRESS: at 6.64% examples, 64520 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:44,221: INFO: EPOCH 1 - PROGRESS: at 7.37% examples, 65188 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:37:45,418: INFO: EPOCH 1 - PROGRESS: at 7.93% examples, 64372 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:46,461: INFO: EPOCH 1 - PROGRESS: at 8.60% examples, 64932 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:47,608: INFO: EPOCH 1 - PROGRESS: at 9.20% examples, 64440 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:48,692: INFO: EPOCH 1 - PROGRESS: at 9.87% examples, 64773 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:37:49,822: INFO: EPOCH 1 - PROGRESS: at 10.53% examples, 64819 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:50,956: INFO: EPOCH 1 - PROGRESS: at 11.13% examples, 64850 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:52,092: INFO: EPOCH 1 - PROGRESS: at 11.80% examples, 64973 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:53,227: INFO: EPOCH 1 - PROGRESS: at 12.48% examples, 65077 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:54,444: INFO: EPOCH 1 - PROGRESS: at 13.16% examples, 64930 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:55,625: INFO: EPOCH 1 - PROGRESS: at 13.92% examples, 65299 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:56,724: INFO: EPOCH 1 - PROGRESS: at 14.70% examples, 65857 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:57,843: INFO: EPOCH 1 - PROGRESS: at 15.47% examples, 66295 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:37:58,932: INFO: EPOCH 1 - PROGRESS: at 16.19% examples, 66449 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:37:59,957: INFO: EPOCH 1 - PROGRESS: at 16.82% examples, 66400 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:00,973: INFO: EPOCH 1 - PROGRESS: at 17.43% examples, 66374 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:02,040: INFO: EPOCH 1 - PROGRESS: at 18.05% examples, 66234 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:03,166: INFO: EPOCH 1 - PROGRESS: at 18.76% examples, 66278 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:04,369: INFO: EPOCH 1 - PROGRESS: at 19.55% examples, 66678 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:05,527: INFO: EPOCH 1 - PROGRESS: at 20.37% examples, 66930 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:06,543: INFO: EPOCH 1 - PROGRESS: at 21.09% examples, 67357 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:07,684: INFO: EPOCH 1 - PROGRESS: at 21.90% examples, 67608 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:08,801: INFO: EPOCH 1 - PROGRESS: at 22.68% examples, 67878 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:09,867: INFO: EPOCH 1 - PROGRESS: at 23.40% examples, 67974 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:10,897: INFO: EPOCH 1 - PROGRESS: at 24.27% examples, 68596 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:11,973: INFO: EPOCH 1 - PROGRESS: at 25.14% examples, 69123 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:12,973: INFO: EPOCH 1 - PROGRESS: at 25.79% examples, 69288 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:14,127: INFO: EPOCH 1 - PROGRESS: at 26.57% examples, 69421 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:15,224: INFO: EPOCH 1 - PROGRESS: at 27.31% examples, 69637 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:16,390: INFO: EPOCH 1 - PROGRESS: at 28.14% examples, 69950 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:17,454: INFO: EPOCH 1 - PROGRESS: at 28.87% examples, 70120 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:18,476: INFO: EPOCH 1 - PROGRESS: at 29.64% examples, 70412 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:19,541: INFO: EPOCH 1 - PROGRESS: at 30.39% examples, 70632 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:20,544: INFO: EPOCH 1 - PROGRESS: at 31.15% examples, 70936 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:21,635: INFO: EPOCH 1 - PROGRESS: at 31.84% examples, 70916 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:22,661: INFO: EPOCH 1 - PROGRESS: at 32.53% examples, 70968 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:23,858: INFO: EPOCH 1 - PROGRESS: at 33.30% examples, 70980 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:24,928: INFO: EPOCH 1 - PROGRESS: at 34.06% examples, 71161 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:26,027: INFO: EPOCH 1 - PROGRESS: at 34.83% examples, 71285 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:27,145: INFO: EPOCH 1 - PROGRESS: at 35.61% examples, 71391 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:28,189: INFO: EPOCH 1 - PROGRESS: at 36.55% examples, 71899 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:29,245: INFO: EPOCH 1 - PROGRESS: at 37.25% examples, 71906 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:30,331: INFO: EPOCH 1 - PROGRESS: at 37.98% examples, 71877 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:31,493: INFO: EPOCH 1 - PROGRESS: at 38.74% examples, 71905 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:32,610: INFO: EPOCH 1 - PROGRESS: at 39.47% examples, 71990 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:33,677: INFO: EPOCH 1 - PROGRESS: at 40.27% examples, 72134 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:34,701: INFO: EPOCH 1 - PROGRESS: at 40.97% examples, 72170 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:35,888: INFO: EPOCH 1 - PROGRESS: at 41.68% examples, 72022 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:37,117: INFO: EPOCH 1 - PROGRESS: at 42.45% examples, 71975 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:38,163: INFO: EPOCH 1 - PROGRESS: at 43.23% examples, 72120 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:39,172: INFO: EPOCH 1 - PROGRESS: at 43.93% examples, 72170 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:40,210: INFO: EPOCH 1 - PROGRESS: at 44.54% examples, 72048 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:41,414: INFO: EPOCH 1 - PROGRESS: at 45.33% examples, 72026 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:42,455: INFO: EPOCH 1 - PROGRESS: at 46.19% examples, 72309 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:43,628: INFO: EPOCH 1 - PROGRESS: at 47.08% examples, 72555 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:44,759: INFO: EPOCH 1 - PROGRESS: at 47.89% examples, 72605 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:45,898: INFO: EPOCH 1 - PROGRESS: at 48.68% examples, 72649 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:47,140: INFO: EPOCH 1 - PROGRESS: at 49.72% examples, 72955 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:48,419: INFO: EPOCH 1 - PROGRESS: at 50.50% examples, 72855 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:49,770: INFO: EPOCH 1 - PROGRESS: at 51.25% examples, 72689 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:51,029: INFO: EPOCH 1 - PROGRESS: at 52.02% examples, 72615 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:52,042: INFO: EPOCH 1 - PROGRESS: at 52.70% examples, 72641 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:53,174: INFO: EPOCH 1 - PROGRESS: at 53.28% examples, 72449 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:54,256: INFO: EPOCH 1 - PROGRESS: at 53.87% examples, 72307 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:55,414: INFO: EPOCH 1 - PROGRESS: at 54.57% examples, 72215 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:56,623: INFO: EPOCH 1 - PROGRESS: at 55.20% examples, 71972 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:57,625: INFO: EPOCH 1 - PROGRESS: at 55.74% examples, 71798 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:38:58,663: INFO: EPOCH 1 - PROGRESS: at 56.44% examples, 71819 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:38:59,740: INFO: EPOCH 1 - PROGRESS: at 57.08% examples, 71805 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:00,830: INFO: EPOCH 1 - PROGRESS: at 57.89% examples, 71962 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:02,002: INFO: EPOCH 1 - PROGRESS: at 58.68% examples, 71971 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:03,101: INFO: EPOCH 1 - PROGRESS: at 59.44% examples, 72040 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:04,105: INFO: EPOCH 1 - PROGRESS: at 60.14% examples, 72077 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:05,319: INFO: EPOCH 1 - PROGRESS: at 60.76% examples, 71856 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:06,392: INFO: EPOCH 1 - PROGRESS: at 61.36% examples, 71747 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:07,418: INFO: EPOCH 1 - PROGRESS: at 61.92% examples, 71576 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:08,691: INFO: EPOCH 1 - PROGRESS: at 62.60% examples, 71409 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:09,881: INFO: EPOCH 1 - PROGRESS: at 63.38% examples, 71415 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:10,921: INFO: EPOCH 1 - PROGRESS: at 64.11% examples, 71435 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:11,947: INFO: EPOCH 1 - PROGRESS: at 64.74% examples, 71461 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:13,075: INFO: EPOCH 1 - PROGRESS: at 65.33% examples, 71321 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:14,082: INFO: EPOCH 1 - PROGRESS: at 65.95% examples, 71268 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:15,213: INFO: EPOCH 1 - PROGRESS: at 66.59% examples, 71219 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:16,383: INFO: EPOCH 1 - PROGRESS: at 67.21% examples, 71062 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:17,433: INFO: EPOCH 1 - PROGRESS: at 67.91% examples, 71077 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:18,436: INFO: EPOCH 1 - PROGRESS: at 68.60% examples, 71121 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:19,500: INFO: EPOCH 1 - PROGRESS: at 69.20% examples, 71026 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:20,854: INFO: EPOCH 1 - PROGRESS: at 69.96% examples, 70927 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:22,212: INFO: EPOCH 1 - PROGRESS: at 70.73% examples, 70831 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:23,474: INFO: EPOCH 1 - PROGRESS: at 71.52% examples, 70794 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:24,501: INFO: EPOCH 1 - PROGRESS: at 72.11% examples, 70730 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:25,617: INFO: EPOCH 1 - PROGRESS: at 72.78% examples, 70708 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:26,747: INFO: EPOCH 1 - PROGRESS: at 73.40% examples, 70587 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:27,995: INFO: EPOCH 1 - PROGRESS: at 74.18% examples, 70566 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:29,174: INFO: EPOCH 1 - PROGRESS: at 74.90% examples, 70543 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:30,230: INFO: EPOCH 1 - PROGRESS: at 75.51% examples, 70479 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:31,409: INFO: EPOCH 1 - PROGRESS: at 76.18% examples, 70419 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:32,414: INFO: EPOCH 1 - PROGRESS: at 76.84% examples, 70452 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:33,541: INFO: EPOCH 1 - PROGRESS: at 77.38% examples, 70327 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:34,610: INFO: EPOCH 1 - PROGRESS: at 77.98% examples, 70255 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:35,637: INFO: EPOCH 1 - PROGRESS: at 78.48% examples, 70132 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:36,730: INFO: EPOCH 1 - PROGRESS: at 79.01% examples, 69977 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:37,829: INFO: EPOCH 1 - PROGRESS: at 79.62% examples, 69894 words/s, in_qsize 6, out_qsize 1
# 2020-02-08 22:39:38,861: INFO: EPOCH 1 - PROGRESS: at 80.26% examples, 69910 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:40,168: INFO: EPOCH 1 - PROGRESS: at 81.02% examples, 69862 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:41,200: INFO: EPOCH 1 - PROGRESS: at 81.72% examples, 69893 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:42,488: INFO: EPOCH 1 - PROGRESS: at 82.33% examples, 69710 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:43,900: INFO: EPOCH 1 - PROGRESS: at 83.13% examples, 69617 words/s, in_qsize 6, out_qsize 1
# 2020-02-08 22:39:45,230: INFO: EPOCH 1 - PROGRESS: at 83.91% examples, 69564 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:46,235: INFO: EPOCH 1 - PROGRESS: at 84.53% examples, 69538 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:47,690: INFO: EPOCH 1 - PROGRESS: at 85.24% examples, 69354 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:49,079: INFO: EPOCH 1 - PROGRESS: at 86.01% examples, 69273 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:50,150: INFO: EPOCH 1 - PROGRESS: at 86.51% examples, 69150 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:51,174: INFO: EPOCH 1 - PROGRESS: at 87.04% examples, 69051 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:52,197: INFO: EPOCH 1 - PROGRESS: at 87.53% examples, 68954 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:53,223: INFO: EPOCH 1 - PROGRESS: at 88.24% examples, 68990 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:54,285: INFO: EPOCH 1 - PROGRESS: at 89.00% examples, 69072 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:55,410: INFO: EPOCH 1 - PROGRESS: at 89.68% examples, 69061 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:56,563: INFO: EPOCH 1 - PROGRESS: at 90.27% examples, 68967 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:57,808: INFO: EPOCH 1 - PROGRESS: at 90.97% examples, 68901 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:39:58,928: INFO: EPOCH 1 - PROGRESS: at 91.57% examples, 68824 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:39:59,989: INFO: EPOCH 1 - PROGRESS: at 92.35% examples, 68910 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:01,055: INFO: EPOCH 1 - PROGRESS: at 93.14% examples, 68992 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:02,088: INFO: EPOCH 1 - PROGRESS: at 93.85% examples, 69028 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:03,134: INFO: EPOCH 1 - PROGRESS: at 94.72% examples, 69181 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:04,153: INFO: EPOCH 1 - PROGRESS: at 95.49% examples, 69281 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:05,194: INFO: EPOCH 1 - PROGRESS: at 96.20% examples, 69307 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:06,248: INFO: EPOCH 1 - PROGRESS: at 96.95% examples, 69375 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:07,324: INFO: EPOCH 1 - PROGRESS: at 97.71% examples, 69444 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:08,334: INFO: EPOCH 1 - PROGRESS: at 98.40% examples, 69483 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:09,479: INFO: EPOCH 1 - PROGRESS: at 99.05% examples, 69459 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:10,873: INFO: EPOCH 1 - PROGRESS: at 99.82% examples, 69381 words/s, in_qsize 2, out_qsize 1
# 2020-02-08 22:40:10,879: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-02-08 22:40:10,887: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-02-08 22:40:10,897: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-02-08 22:40:10,902: INFO: EPOCH - 1 : training on 11587581 raw words (11062036 effective words) took 159.2s, 69489 effective words/s
# 2020-02-08 22:40:10,905: INFO: training on a 11587581 raw words (11062036 effective words) took 159.2s, 69470 effective words/s
# 2020-02-08 22:40:12,265: WARNING: Effective 'alpha' higher than previous training cycles
# 2020-02-08 22:40:12,269: INFO: training model with 3 workers on 100034 vocabulary and 256 features, using sg=0 hs=0 sample=0.001 negative=5 window=4
# 2020-02-08 22:40:13,471: INFO: EPOCH 1 - PROGRESS: at 0.61% examples, 56597 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:14,649: INFO: EPOCH 1 - PROGRESS: at 1.37% examples, 64272 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:15,653: INFO: EPOCH 1 - PROGRESS: at 2.10% examples, 67779 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:16,754: INFO: EPOCH 1 - PROGRESS: at 2.70% examples, 65959 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:18,105: INFO: EPOCH 1 - PROGRESS: at 3.49% examples, 65383 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:19,311: INFO: EPOCH 1 - PROGRESS: at 4.28% examples, 66335 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:20,393: INFO: EPOCH 1 - PROGRESS: at 5.05% examples, 68046 words/s, in_qsize 6, out_qsize 1
# 2020-02-08 22:40:21,533: INFO: EPOCH 1 - PROGRESS: at 5.75% examples, 67900 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:22,589: INFO: EPOCH 1 - PROGRESS: at 6.36% examples, 67403 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:23,840: INFO: EPOCH 1 - PROGRESS: at 7.03% examples, 66641 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:24,912: INFO: EPOCH 1 - PROGRESS: at 7.71% examples, 67040 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:26,030: INFO: EPOCH 1 - PROGRESS: at 8.30% examples, 66411 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:27,044: INFO: EPOCH 1 - PROGRESS: at 8.91% examples, 66365 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:28,165: INFO: EPOCH 1 - PROGRESS: at 9.54% examples, 65880 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:29,350: INFO: EPOCH 1 - PROGRESS: at 10.21% examples, 65769 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:30,363: INFO: EPOCH 1 - PROGRESS: at 10.73% examples, 65255 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:31,463: INFO: EPOCH 1 - PROGRESS: at 11.33% examples, 64948 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:32,532: INFO: EPOCH 1 - PROGRESS: at 12.10% examples, 65735 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:33,729: INFO: EPOCH 1 - PROGRESS: at 12.72% examples, 65519 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:34,749: INFO: EPOCH 1 - PROGRESS: at 13.38% examples, 65928 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:35,753: INFO: EPOCH 1 - PROGRESS: at 14.01% examples, 66345 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:36,819: INFO: EPOCH 1 - PROGRESS: at 14.53% examples, 65797 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:37,831: INFO: EPOCH 1 - PROGRESS: at 15.07% examples, 65418 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:38,888: INFO: EPOCH 1 - PROGRESS: at 15.61% examples, 64976 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:39,900: INFO: EPOCH 1 - PROGRESS: at 16.21% examples, 65007 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:41,179: INFO: EPOCH 1 - PROGRESS: at 16.91% examples, 64752 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:42,426: INFO: EPOCH 1 - PROGRESS: at 17.71% examples, 64899 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:43,596: INFO: EPOCH 1 - PROGRESS: at 18.47% examples, 65207 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:44,736: INFO: EPOCH 1 - PROGRESS: at 19.18% examples, 65272 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:45,820: INFO: EPOCH 1 - PROGRESS: at 19.81% examples, 65150 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:46,896: INFO: EPOCH 1 - PROGRESS: at 20.41% examples, 65035 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:47,906: INFO: EPOCH 1 - PROGRESS: at 21.11% examples, 65321 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:49,055: INFO: EPOCH 1 - PROGRESS: at 21.72% examples, 65089 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:50,075: INFO: EPOCH 1 - PROGRESS: at 22.49% examples, 65602 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:51,096: INFO: EPOCH 1 - PROGRESS: at 23.37% examples, 66327 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:52,320: INFO: EPOCH 1 - PROGRESS: at 24.28% examples, 66904 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:53,520: INFO: EPOCH 1 - PROGRESS: at 25.05% examples, 67027 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:54,641: INFO: EPOCH 1 - PROGRESS: at 25.87% examples, 67268 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:55,827: INFO: EPOCH 1 - PROGRESS: at 26.61% examples, 67395 words/s, in_qsize 6, out_qsize 1
# 2020-02-08 22:40:56,923: INFO: EPOCH 1 - PROGRESS: at 27.37% examples, 67649 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:40:58,087: INFO: EPOCH 1 - PROGRESS: at 28.14% examples, 67798 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:40:59,293: INFO: EPOCH 1 - PROGRESS: at 28.91% examples, 67877 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:00,469: INFO: EPOCH 1 - PROGRESS: at 29.70% examples, 67997 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:01,529: INFO: EPOCH 1 - PROGRESS: at 30.38% examples, 68078 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:02,638: INFO: EPOCH 1 - PROGRESS: at 30.99% examples, 67905 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:03,663: INFO: EPOCH 1 - PROGRESS: at 31.46% examples, 67650 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:04,734: INFO: EPOCH 1 - PROGRESS: at 32.23% examples, 67901 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:05,830: INFO: EPOCH 1 - PROGRESS: at 32.92% examples, 67932 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:06,872: INFO: EPOCH 1 - PROGRESS: at 33.63% examples, 68027 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:07,873: INFO: EPOCH 1 - PROGRESS: at 34.51% examples, 68514 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:08,936: INFO: EPOCH 1 - PROGRESS: at 35.17% examples, 68558 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:10,069: INFO: EPOCH 1 - PROGRESS: at 35.95% examples, 68700 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:11,124: INFO: EPOCH 1 - PROGRESS: at 36.71% examples, 68926 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:12,226: INFO: EPOCH 1 - PROGRESS: at 37.35% examples, 68779 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:13,296: INFO: EPOCH 1 - PROGRESS: at 37.97% examples, 68668 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:14,326: INFO: EPOCH 1 - PROGRESS: at 38.63% examples, 68750 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:15,504: INFO: EPOCH 1 - PROGRESS: at 39.40% examples, 68824 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:16,514: INFO: EPOCH 1 - PROGRESS: at 40.10% examples, 68924 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:17,687: INFO: EPOCH 1 - PROGRESS: at 40.73% examples, 68696 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:18,875: INFO: EPOCH 1 - PROGRESS: at 41.50% examples, 68765 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:19,886: INFO: EPOCH 1 - PROGRESS: at 42.26% examples, 69005 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:21,019: INFO: EPOCH 1 - PROGRESS: at 43.02% examples, 69103 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:22,104: INFO: EPOCH 1 - PROGRESS: at 43.89% examples, 69385 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:23,288: INFO: EPOCH 1 - PROGRESS: at 44.87% examples, 69696 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:24,375: INFO: EPOCH 1 - PROGRESS: at 45.69% examples, 69844 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:25,416: INFO: EPOCH 1 - PROGRESS: at 46.46% examples, 70017 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:26,453: INFO: EPOCH 1 - PROGRESS: at 47.39% examples, 70445 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:27,597: INFO: EPOCH 1 - PROGRESS: at 48.19% examples, 70604 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:28,835: INFO: EPOCH 1 - PROGRESS: at 49.04% examples, 70708 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:29,870: INFO: EPOCH 1 - PROGRESS: at 49.72% examples, 70746 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:31,052: INFO: EPOCH 1 - PROGRESS: at 50.46% examples, 70763 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:32,325: INFO: EPOCH 1 - PROGRESS: at 51.22% examples, 70703 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:33,473: INFO: EPOCH 1 - PROGRESS: at 51.86% examples, 70524 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:34,537: INFO: EPOCH 1 - PROGRESS: at 52.54% examples, 70539 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:35,546: INFO: EPOCH 1 - PROGRESS: at 53.15% examples, 70482 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:36,573: INFO: EPOCH 1 - PROGRESS: at 53.94% examples, 70639 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:37,702: INFO: EPOCH 1 - PROGRESS: at 54.71% examples, 70687 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:38,772: INFO: EPOCH 1 - PROGRESS: at 55.47% examples, 70783 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:39,818: INFO: EPOCH 1 - PROGRESS: at 56.25% examples, 70987 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:40,841: INFO: EPOCH 1 - PROGRESS: at 56.90% examples, 71006 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:41,874: INFO: EPOCH 1 - PROGRESS: at 57.61% examples, 71037 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:42,990: INFO: EPOCH 1 - PROGRESS: at 58.21% examples, 70897 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:44,310: INFO: EPOCH 1 - PROGRESS: at 58.96% examples, 70803 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:45,331: INFO: EPOCH 1 - PROGRESS: at 59.68% examples, 70844 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:46,408: INFO: EPOCH 1 - PROGRESS: at 60.28% examples, 70741 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:47,512: INFO: EPOCH 1 - PROGRESS: at 61.07% examples, 70812 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:48,709: INFO: EPOCH 1 - PROGRESS: at 61.89% examples, 70831 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:49,829: INFO: EPOCH 1 - PROGRESS: at 62.67% examples, 70891 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:50,963: INFO: EPOCH 1 - PROGRESS: at 63.44% examples, 70942 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:52,125: INFO: EPOCH 1 - PROGRESS: at 64.23% examples, 70972 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:53,204: INFO: EPOCH 1 - PROGRESS: at 65.01% examples, 71061 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:54,374: INFO: EPOCH 1 - PROGRESS: at 65.78% examples, 71084 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:55,431: INFO: EPOCH 1 - PROGRESS: at 66.54% examples, 71186 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:56,600: INFO: EPOCH 1 - PROGRESS: at 67.30% examples, 71207 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:57,757: INFO: EPOCH 1 - PROGRESS: at 68.10% examples, 71240 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:41:58,778: INFO: EPOCH 1 - PROGRESS: at 68.85% examples, 71355 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:41:59,861: INFO: EPOCH 1 - PROGRESS: at 69.64% examples, 71435 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:00,922: INFO: EPOCH 1 - PROGRESS: at 70.46% examples, 71612 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:01,958: INFO: EPOCH 1 - PROGRESS: at 71.32% examples, 71805 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:03,057: INFO: EPOCH 1 - PROGRESS: at 72.10% examples, 71917 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:04,108: INFO: EPOCH 1 - PROGRESS: at 72.93% examples, 72011 words/s, in_qsize 4, out_qsize 1
# 2020-02-08 22:42:05,152: INFO: EPOCH 1 - PROGRESS: at 73.77% examples, 72187 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:06,268: INFO: EPOCH 1 - PROGRESS: at 74.38% examples, 72064 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:07,415: INFO: EPOCH 1 - PROGRESS: at 75.15% examples, 72075 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:08,492: INFO: EPOCH 1 - PROGRESS: at 75.93% examples, 72141 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:09,857: INFO: EPOCH 1 - PROGRESS: at 76.59% examples, 71926 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:11,213: INFO: EPOCH 1 - PROGRESS: at 77.33% examples, 71824 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:12,363: INFO: EPOCH 1 - PROGRESS: at 78.09% examples, 71848 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:13,389: INFO: EPOCH 1 - PROGRESS: at 78.85% examples, 71941 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:14,534: INFO: EPOCH 1 - PROGRESS: at 79.62% examples, 71970 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:15,568: INFO: EPOCH 1 - PROGRESS: at 80.21% examples, 71908 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:16,571: INFO: EPOCH 1 - PROGRESS: at 80.83% examples, 71929 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:17,796: INFO: EPOCH 1 - PROGRESS: at 81.46% examples, 71829 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:19,106: INFO: EPOCH 1 - PROGRESS: at 82.21% examples, 71759 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:20,356: INFO: EPOCH 1 - PROGRESS: at 82.98% examples, 71726 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:21,704: INFO: EPOCH 1 - PROGRESS: at 83.76% examples, 71638 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:22,742: INFO: EPOCH 1 - PROGRESS: at 84.35% examples, 71580 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:23,940: INFO: EPOCH 1 - PROGRESS: at 85.01% examples, 71490 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:25,185: INFO: EPOCH 1 - PROGRESS: at 85.73% examples, 71463 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:26,271: INFO: EPOCH 1 - PROGRESS: at 86.45% examples, 71454 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:27,286: INFO: EPOCH 1 - PROGRESS: at 87.06% examples, 71408 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:28,351: INFO: EPOCH 1 - PROGRESS: at 87.66% examples, 71340 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:29,364: INFO: EPOCH 1 - PROGRESS: at 88.36% examples, 71368 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:30,476: INFO: EPOCH 1 - PROGRESS: at 88.96% examples, 71275 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:31,502: INFO: EPOCH 1 - PROGRESS: at 89.57% examples, 71228 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:32,583: INFO: EPOCH 1 - PROGRESS: at 90.16% examples, 71152 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:33,628: INFO: EPOCH 1 - PROGRESS: at 90.90% examples, 71167 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:34,705: INFO: EPOCH 1 - PROGRESS: at 91.61% examples, 71162 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:35,818: INFO: EPOCH 1 - PROGRESS: at 92.30% examples, 71139 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:36,903: INFO: EPOCH 1 - PROGRESS: at 93.25% examples, 71329 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:37,983: INFO: EPOCH 1 - PROGRESS: at 94.01% examples, 71386 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:38,991: INFO: EPOCH 1 - PROGRESS: at 94.70% examples, 71416 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:40,129: INFO: EPOCH 1 - PROGRESS: at 95.48% examples, 71478 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:41,230: INFO: EPOCH 1 - PROGRESS: at 96.28% examples, 71522 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:42,248: INFO: EPOCH 1 - PROGRESS: at 97.18% examples, 71673 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:43,444: INFO: EPOCH 1 - PROGRESS: at 98.08% examples, 71798 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:44,473: INFO: EPOCH 1 - PROGRESS: at 98.92% examples, 71930 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:45,546: INFO: EPOCH 1 - PROGRESS: at 99.71% examples, 71985 words/s, in_qsize 4, out_qsize 0
# 2020-02-08 22:42:45,779: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-02-08 22:42:45,840: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-02-08 22:42:45,866: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-02-08 22:42:45,866: INFO: EPOCH - 1 : training on 11587581 raw words (11063448 effective words) took 153.6s, 72040 effective words/s
# 2020-02-08 22:42:45,871: INFO: training on a 11587581 raw words (11063448 effective words) took 153.6s, 72029 effective words/s
# 2020-02-08 22:42:46,648: WARNING: Effective 'alpha' higher than previous training cycles
# 2020-02-08 22:42:46,648: INFO: training model with 3 workers on 100034 vocabulary and 256 features, using sg=0 hs=0 sample=0.001 negative=5 window=4
# 2020-02-08 22:42:47,675: INFO: EPOCH 1 - PROGRESS: at 0.69% examples, 74418 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:48,689: INFO: EPOCH 1 - PROGRESS: at 1.44% examples, 79313 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:49,711: INFO: EPOCH 1 - PROGRESS: at 2.16% examples, 77573 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:50,764: INFO: EPOCH 1 - PROGRESS: at 3.01% examples, 80850 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:51,791: INFO: EPOCH 1 - PROGRESS: at 3.80% examples, 81356 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:52,847: INFO: EPOCH 1 - PROGRESS: at 4.58% examples, 81141 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:53,859: INFO: EPOCH 1 - PROGRESS: at 5.44% examples, 82966 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:54,905: INFO: EPOCH 1 - PROGRESS: at 6.15% examples, 81684 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:55,915: INFO: EPOCH 1 - PROGRESS: at 6.96% examples, 83004 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:56,919: INFO: EPOCH 1 - PROGRESS: at 7.66% examples, 82302 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:42:57,982: INFO: EPOCH 1 - PROGRESS: at 8.50% examples, 82968 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:42:59,074: INFO: EPOCH 1 - PROGRESS: at 9.42% examples, 84042 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:00,376: INFO: EPOCH 1 - PROGRESS: at 10.44% examples, 84372 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:01,390: INFO: EPOCH 1 - PROGRESS: at 11.29% examples, 85017 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:02,426: INFO: EPOCH 1 - PROGRESS: at 12.05% examples, 84848 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:03,429: INFO: EPOCH 1 - PROGRESS: at 12.82% examples, 84836 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:04,520: INFO: EPOCH 1 - PROGRESS: at 13.61% examples, 84969 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:05,525: INFO: EPOCH 1 - PROGRESS: at 14.39% examples, 84989 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:06,624: INFO: EPOCH 1 - PROGRESS: at 15.20% examples, 85238 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:07,808: INFO: EPOCH 1 - PROGRESS: at 16.06% examples, 84967 words/s, in_qsize 6, out_qsize 1
# 2020-02-08 22:43:08,858: INFO: EPOCH 1 - PROGRESS: at 16.85% examples, 84808 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:09,878: INFO: EPOCH 1 - PROGRESS: at 17.54% examples, 84347 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:10,909: INFO: EPOCH 1 - PROGRESS: at 18.12% examples, 83519 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:12,052: INFO: EPOCH 1 - PROGRESS: at 18.81% examples, 82761 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:13,090: INFO: EPOCH 1 - PROGRESS: at 19.44% examples, 82033 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:14,158: INFO: EPOCH 1 - PROGRESS: at 20.23% examples, 81962 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:15,320: INFO: EPOCH 1 - PROGRESS: at 21.20% examples, 82281 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:16,453: INFO: EPOCH 1 - PROGRESS: at 22.01% examples, 82037 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:17,491: INFO: EPOCH 1 - PROGRESS: at 22.70% examples, 81745 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:18,556: INFO: EPOCH 1 - PROGRESS: at 23.44% examples, 81665 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:19,557: INFO: EPOCH 1 - PROGRESS: at 24.12% examples, 81489 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:20,716: INFO: EPOCH 1 - PROGRESS: at 24.83% examples, 80957 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:21,834: INFO: EPOCH 1 - PROGRESS: at 25.47% examples, 80532 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:22,902: INFO: EPOCH 1 - PROGRESS: at 26.07% examples, 79977 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:24,044: INFO: EPOCH 1 - PROGRESS: at 26.77% examples, 79574 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:25,139: INFO: EPOCH 1 - PROGRESS: at 27.51% examples, 79523 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:26,450: INFO: EPOCH 1 - PROGRESS: at 28.32% examples, 79062 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:27,457: INFO: EPOCH 1 - PROGRESS: at 28.91% examples, 78739 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:28,653: INFO: EPOCH 1 - PROGRESS: at 29.62% examples, 78313 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:29,671: INFO: EPOCH 1 - PROGRESS: at 30.27% examples, 78227 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:30,702: INFO: EPOCH 1 - PROGRESS: at 30.89% examples, 77905 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:31,803: INFO: EPOCH 1 - PROGRESS: at 31.69% examples, 77900 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:33,036: INFO: EPOCH 1 - PROGRESS: at 32.42% examples, 77667 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:34,134: INFO: EPOCH 1 - PROGRESS: at 33.11% examples, 77473 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:35,321: INFO: EPOCH 1 - PROGRESS: at 33.77% examples, 77142 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:36,336: INFO: EPOCH 1 - PROGRESS: at 34.39% examples, 76904 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:37,366: INFO: EPOCH 1 - PROGRESS: at 35.00% examples, 76633 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:38,406: INFO: EPOCH 1 - PROGRESS: at 35.57% examples, 76368 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:39,486: INFO: EPOCH 1 - PROGRESS: at 36.27% examples, 76244 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:40,644: INFO: EPOCH 1 - PROGRESS: at 36.87% examples, 75832 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:41,703: INFO: EPOCH 1 - PROGRESS: at 37.56% examples, 75754 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:43,034: INFO: EPOCH 1 - PROGRESS: at 38.18% examples, 75149 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:44,117: INFO: EPOCH 1 - PROGRESS: at 38.69% examples, 74730 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:45,125: INFO: EPOCH 1 - PROGRESS: at 39.39% examples, 74746 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:46,130: INFO: EPOCH 1 - PROGRESS: at 39.92% examples, 74443 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:47,330: INFO: EPOCH 1 - PROGRESS: at 40.53% examples, 74065 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:48,364: INFO: EPOCH 1 - PROGRESS: at 41.12% examples, 73892 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:49,406: INFO: EPOCH 1 - PROGRESS: at 41.80% examples, 73878 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:50,469: INFO: EPOCH 1 - PROGRESS: at 42.45% examples, 73829 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:51,717: INFO: EPOCH 1 - PROGRESS: at 43.22% examples, 73715 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:52,726: INFO: EPOCH 1 - PROGRESS: at 43.82% examples, 73593 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:53,914: INFO: EPOCH 1 - PROGRESS: at 44.51% examples, 73424 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:55,015: INFO: EPOCH 1 - PROGRESS: at 45.22% examples, 73357 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:43:56,087: INFO: EPOCH 1 - PROGRESS: at 45.81% examples, 73175 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:57,186: INFO: EPOCH 1 - PROGRESS: at 46.45% examples, 72977 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:58,408: INFO: EPOCH 1 - PROGRESS: at 47.12% examples, 72792 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:43:59,566: INFO: EPOCH 1 - PROGRESS: at 47.89% examples, 72806 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:00,646: INFO: EPOCH 1 - PROGRESS: at 48.61% examples, 72771 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:01,831: INFO: EPOCH 1 - PROGRESS: at 49.20% examples, 72510 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:02,836: INFO: EPOCH 1 - PROGRESS: at 50.12% examples, 72925 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:03,887: INFO: EPOCH 1 - PROGRESS: at 50.94% examples, 73046 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:05,089: INFO: EPOCH 1 - PROGRESS: at 51.52% examples, 72774 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:06,122: INFO: EPOCH 1 - PROGRESS: at 52.23% examples, 72784 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:07,354: INFO: EPOCH 1 - PROGRESS: at 52.86% examples, 72495 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:08,677: INFO: EPOCH 1 - PROGRESS: at 53.63% examples, 72360 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:09,722: INFO: EPOCH 1 - PROGRESS: at 54.25% examples, 72251 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:10,971: INFO: EPOCH 1 - PROGRESS: at 54.97% examples, 72088 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:11,990: INFO: EPOCH 1 - PROGRESS: at 55.57% examples, 72009 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:13,093: INFO: EPOCH 1 - PROGRESS: at 56.23% examples, 71969 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:14,139: INFO: EPOCH 1 - PROGRESS: at 56.82% examples, 71869 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:15,288: INFO: EPOCH 1 - PROGRESS: at 57.54% examples, 71797 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:16,404: INFO: EPOCH 1 - PROGRESS: at 58.17% examples, 71643 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:17,516: INFO: EPOCH 1 - PROGRESS: at 58.87% examples, 71603 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:18,582: INFO: EPOCH 1 - PROGRESS: at 59.46% examples, 71499 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:19,871: INFO: EPOCH 1 - PROGRESS: at 60.22% examples, 71426 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:21,143: INFO: EPOCH 1 - PROGRESS: at 60.98% examples, 71372 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:22,159: INFO: EPOCH 1 - PROGRESS: at 61.67% examples, 71402 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:23,283: INFO: EPOCH 1 - PROGRESS: at 62.26% examples, 71259 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:24,345: INFO: EPOCH 1 - PROGRESS: at 62.89% examples, 71169 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:25,610: INFO: EPOCH 1 - PROGRESS: at 63.60% examples, 71121 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:26,643: INFO: EPOCH 1 - PROGRESS: at 64.28% examples, 71147 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:27,881: INFO: EPOCH 1 - PROGRESS: at 64.89% examples, 70939 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:28,887: INFO: EPOCH 1 - PROGRESS: at 65.61% examples, 70985 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:30,020: INFO: EPOCH 1 - PROGRESS: at 66.18% examples, 70850 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:31,053: INFO: EPOCH 1 - PROGRESS: at 66.81% examples, 70789 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:32,243: INFO: EPOCH 1 - PROGRESS: at 67.50% examples, 70709 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:33,291: INFO: EPOCH 1 - PROGRESS: at 68.20% examples, 70730 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:34,455: INFO: EPOCH 1 - PROGRESS: at 68.84% examples, 70671 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:35,559: INFO: EPOCH 1 - PROGRESS: at 69.61% examples, 70742 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:36,616: INFO: EPOCH 1 - PROGRESS: at 70.20% examples, 70662 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:37,680: INFO: EPOCH 1 - PROGRESS: at 70.90% examples, 70670 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:38,722: INFO: EPOCH 1 - PROGRESS: at 71.51% examples, 70651 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:39,886: INFO: EPOCH 1 - PROGRESS: at 72.09% examples, 70505 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:41,155: INFO: EPOCH 1 - PROGRESS: at 72.82% examples, 70456 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:42,481: INFO: EPOCH 1 - PROGRESS: at 73.59% examples, 70387 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:43,696: INFO: EPOCH 1 - PROGRESS: at 74.33% examples, 70386 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:44,991: INFO: EPOCH 1 - PROGRESS: at 75.11% examples, 70337 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:46,086: INFO: EPOCH 1 - PROGRESS: at 75.63% examples, 70169 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:47,094: INFO: EPOCH 1 - PROGRESS: at 76.28% examples, 70206 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:48,109: INFO: EPOCH 1 - PROGRESS: at 76.80% examples, 70086 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:49,150: INFO: EPOCH 1 - PROGRESS: at 77.40% examples, 70037 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:50,304: INFO: EPOCH 1 - PROGRESS: at 78.10% examples, 69999 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:51,336: INFO: EPOCH 1 - PROGRESS: at 78.73% examples, 69951 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:52,353: INFO: EPOCH 1 - PROGRESS: at 79.52% examples, 70062 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:53,421: INFO: EPOCH 1 - PROGRESS: at 80.21% examples, 70068 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:54,515: INFO: EPOCH 1 - PROGRESS: at 80.91% examples, 70063 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:55,739: INFO: EPOCH 1 - PROGRESS: at 81.57% examples, 69986 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:44:56,773: INFO: EPOCH 1 - PROGRESS: at 82.10% examples, 69869 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:57,837: INFO: EPOCH 1 - PROGRESS: at 82.62% examples, 69739 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:58,877: INFO: EPOCH 1 - PROGRESS: at 83.21% examples, 69693 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:44:59,878: INFO: EPOCH 1 - PROGRESS: at 83.76% examples, 69600 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:00,986: INFO: EPOCH 1 - PROGRESS: at 84.37% examples, 69521 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:01,986: INFO: EPOCH 1 - PROGRESS: at 85.10% examples, 69572 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:02,997: INFO: EPOCH 1 - PROGRESS: at 85.94% examples, 69749 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:04,055: INFO: EPOCH 1 - PROGRESS: at 86.55% examples, 69696 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:05,086: INFO: EPOCH 1 - PROGRESS: at 87.33% examples, 69797 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:06,186: INFO: EPOCH 1 - PROGRESS: at 87.95% examples, 69725 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:07,380: INFO: EPOCH 1 - PROGRESS: at 88.71% examples, 69740 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:08,444: INFO: EPOCH 1 - PROGRESS: at 89.47% examples, 69819 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:09,530: INFO: EPOCH 1 - PROGRESS: at 90.17% examples, 69820 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:10,619: INFO: EPOCH 1 - PROGRESS: at 90.92% examples, 69885 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:11,705: INFO: EPOCH 1 - PROGRESS: at 91.46% examples, 69822 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:13,020: INFO: EPOCH 1 - PROGRESS: at 92.25% examples, 69782 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:45:14,021: INFO: EPOCH 1 - PROGRESS: at 92.96% examples, 69823 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:15,204: INFO: EPOCH 1 - PROGRESS: at 93.52% examples, 69711 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:16,483: INFO: EPOCH 1 - PROGRESS: at 94.28% examples, 69686 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:17,818: INFO: EPOCH 1 - PROGRESS: at 95.05% examples, 69636 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:19,163: INFO: EPOCH 1 - PROGRESS: at 95.83% examples, 69585 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:20,505: INFO: EPOCH 1 - PROGRESS: at 96.62% examples, 69533 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:21,584: INFO: EPOCH 1 - PROGRESS: at 97.32% examples, 69541 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:45:22,717: INFO: EPOCH 1 - PROGRESS: at 97.93% examples, 69458 words/s, in_qsize 6, out_qsize 0
# ...
# 2020-02-08 22:48:05,526: INFO: EPOCH 1 - PROGRESS: at 99.11% examples, 68987 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:06,573: INFO: EPOCH 1 - PROGRESS: at 99.64% examples, 68893 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:06,964: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-02-08 22:48:07,070: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-02-08 22:48:07,084: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-02-08 22:48:07,089: INFO: EPOCH - 1 : training on 11587581 raw words (11063195 effective words) took 160.5s, 68912 effective words/s
# 2020-02-08 22:48:07,093: INFO: training on a 11587581 raw words (11063195 effective words) took 160.6s, 68906 effective words/s
# 2020-02-08 22:48:08,200: WARNING: Effective 'alpha' higher than previous training cycles
# 2020-02-08 22:48:08,202: INFO: training model with 3 workers on 100034 vocabulary and 256 features, using sg=0 hs=0 sample=0.001 negative=5 window=4
# 2020-02-08 22:48:09,277: INFO: EPOCH 1 - PROGRESS: at 0.58% examples, 62521 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:10,381: INFO: EPOCH 1 - PROGRESS: at 1.33% examples, 69995 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:11,422: INFO: EPOCH 1 - PROGRESS: at 1.95% examples, 68080 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:12,572: INFO: EPOCH 1 - PROGRESS: at 2.63% examples, 67535 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:13,577: INFO: EPOCH 1 - PROGRESS: at 3.32% examples, 69137 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:14,685: INFO: EPOCH 1 - PROGRESS: at 3.83% examples, 66148 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:15,835: INFO: EPOCH 1 - PROGRESS: at 4.41% examples, 64912 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:17,086: INFO: EPOCH 1 - PROGRESS: at 5.21% examples, 65441 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:18,184: INFO: EPOCH 1 - PROGRESS: at 5.88% examples, 65864 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:19,501: INFO: EPOCH 1 - PROGRESS: at 6.72% examples, 66607 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:20,735: INFO: EPOCH 1 - PROGRESS: at 7.47% examples, 66853 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:21,950: INFO: EPOCH 1 - PROGRESS: at 8.21% examples, 67123 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:23,061: INFO: EPOCH 1 - PROGRESS: at 9.00% examples, 67896 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:24,271: INFO: EPOCH 1 - PROGRESS: at 9.81% examples, 68127 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:25,379: INFO: EPOCH 1 - PROGRESS: at 10.57% examples, 68702 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:26,480: INFO: EPOCH 1 - PROGRESS: at 11.37% examples, 69246 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:27,540: INFO: EPOCH 1 - PROGRESS: at 12.10% examples, 69384 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:28,662: INFO: EPOCH 1 - PROGRESS: at 12.86% examples, 69759 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:29,793: INFO: EPOCH 1 - PROGRESS: at 13.64% examples, 70073 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:30,814: INFO: EPOCH 1 - PROGRESS: at 14.40% examples, 70678 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:31,928: INFO: EPOCH 1 - PROGRESS: at 15.17% examples, 70978 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:33,053: INFO: EPOCH 1 - PROGRESS: at 15.96% examples, 71214 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:34,074: INFO: EPOCH 1 - PROGRESS: at 16.82% examples, 72075 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:35,078: INFO: EPOCH 1 - PROGRESS: at 17.60% examples, 72568 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:36,134: INFO: EPOCH 1 - PROGRESS: at 18.45% examples, 73225 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:37,213: INFO: EPOCH 1 - PROGRESS: at 19.07% examples, 72798 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:38,358: INFO: EPOCH 1 - PROGRESS: at 19.84% examples, 72868 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:39,472: INFO: EPOCH 1 - PROGRESS: at 20.64% examples, 73011 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:40,505: INFO: EPOCH 1 - PROGRESS: at 21.38% examples, 73320 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:41,672: INFO: EPOCH 1 - PROGRESS: at 22.15% examples, 73332 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:42,755: INFO: EPOCH 1 - PROGRESS: at 22.93% examples, 73491 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:43,922: INFO: EPOCH 1 - PROGRESS: at 23.73% examples, 73494 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:45,012: INFO: EPOCH 1 - PROGRESS: at 24.48% examples, 73642 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:46,122: INFO: EPOCH 1 - PROGRESS: at 25.33% examples, 74149 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:47,235: INFO: EPOCH 1 - PROGRESS: at 26.19% examples, 74464 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:48,308: INFO: EPOCH 1 - PROGRESS: at 26.97% examples, 74602 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:49,416: INFO: EPOCH 1 - PROGRESS: at 27.77% examples, 74671 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:50,508: INFO: EPOCH 1 - PROGRESS: at 28.52% examples, 74765 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:51,573: INFO: EPOCH 1 - PROGRESS: at 29.29% examples, 74894 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:52,630: INFO: EPOCH 1 - PROGRESS: at 30.10% examples, 75047 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:53,716: INFO: EPOCH 1 - PROGRESS: at 30.87% examples, 75123 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:54,804: INFO: EPOCH 1 - PROGRESS: at 31.68% examples, 75218 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:55,820: INFO: EPOCH 1 - PROGRESS: at 32.44% examples, 75417 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:56,868: INFO: EPOCH 1 - PROGRESS: at 33.30% examples, 75756 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:48:57,999: INFO: EPOCH 1 - PROGRESS: at 34.27% examples, 76137 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:48:59,139: INFO: EPOCH 1 - PROGRESS: at 35.04% examples, 76115 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:00,272: INFO: EPOCH 1 - PROGRESS: at 35.84% examples, 76106 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:01,378: INFO: EPOCH 1 - PROGRESS: at 36.63% examples, 76110 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:02,419: INFO: EPOCH 1 - PROGRESS: at 37.37% examples, 76215 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:03,537: INFO: EPOCH 1 - PROGRESS: at 38.14% examples, 76208 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:04,556: INFO: EPOCH 1 - PROGRESS: at 38.83% examples, 76181 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:05,678: INFO: EPOCH 1 - PROGRESS: at 39.46% examples, 75841 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:06,750: INFO: EPOCH 1 - PROGRESS: at 40.21% examples, 75921 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:08,027: INFO: EPOCH 1 - PROGRESS: at 41.21% examples, 76208 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:09,108: INFO: EPOCH 1 - PROGRESS: at 41.96% examples, 76260 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:10,157: INFO: EPOCH 1 - PROGRESS: at 42.58% examples, 76049 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:11,286: INFO: EPOCH 1 - PROGRESS: at 43.37% examples, 76041 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:12,347: INFO: EPOCH 1 - PROGRESS: at 44.14% examples, 76111 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:13,384: INFO: EPOCH 1 - PROGRESS: at 44.84% examples, 76074 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:14,496: INFO: EPOCH 1 - PROGRESS: at 45.63% examples, 76096 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:15,547: INFO: EPOCH 1 - PROGRESS: at 46.37% examples, 76176 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:16,577: INFO: EPOCH 1 - PROGRESS: at 47.15% examples, 76275 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:17,642: INFO: EPOCH 1 - PROGRESS: at 47.94% examples, 76344 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:18,673: INFO: EPOCH 1 - PROGRESS: at 48.67% examples, 76435 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:19,763: INFO: EPOCH 1 - PROGRESS: at 49.45% examples, 76465 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:20,776: INFO: EPOCH 1 - PROGRESS: at 50.22% examples, 76578 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:21,850: INFO: EPOCH 1 - PROGRESS: at 50.98% examples, 76620 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:22,990: INFO: EPOCH 1 - PROGRESS: at 51.98% examples, 76967 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:24,127: INFO: EPOCH 1 - PROGRESS: at 53.05% examples, 77314 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:25,161: INFO: EPOCH 1 - PROGRESS: at 53.87% examples, 77512 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:26,183: INFO: EPOCH 1 - PROGRESS: at 54.64% examples, 77589 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:27,199: INFO: EPOCH 1 - PROGRESS: at 55.39% examples, 77660 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:28,219: INFO: EPOCH 1 - PROGRESS: at 56.16% examples, 77730 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:29,295: INFO: EPOCH 1 - PROGRESS: at 56.91% examples, 77737 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:30,378: INFO: EPOCH 1 - PROGRESS: at 57.70% examples, 77767 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:31,449: INFO: EPOCH 1 - PROGRESS: at 58.51% examples, 77796 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:32,509: INFO: EPOCH 1 - PROGRESS: at 59.32% examples, 77821 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:33,585: INFO: EPOCH 1 - PROGRESS: at 60.15% examples, 77963 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:34,698: INFO: EPOCH 1 - PROGRESS: at 60.96% examples, 77951 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:35,733: INFO: EPOCH 1 - PROGRESS: at 61.73% examples, 78010 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:36,781: INFO: EPOCH 1 - PROGRESS: at 62.50% examples, 78055 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:37,832: INFO: EPOCH 1 - PROGRESS: at 63.29% examples, 78095 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:38,865: INFO: EPOCH 1 - PROGRESS: at 64.08% examples, 78153 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:39,944: INFO: EPOCH 1 - PROGRESS: at 64.94% examples, 78272 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:41,042: INFO: EPOCH 1 - PROGRESS: at 65.66% examples, 78262 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:42,213: INFO: EPOCH 1 - PROGRESS: at 66.42% examples, 78200 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:43,275: INFO: EPOCH 1 - PROGRESS: at 67.22% examples, 78225 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:44,563: INFO: EPOCH 1 - PROGRESS: at 68.03% examples, 78069 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:45,722: INFO: EPOCH 1 - PROGRESS: at 68.78% examples, 78010 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:47,053: INFO: EPOCH 1 - PROGRESS: at 69.58% examples, 77834 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:48,225: INFO: EPOCH 1 - PROGRESS: at 70.39% examples, 77776 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:49,389: INFO: EPOCH 1 - PROGRESS: at 71.18% examples, 77734 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:50,435: INFO: EPOCH 1 - PROGRESS: at 71.96% examples, 77779 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:51,455: INFO: EPOCH 1 - PROGRESS: at 72.72% examples, 77834 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:52,587: INFO: EPOCH 1 - PROGRESS: at 73.47% examples, 77802 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:53,778: INFO: EPOCH 1 - PROGRESS: at 74.23% examples, 77737 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:54,822: INFO: EPOCH 1 - PROGRESS: at 74.92% examples, 77689 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:55,845: INFO: EPOCH 1 - PROGRESS: at 75.45% examples, 77548 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:56,875: INFO: EPOCH 1 - PROGRESS: at 76.04% examples, 77425 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:49:57,904: INFO: EPOCH 1 - PROGRESS: at 76.73% examples, 77393 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:49:58,950: INFO: EPOCH 1 - PROGRESS: at 77.34% examples, 77264 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:00,028: INFO: EPOCH 1 - PROGRESS: at 77.97% examples, 77114 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:01,076: INFO: EPOCH 1 - PROGRESS: at 78.63% examples, 77069 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:02,086: INFO: EPOCH 1 - PROGRESS: at 79.22% examples, 76968 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:03,200: INFO: EPOCH 1 - PROGRESS: at 79.97% examples, 76959 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:04,237: INFO: EPOCH 1 - PROGRESS: at 80.73% examples, 77007 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:05,432: INFO: EPOCH 1 - PROGRESS: at 81.47% examples, 76955 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:06,480: INFO: EPOCH 1 - PROGRESS: at 82.12% examples, 76839 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:07,577: INFO: EPOCH 1 - PROGRESS: at 82.93% examples, 76851 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:08,624: INFO: EPOCH 1 - PROGRESS: at 83.59% examples, 76812 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:09,641: INFO: EPOCH 1 - PROGRESS: at 84.26% examples, 76792 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:10,680: INFO: EPOCH 1 - PROGRESS: at 85.03% examples, 76838 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:11,714: INFO: EPOCH 1 - PROGRESS: at 85.69% examples, 76811 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:12,959: INFO: EPOCH 1 - PROGRESS: at 86.36% examples, 76656 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:14,106: INFO: EPOCH 1 - PROGRESS: at 87.17% examples, 76639 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:15,238: INFO: EPOCH 1 - PROGRESS: at 87.96% examples, 76629 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:16,358: INFO: EPOCH 1 - PROGRESS: at 88.75% examples, 76629 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:17,461: INFO: EPOCH 1 - PROGRESS: at 89.54% examples, 76635 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:18,474: INFO: EPOCH 1 - PROGRESS: at 90.28% examples, 76693 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:19,522: INFO: EPOCH 1 - PROGRESS: at 91.04% examples, 76777 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:20,612: INFO: EPOCH 1 - PROGRESS: at 91.81% examples, 76787 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:21,642: INFO: EPOCH 1 - PROGRESS: at 92.51% examples, 76765 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:22,811: INFO: EPOCH 1 - PROGRESS: at 93.35% examples, 76795 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:23,899: INFO: EPOCH 1 - PROGRESS: at 94.26% examples, 76880 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:24,940: INFO: EPOCH 1 - PROGRESS: at 95.02% examples, 76921 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:26,114: INFO: EPOCH 1 - PROGRESS: at 95.71% examples, 76818 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:27,311: INFO: EPOCH 1 - PROGRESS: at 96.51% examples, 76775 words/s, in_qsize 5, out_qsize 0
# 2020-02-08 22:50:28,400: INFO: EPOCH 1 - PROGRESS: at 97.30% examples, 76782 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:29,444: INFO: EPOCH 1 - PROGRESS: at 98.04% examples, 76820 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:30,485: INFO: EPOCH 1 - PROGRESS: at 98.72% examples, 76795 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:31,549: INFO: EPOCH 1 - PROGRESS: at 99.45% examples, 76755 words/s, in_qsize 6, out_qsize 0
# 2020-02-08 22:50:32,239: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-02-08 22:50:32,263: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-02-08 22:50:32,286: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-02-08 22:50:32,290: INFO: EPOCH - 1 : training on 11587581 raw words (11062517 effective words) took 144.1s, 76782 effective words/s
# 2020-02-08 22:50:32,298: INFO: training on a 11587581 raw words (11062517 effective words) took 144.1s, 76773 effective words/s

# %%
## print result
model.docvecs['0'] #print出 一個256維的Array
# Out:
# array([-0.03852876,  0.00765406,  0.02372419,  0.01399603,  0.00710394,
#        -0.01441557,  0.0032913 , -0.02621815,  0.01749706,  0.04937169,
#        -0.02575954,  0.02617125,  0.02449835, -0.0188009 , -0.02720987,
#         0.01799194,  0.02387404,  0.00128834, -0.02824874, -0.01840818,
#        -0.00289498,  0.01977812, -0.01442692,  0.03312167,  0.01492169,
#         0.01493587,  0.02330676,  0.00393479, -0.01106325,  0.01875677,
#         0.01633036,  0.0212524 , -0.03381044,  0.00562285, -0.02668449,
#         0.020941  ,  0.02919257,  0.01184755, -0.01422743, -0.03366645,
#         0.03018854, -0.01897448,  0.02486464,  0.02660862,  0.038867  ,
#         0.01722739, -0.01206049, -0.0320338 , -0.02911738,  0.00358008,
#        -0.02167002, -0.03597216,  0.00970996, -0.00214171, -0.00403694,
#         0.03207056, -0.02492057, -0.01182527, -0.0021317 , -0.034279  ,
#        -0.03350209,  0.0332419 ,  0.02121721, -0.01598504,  0.01517421,
#        -0.02484555, -0.00183117,  0.01435033,  0.03332711,  0.02880821,
#        -0.00672556, -0.02749928,  0.00675008, -0.01533696, -0.00168283,
#         0.02933373,  0.0117223 , -0.02167003,  0.03431396, -0.04684252,
#        -0.02325133, -0.05186068,  0.00223816,  0.00020535,  0.02063267,
#        -0.0107673 ,  0.02666682, -0.00209369, -0.00702684, -0.00685107,
#         0.01502853,  0.03863268, -0.02366795, -0.0037851 ,  0.03843245,
#        -0.00452802, -0.02111473,  0.03251597,  0.01790435,  0.01795508,
#        -0.01723944,  0.0245466 , -0.01938447, -0.00916205, -0.01542892,
#        -0.01406023, -0.02458282, -0.01352488, -0.06755731,  0.02526596,
#         0.02931877, -0.0210936 , -0.03001443,  0.00049749, -0.01087703,
#         0.03622797,  0.02666119,  0.00299641, -0.02751017,  0.06396674,
#        -0.00604379, -0.01655447,  0.00810156, -0.06703539,  0.01150998,
#         0.03224566, -0.02442056, -0.05551591, -0.02227418, -0.06213478,
#         0.0120953 ,  0.02549445,  0.02151279, -0.03160809, -0.01537907,
#        -0.01182884, -0.00780446,  0.00802683, -0.04049474, -0.03147249,
#        -0.01889277, -0.02723121, -0.03608263, -0.02438882,  0.03315635,
#         0.02558609,  0.00196928, -0.04194697,  0.00250823,  0.01196181,
#         0.00756707, -0.00061495,  0.0094833 ,  0.04353461,  0.04823058,
#         0.00100609, -0.04716331, -0.0021901 ,  0.05482329, -0.021927  ,
#         0.00134069,  0.05789802,  0.01917257,  0.00368036,  0.04889235,
#         0.04627943,  0.01347317, -0.01273835,  0.00304983,  0.02408996,
#         0.00965364,  0.00269849,  0.00599107, -0.00266016, -0.01344555,
#        -0.02440281, -0.0250493 , -0.01370868, -0.02774118, -0.0093855 ,
#         0.01007079,  0.0580656 ,  0.00850511, -0.00329723,  0.01098863,
#        -0.04395156,  0.03031461,  0.02424044, -0.01926486, -0.0135912 ,
#         0.03652957,  0.0432014 ,  0.02524699, -0.01902646, -0.02572035,
#         0.00442417,  0.04763881,  0.0339711 , -0.04744537, -0.0258038 ,
#        -0.03378542, -0.00708899, -0.01607218,  0.00337123,  0.00353471,
#         0.06905937,  0.01480445,  0.00505997, -0.00019134,  0.03060255,
#         0.04730309, -0.02111764, -0.00421644, -0.01580664, -0.04585189,
#        -0.00865697, -0.01474392, -0.00212715, -0.00692795,  0.02980781,
#        -0.00953098, -0.0114182 ,  0.00527535, -0.00674728,  0.05384107,
#        -0.03816906, -0.04806365,  0.02036672,  0.02441613,  0.00891255,
#        -0.00801912, -0.026831  , -0.06847765, -0.02683048,  0.00903291,
#        -0.0052218 , -0.01621388, -0.02210898,  0.01899064,  0.0022745 ,
#        -0.0151258 , -0.0038463 ,  0.01121209,  0.0246512 ,  0.04142909,
#         0.00508327,  0.01646543, -0.02409933, -0.01241794, -0.0416442 ,
#         0.00381175, -0.00130958,  0.01492768, -0.02080162, -0.02274952,
#        -0.03431927], dtype=float32)

# %%
## save result
model.save('word2vec_model.doc2vec')
# Out:
# 2020-02-08 22:50:42,167: INFO: saving Doc2Vec object under word2vec_model.doc2vec, separately None
# 2020-02-08 22:50:42,177: INFO: storing np array 'syn1neg' to word2vec_model.doc2vec.trainables.syn1neg.npy
# 2020-02-08 22:50:42,515: INFO: storing np array 'vectors' to word2vec_model.doc2vec.wv.vectors.npy
# 2020-02-08 22:50:42,867: INFO: storing np array 'vectors_docs' to word2vec_model.doc2vec.docvecs.vectors_docs.npy
# 2020-02-08 22:50:46,441: INFO: saved word2vec_model.doc2vec
